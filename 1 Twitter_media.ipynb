# %%
# !pip install scipy==1.8.0
import scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scipy==1.8.0
#   Downloading scipy-1.8.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 MB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scipy==1.8.0) (1.21.6)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# Successfully installed scipy-1.8.0

# %%
#セクション2 ①
import csv

filename = '1.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    現代ビジネス_lists=[]
    for row in csvreader:
      現代ビジネス_lists += row

    print('データ取得終了時刻：', 現代ビジネス_lists[-2])
    del 現代ビジネス_lists[-1]
    del 現代ビジネス_lists[-1]

    unique_set = set(現代ビジネス_lists)
    現代ビジネス_list = list(unique_set)
    現代ビジネス_list.append('現代ビジネス')

    print('現代ビジネスのフォロワー数：', len(現代ビジネス_list)-1)
    print('\n')

filename = '2.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    沖縄タイムス_lists=[]
    for row in csvreader:
      沖縄タイムス_lists += row

    print('データ取得終了時刻：', 沖縄タイムス_lists[-2])
    del 沖縄タイムス_lists[-1]
    del 沖縄タイムス_lists[-1]

    unique_set = set(沖縄タイムス_lists)
    沖縄タイムス_list = list(unique_set)
    沖縄タイムス_list.append('沖縄タイムス')
        
    print('沖縄タイムスのフォロワー数：', len(沖縄タイムス_list)-1)
    print('\n')
    
filename = '3.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    毎日新聞_lists=[]
    for row in csvreader:
      毎日新聞_lists += row

    print('データ取得終了時刻：', 毎日新聞_lists[-2])
    del 毎日新聞_lists[-1]
    del 毎日新聞_lists[-1]

    unique_set = set(毎日新聞_lists)
    毎日新聞_list = list(unique_set)
    毎日新聞_list.append('毎日新聞')
        
    print('毎日新聞のフォロワー数：', len(毎日新聞_list)-1)
    print('\n')
    
filename = '4.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    朝日新聞_lists=[]
    for row in csvreader:
      朝日新聞_lists += row

    print('データ取得終了時刻：', 朝日新聞_lists[-2])
    del 朝日新聞_lists[-1]
    del 朝日新聞_lists[-1]

    unique_set = set(朝日新聞_lists)
    朝日新聞_list = list(unique_set)
    朝日新聞_list.append('朝日新聞')
        
    print('朝日新聞のフォロワー数：', len(朝日新聞_list)-1)
    print('\n')
    
filename = '5.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    時事ドットコム_lists=[]
    for row in csvreader:
      時事ドットコム_lists += row

    print('データ取得終了時刻：', 時事ドットコム_lists[-2])
    del 時事ドットコム_lists[-1]
    del 時事ドットコム_lists[-1]

    unique_set = set(時事ドットコム_lists)
    時事ドットコム_list = list(unique_set)
    時事ドットコム_list.append('時事ドットコム')
        
    print('時事ドットコムのフォロワー数：', len(時事ドットコム_list)-1)
    print('\n')
    
filename = '6.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本経済新聞_lists=[]
    for row in csvreader:
      日本経済新聞_lists += row

    print('データ取得終了時刻：', 日本経済新聞_lists[-2])
    del 日本経済新聞_lists[-1]
    del 日本経済新聞_lists[-1]

    unique_set = set(日本経済新聞_lists)
    日本経済新聞_list = list(unique_set)
    日本経済新聞_list.append('日本経済新聞')
        
    print('日本経済新聞のフォロワー数：', len(日本経済新聞_list)-1)
    print('\n')
    
filename = '7.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    産経ニュース_lists=[]
    for row in csvreader:
      産経ニュース_lists += row

    print('データ取得終了時刻：', 産経ニュース_lists[-2])
    del 産経ニュース_lists[-1]
    del 産経ニュース_lists[-1]

    unique_set = set(産経ニュース_lists)
    産経ニュース_list = list(unique_set)
    産経ニュース_list.append('産経ニュース')
        
    print('産経ニュースのフォロワー数：', len(産経ニュース_list)-1)
    print('\n')
    
filename = '8.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    東京新聞_lists=[]
    for row in csvreader:
      東京新聞_lists += row

    print('データ取得終了時刻：', 東京新聞_lists[-2])
    del 東京新聞_lists[-1]
    del 東京新聞_lists[-1]

    unique_set = set(東京新聞_lists)
    東京新聞_list = list(unique_set)
    東京新聞_list.append('東京新聞')
        
    print('東京新聞のフォロワー数：', len(東京新聞_list)-1)
    print('\n')
    
filename = '9.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    読売新聞オンライン_lists=[]
    for row in csvreader:
      読売新聞オンライン_lists += row

    print('データ取得終了時刻：', 読売新聞オンライン_lists[-2])
    del 読売新聞オンライン_lists[-1]
    del 読売新聞オンライン_lists[-1]

    unique_set = set(読売新聞オンライン_lists)
    読売新聞オンライン_list = list(unique_set)
    読売新聞オンライン_list.append('読売新聞オンライン')
        
    print('読売新聞オンラインのフォロワー数：', len(読売新聞オンライン_list)-1)
    print('\n')
    
filename = '10.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    zakzak_lists=[]
    for row in csvreader:
      zakzak_lists += row

    print('データ取得終了時刻：', zakzak_lists[-2])
    del zakzak_lists[-1]
    del zakzak_lists[-1]

    unique_set = set(zakzak_lists)
    zakzak_list = list(unique_set)
    zakzak_list.append('zakzak')
        
    print('zakzakのフォロワー数：', len(zakzak_list)-1)
    print('\n')
    
filename = '11.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    NHKニュース_lists=[]
    for row in csvreader:
      NHKニュース_lists += row

    print('データ取得終了時刻：', NHKニュース_lists[-2])
    del NHKニュース_lists[-1]
    del NHKニュース_lists[-1]

    unique_set = set(NHKニュース_lists)
    NHKニュース_list = list(unique_set)
    NHKニュース_list.append('NHKニュース')
        
    print('NHKニュースのフォロワー数：', len(NHKニュース_list)-1)
    print('\n')
    
filename = '12.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    しんぶん赤旗_lists=[]
    for row in csvreader:
      しんぶん赤旗_lists += row

    print('データ取得終了時刻：', しんぶん赤旗_lists[-2])
    del しんぶん赤旗_lists[-1]
    del しんぶん赤旗_lists[-1]

    unique_set = set(しんぶん赤旗_lists)
    しんぶん赤旗_list = list(unique_set)
    しんぶん赤旗_list.append('しんぶん赤旗')
        
    print('しんぶん赤旗のフォロワー数：', len(しんぶん赤旗_list)-1)
    print('\n')
    
filename = '13.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日刊ゲンダイ_lists=[]
    for row in csvreader:
      日刊ゲンダイ_lists += row

    print('データ取得終了時刻：', 日刊ゲンダイ_lists[-2])
    del 日刊ゲンダイ_lists[-1]
    del 日刊ゲンダイ_lists[-1]

    unique_set = set(日刊ゲンダイ_lists)
    日刊ゲンダイ_list = list(unique_set)
    日刊ゲンダイ_list.append('日刊ゲンダイ')
        
    print('日刊ゲンダイのフォロワー数：', len(日刊ゲンダイ_list)-1)
    print('\n')
    
filename = '14.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    アゴラ_lists=[]
    for row in csvreader:
      アゴラ_lists += row

    print('データ取得終了時刻：', アゴラ_lists[-2])
    del アゴラ_lists[-1]
    del アゴラ_lists[-1]

    unique_set = set(アゴラ_lists)
    アゴラ_list = list(unique_set)
    アゴラ_list.append('アゴラ')
        
    print('アゴラのフォロワー数：', len(アゴラ_list)-1)
    print('\n')
    
filename = '15.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    アノニマス_ポスト_lists=[]
    for row in csvreader:
      アノニマス_ポスト_lists += row

    print('データ取得終了時刻：', アノニマス_ポスト_lists[-2])
    del アノニマス_ポスト_lists[-1]
    del アノニマス_ポスト_lists[-1]

    unique_set = set(アノニマス_ポスト_lists)
    アノニマス_ポスト_list = list(unique_set)
    アノニマス_ポスト_list.append('アノニマス_ポスト')
        
    print('アノニマス_ポストのフォロワー数：', len(アノニマス_ポスト_list)-1)
    print('\n')
    
filename = '16.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    ハム速_lists=[]
    for row in csvreader:
      ハム速_lists += row

    print('データ取得終了時刻：', ハム速_lists[-2])
    del ハム速_lists[-1]
    del ハム速_lists[-1]

    unique_set = set(ハム速_lists)
    ハム速_list = list(unique_set)
    ハム速_list.append('ハム速')
        
    print('ハム速のフォロワー数：', len(ハム速_list)-1)
    print('\n')
    
filename = '17.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    政治知新_lists=[]
    for row in csvreader:
      政治知新_lists += row

    print('データ取得終了時刻：', 政治知新_lists[-2])
    del 政治知新_lists[-1]
    del 政治知新_lists[-1]

    unique_set = set(政治知新_lists)
    政治知新_list = list(unique_set)
    政治知新_list.append('政治知新')
        
    print('政治知新のフォロワー数：', len(政治知新_list)-1)
    print('\n')
    
filename = '18.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    litera_lists=[]
    for row in csvreader:
      litera_lists += row

    print('データ取得終了時刻：', litera_lists[-2])
    del litera_lists[-1]
    del litera_lists[-1]

    unique_set = set(litera_lists)
    litera_list = list(unique_set)
    litera_list.append('litera')
        
    print('literaのフォロワー数：', len(litera_list)-1)
    print('\n')
    
filename = '19.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    Share_News_Japan_lists=[]
    for row in csvreader:
      Share_News_Japan_lists += row

    print('データ取得終了時刻：', Share_News_Japan_lists[-2])
    del Share_News_Japan_lists[-1]
    del Share_News_Japan_lists[-1]

    unique_set = set(Share_News_Japan_lists)
    Share_News_Japan_list = list(unique_set)
    Share_News_Japan_list.append('Share_News_Japan')
        
    print('Share_News_Japanのフォロワー数：', len(Share_News_Japan_list)-1)
    print('\n')
    
filename = '20.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    もえるあじあ_lists=[]
    for row in csvreader:
      もえるあじあ_lists += row

    print('データ取得終了時刻：', もえるあじあ_lists[-2])
    del もえるあじあ_lists[-1]
    del もえるあじあ_lists[-1]

    unique_set = set(もえるあじあ_lists)
    もえるあじあ_list = list(unique_set)
    もえるあじあ_list.append('もえるあじあ')
        
    print('もえるあじあのフォロワー数：', len(もえるあじあ_list)-1)
    print('\n')
    
filename = '21.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    BuzzFeed_Japan_lists=[]
    for row in csvreader:
      BuzzFeed_Japan_lists += row

    print('データ取得終了時刻：', BuzzFeed_Japan_lists[-2])
    del BuzzFeed_Japan_lists[-1]
    del BuzzFeed_Japan_lists[-1]

    unique_set = set(BuzzFeed_Japan_lists)
    BuzzFeed_Japan_list = list(unique_set)
    BuzzFeed_Japan_list.append('BuzzFeed_Japan')
        
    print('BuzzFeed_Japanのフォロワー数：', len(BuzzFeed_Japan_list)-1)
    print('\n')
    
filename = '22.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    Yahoo_ニュース_lists=[]
    for row in csvreader:
      Yahoo_ニュース_lists += row

    print('データ取得終了時刻：', Yahoo_ニュース_lists[-2])
    del Yahoo_ニュース_lists[-1]
    del Yahoo_ニュース_lists[-1]

    unique_set = set(Yahoo_ニュース_lists)
    Yahoo_ニュース_list = list(unique_set)
    Yahoo_ニュース_list.append('Yahoo_ニュース')
        
    print('Yahoo_ニュースのフォロワー数：', len(Yahoo_ニュース_list)-1)
    print('\n')

sum_list = [現代ビジネス_list, 沖縄タイムス_list, 毎日新聞_list, 朝日新聞_list, 時事ドットコム_list, 日本経済新聞_list, 産経ニュース_list, 東京新聞_list, 読売新聞オンライン_list, zakzak_list, NHKニュース_list, しんぶん赤旗_list, 日刊ゲンダイ_list, アゴラ_list, アノニマス_ポスト_list, ハム速_list, 政治知新_list, litera_list, Share_News_Japan_list, もえるあじあ_list, BuzzFeed_Japan_list, Yahoo_ニュース_list]
# Out:
# データ取得終了時刻： 2022-04-21T18:41:46
# 現代ビジネスのフォロワー数： 159783
#
#
# データ取得終了時刻： 2022-04-21T18:56:54
# 沖縄タイムスのフォロワー数： 123898
#
#
# データ取得終了時刻： 2022-04-22T23:10:38
# 毎日新聞のフォロワー数： 961908
#
#
# データ取得終了時刻： 2022-04-24T15:42:25
# 朝日新聞のフォロワー数： 1319121
#
#
# データ取得終了時刻： 2022-04-22T08:29:02
# 時事ドットコムのフォロワー数： 333171
#
#
# データ取得終了時刻： 2022-04-26T04:51:54
# 日本経済新聞のフォロワー数： 3502954
#
#
# データ取得終了時刻： 2022-04-24T01:32:45
# 産経ニュースのフォロワー数： 657252
#
#
# データ取得終了時刻： 2022-04-22T16:12:21
# 東京新聞のフォロワー数： 95458
#
#
# データ取得終了時刻： 2022-04-23T21:16:17
# 読売新聞オンラインのフォロワー数： 817603
#
#
# データ取得終了時刻： 2022-04-21T23:06:11
# zakzakのフォロワー数： 72106
#
#
# データ取得終了時刻： 2022-04-27T10:29:08
# NHKニュースのフォロワー数： 3392866
#
#
# データ取得終了時刻： 2022-04-21T23:21:15
# しんぶん赤旗のフォロワー数： 52107
#
#
# データ取得終了時刻： 2022-04-21T23:51:22
# 日刊ゲンダイのフォロワー数： 126359
#
#
# データ取得終了時刻： 2022-04-22T00:06:26
# アゴラのフォロワー数： 43559
#
#
# データ取得終了時刻： 2022-04-22T00:21:32
# アノニマス_ポストのフォロワー数： 119150
#
#
# データ取得終了時刻： 2022-04-22T18:17:41
# ハム速のフォロワー数： 385114
#
#
# データ取得終了時刻： 2022-04-22T09:37:45
# 政治知新のフォロワー数： 67221
#
#
# データ取得終了時刻： 2022-04-22T10:07:54
# literaのフォロワー数： 106136
#
#
# データ取得終了時刻： 2022-04-22T10:38:05
# Share_News_Japanのフォロワー数： 135938
#
#
# データ取得終了時刻： 2022-04-22T10:38:06
# もえるあじあのフォロワー数： 24255
#
#
# データ取得終了時刻： 2022-04-23T14:28:59
# BuzzFeed_Japanのフォロワー数： 187453
#
#
# データ取得終了時刻： 2022-04-23T18:30:20
# Yahoo_ニュースのフォロワー数： 1174048

# %%
import networkx as nx
import math
import csv
import random as rand
import sys

_DEBUG_ = False

                                                                                                               
def buildG(G, list):                                                                                            
    for line in list:
       G.add_edge(line[0], line[1],weight=float(line[2]))                                                       #これでファイルから重み付き無向グラフの情報を打ち込む 元々int関数がついてたが削除
                                                                                                                #もしファイルの情報に重みが付与されていなかったら重みを自動で1とする。
                                                                                                                #この作業はGの中にある塊の数が一つ増えるまでエッジを減らし続ける。得られる成果はエッジが減ったG
                                                                                                                # This method keeps removing edges from Graph until one of the connected components of Graph splits into two
                                                                                                                # compute the edge betweenness
def CmtyGirvanNewmanStep(G): #③
    if _DEBUG_:
        print("Running CmtyGirvanNewmanStep method ...")
    init_ncomp = nx.number_connected_components(G)                                                              #number of components 連結グループの数を取得
    ncomp = init_ncomp                                                                                          #ncompを更新し続けてある塊を分割できるまで繰り返す。
    while ncomp <= init_ncomp:
        bw = nx.edge_betweenness_centrality(G, weight='weight')                                                 #edge betweenness for G
                                                                                                                #find the edge with max centrality その段階のグラフで最大の中心性を持つエッジを取得。
                                                                                                                #bwの形式は形式は{('エッジ', 'エッジ'): edge_betweenness_centralityの値の値, ...}
        max_ = max(bw.values())
                                                                                                                #find the edge with the highest centrality and remove all of them if there is more than one!
        for k, v in bw.items():                                                                                 #この場合kはインデックスでvが中身
            if float(v) == max_:
                G.remove_edge(k[0],k[1])                                                                        #remove the central edge
        ncomp = nx.number_connected_components(G)                                                               #recalculate the no of components

                                                                                                                #渡されたグラフGのモジュラリティーを計算して引数Modとして渡す
                                                                                                                # This method compute the modularity of current split
def _GirvanNewmanGetModularity(G, deg_, m_): #②
    New_A = nx.adjacency_matrix(G)                                                                              #データは['エッジ', 'エッジ', 重み]というリストが並んでいる。
    New_deg = {}
    New_deg = UpdateDeg(New_A, G.nodes())                                                                       #（重複）UpdateDegでは辞書型で{'ノード名': 重みの総和, ...}が取得できる。
                                                                                                                #Let's compute the Q
    comps = nx.connected_components(G)                                                                                                             #list of components データの形式の確認は困難 
    print('Number of communities in decomposed G: {}'.format(nx.number_connected_components(G)))                #元々Noと記載されてたが、Numberに修正
    Mod = 0                                                                                                     #Modularity of a given partitionning
    for c in comps:
        EWC = 0                                                                                                 #number of edges within a community
        RE = 0                                                                                                  #number of random edges
        for u in c:
            EWC += New_deg[u]     #EWCはその連結部のノードの最新の重みの総和
            RE += deg_[u]         #REはその連結部のノードの初期の重みの総和                                           #count the probability of a random edge
        Mod += ( float(EWC) - float(RE*RE)/float(2*m_) )                                                        #モジュラリティーの計算
    Mod = Mod/float(2*m_) 
    if _DEBUG_:
        print("Modularity: {}".format(Mod))
    return Mod

                                                                                                                #（重複）UpdateDegでは辞書型で{'ノード名': 重みの総和, ...}がdeg_dictに格納されている。
def UpdateDeg(A, nodes): #                                                                                      #nodes = G.nodes()でノードが並ぶリストが格納される。
    deg_dict = {}
    n = len(nodes)                                                                                              #len(A) ---> some ppl get issues when trying len() on sparse matrixes!
    B = A.sum(axis = 1)                                                                                         #グラフのノードが持つそれぞれのエッジの重みを足し合わせたものが格納され、それはノードごとにあり、ノードの番号順に並べられる。
    i = 0
    for node_id in list(nodes): 
        deg_dict[node_id] = B[i]                                                                             #Bは縦に一列なのでB[i, 0]はi番目の要素のこと。つまりdeg_dictは
        i += 1
    return deg_dict

color_list10 = ['bisque', 'lightblue', 'lime', 'yellow', 'aqua', 'coral', 'burlywood', 'fuchsia', 'olive', 'blue', 'lightyellow', 'turquoise', 'lavender', 'lightcoral', 'salmon', 'lightskyblue', 'chocolate', 'red', 'palegreen', 'grey']

# %%
#セクション3.1 
#フォロワー総数（重複ありあり/なし）

sum_totalcount_list = 現代ビジネス_list + 沖縄タイムス_list + 毎日新聞_list + 朝日新聞_list + 時事ドットコム_list + 日本経済新聞_list + 産経ニュース_list + 東京新聞_list + 読売新聞オンライン_list + zakzak_list + NHKニュース_list + しんぶん赤旗_list + 日刊ゲンダイ_list + アゴラ_list + アノニマス_ポスト_list + ハム速_list + 政治知新_list + litera_list + Share_News_Japan_list + もえるあじあ_list + BuzzFeed_Japan_list + Yahoo_ニュース_list

print('収集したフォロワーIDの総数：', len(sum_totalcount_list)-22)
print('フォロワーの総数', len(set(sum_totalcount_list))-22)
# Out:
# 収集したフォロワーIDの総数： 13857460
# フォロワーの総数 7701005

# %% [markdown]
# 収集したフォロワーIDの総数： 13857460
# フォロワーの総数 7701005

# %%
#セクションセクション3.2 
#アカウント同士の共通項の数

for n in sum_list:
  for k in sum_list:
    if n == k:
      continue
    n_k_=set(n) & set(k)
    print(n[-1], 'と', k[-1], 'の共通項の数は', len(n_k_))
  print('\n')

# %%
#セクション3.3
#アカウント同士のJaccard係数

sum_list = [現代ビジネス_list, 沖縄タイムス_list, 毎日新聞_list, 朝日新聞_list, 時事ドットコム_list, 日本経済新聞_list, 産経ニュース_list, 東京新聞_list, 読売新聞オンライン_list, zakzak_list, NHKニュース_list, しんぶん赤旗_list, 日刊ゲンダイ_list, アゴラ_list, アノニマス_ポスト_list, ハム速_list, 政治知新_list, litera_list, Share_News_Japan_list, もえるあじあ_list, BuzzFeed_Japan_list, Yahoo_ニュース_list]

for n in sum_list:
  for k in sum_list:
    if n == k:
      continue
    n_k_=set(n) & set(k)
    print(n[-1], 'と', k[-1], 'のJaccard係数は', (len(n_k_))/((len(n)-1)+(len(k)-1)-(len(n_k_))))
  print('\n')

# %%
#セクション3.4
#アカウント同士のDice係数

sum_list = [現代ビジネス_list, 沖縄タイムス_list, 毎日新聞_list, 朝日新聞_list, 時事ドットコム_list, 日本経済新聞_list, 産経ニュース_list, 東京新聞_list, 読売新聞オンライン_list, zakzak_list, NHKニュース_list, しんぶん赤旗_list, 日刊ゲンダイ_list, アゴラ_list, アノニマス_ポスト_list, ハム速_list, 政治知新_list, litera_list, Share_News_Japan_list, もえるあじあ_list, BuzzFeed_Japan_list, Yahoo_ニュース_list]

for n in sum_list:
  for k in sum_list:
    if n == k:
      continue
    n_k_=set(n) & set(k)
    print(n[-1], 'と', k[-1], 'のDice係数は', (len(n_k_)*2)/((len(n)-1)+(len(k)-1)))
  print('\n')

# %%
#セクション3.5
#アカウント同士のSimpson係数

sum_list = [現代ビジネス_list, 沖縄タイムス_list, 毎日新聞_list, 朝日新聞_list, 時事ドットコム_list, 日本経済新聞_list, 産経ニュース_list, 東京新聞_list, 読売新聞オンライン_list, zakzak_list, NHKニュース_list, しんぶん赤旗_list, 日刊ゲンダイ_list, アゴラ_list, アノニマス_ポスト_list, ハム速_list, 政治知新_list, litera_list, Share_News_Japan_list, もえるあじあ_list, BuzzFeed_Japan_list, Yahoo_ニュース_list]

for n in sum_list:
  for k in sum_list:
    if n == k:
      continue
    n_k_=set(n) & set(k)
    print(n[-1], 'と', k[-1], 'のSimpson係数は', (len(n_k_)-1)/min(len(n)-1, len(k)-1))
  print('\n')

# %%
#セクション4.1 ② 重複なし
#グラフリスト Jaccard係数

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['現代ビジネス', '沖縄タイムス', '毎日新聞', '朝日新聞', '時事ドットコム',  '日本経済新聞', '産経ニュース', '東京新聞', '読売新聞オンライン', 'zakzak', 'NHKニュース', 'しんぶん赤旗', '日刊ゲンダイ', 'アゴラ', 'アノニマス_ポスト', 'ハム速', '政治知新', 'litera', 'Share_News_Japan', 'もえるあじあ', 'BuzzFeed_Japan', 'Yahoo_ニュース']
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_j = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Jaccard_media.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_jt=[]
      for row in csvreader:
        a_b_jt += row
  a_b_j = []
  for i in a_b_jt:
    a_b_j.append(float(i))

if data_import == 0:
  a_b_j = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_list = set(a) & set(b)
        a_b_j.append((len(a_b_list))/((len(a)-1)+(len(b)-1)-(len(a_b_list))))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_j[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_j[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_j[e][2] = a_b_j[e]
      
print(matrix_j)
# Out:
# [['Gendai_biz', 'Okinawa', 0.024803569170745804], ['Gendai_biz', 'Mainichi', 0.039088647932598114], ['Gendai_biz', 'Asahi', 0.03558759230912511], ['Gendai_biz', 'Jiji', 0.04137364297197324], ['Gendai_biz', 'Nikkei', 0.023208070040171412], ['Gendai_biz', 'Sankei', 0.03179093300465612], ['Gendai_biz', 'Tokyo', 0.03406770597005251], ['Gendai_biz', 'Yomiuri', 0.046686035740331616], ['Gendai_biz', 'Zakzak', 0.04669973774842807], ['Gendai_biz', 'Nhk', 0.020868228895925232], ['Gendai_biz', 'Akahata', 0.02355890692855038], ['Gendai_biz', 'Nikkan', 0.06613063679008022], ['Gendai_biz', 'Agora', 0.04108172313867642], ['Gendai_biz', 'Anonymous', 0.016427074792748474], ['Gendai_biz', 'Hamusoku', 0.01082998335989196], ['Gendai_biz', 'Seijichishin', 0.01390408725674547], ['Gendai_biz', 'Litera', 0.04112930379697276], ['Gendai_biz', 'Share_News_Japan', 0.020572197680839316], ['Gendai_biz', 'Moeruasia', 0.005556739390561739], ['Gendai_biz', 'BuzzFeed_Japan', 0.023148093582414993], ['Gendai_biz', 'Yahoo_News', 0.02460673622174869], ['Okinawa', 'Mainichi', 0.0235148841505948], ['Okinawa', 'Asahi', 0.019277727980041348], ['Okinawa', 'Jiji', 0.03136268249204594], ['Okinawa', 'Nikkei', 0.007523818201617438], ['Okinawa', 'Sankei', 0.019233855552322585], ['Okinawa', 'Tokyo', 0.05861175323703857], ['Okinawa', 'Yomiuri', 0.01985437166638503], ['Okinawa', 'Zakzak', 0.025576089913978944], ['Okinawa', 'Nhk', 0.010026557697869497], ['Okinawa', 'Akahata', 0.07542420002321873], ['Okinawa', 'Nikkan', 0.07840577087157742], ['Okinawa', 'Agora', 0.015789729093622234], ['Okinawa', 'Anonymous', 0.010140976193642771], ['Okinawa', 'Hamusoku', 0.005110342321848886], ['Okinawa', 'Seijichishin', 0.009817130840479549], ['Okinawa', 'Litera', 0.07539760455527195], ['Okinawa', 'Share_News_Japan', 0.013290280312602367], ['Okinawa', 'Moeruasia', 0.0043249838999423786], ['Okinawa', 'BuzzFeed_Japan', 0.01403060809072345], ['Okinawa', 'Yahoo_News', 0.016304615921880664], ['Mainichi', 'Asahi', 0.33849300864874954], ['Mainichi', 'Jiji', 0.12723583816840137], ['Mainichi', 'Nikkei', 0.11121033086719145], ['Mainichi', 'Sankei', 0.1507202128657564], ['Mainichi', 'Tokyo', 0.03834660523196608], ['Mainichi', 'Yomiuri', 0.28546362366307554], ['Mainichi', 'Zakzak', 0.023026693313809684], ['Mainichi', 'Nhk', 0.12828823703003578], ['Mainichi', 'Akahata', 0.01848410826707593], ['Mainichi', 'Nikkan', 0.05362588805260641], ['Mainichi', 'Agora', 0.011667510169830893], ['Mainichi', 'Anonymous', 0.010863629563135847], ['Mainichi', 'Hamusoku', 0.014311574559342658], ['Mainichi', 'Seijichishin', 0.008158299217967067], ['Mainichi', 'Litera', 0.032015313394098625], ['Mainichi', 'Share_News_Japan', 0.018972438405242226], ['Mainichi', 'Moeruasia', 0.002557828163965325], ['Mainichi', 'BuzzFeed_Japan', 0.016885256344468077], ['Mainichi', 'Yahoo_News', 0.08886016015138323], ['Asahi', 'Jiji', 0.09976178257718105], ['Asahi', 'Nikkei', 0.16473103392304875], ['Asahi', 'Sankei', 0.1301981590853985], ['Asahi', 'Tokyo', 0.038440334308460854], ['Asahi', 'Yomiuri', 0.31525349445884826], ['Asahi', 'Zakzak', 0.018124935965926556], ['Asahi', 'Nhk', 0.19243806934836066], ['Asahi', 'Akahata', 0.015140174877126275], ['Asahi', 'Nikkan', 0.04280426246278353], ['Asahi', 'Agora', 0.010027787845837863], ['Asahi', 'Anonymous', 0.00889951065668526], ['Asahi', 'Hamusoku', 0.012411619266910706], ['Asahi', 'Seijichishin', 0.006690005075777215], ['Asahi', 'Litera', 0.025935286313899745], ['Asahi', 'Share_News_Japan', 0.014776782569701179], ['Asahi', 'Moeruasia', 0.002093886998729644], ['Asahi', 'BuzzFeed_Japan', 0.014222654864158735], ['Asahi', 'Yahoo_News', 0.0841067161794025], ['Jiji', 'Nikkei', 0.053544170789434804], ['Jiji', 'Sankei', 0.20052291352775115], ['Jiji', 'Tokyo', 0.06380935125918609], ['Jiji', 'Yomiuri', 0.14059984934385283], ['Jiji', 'Zakzak', 0.04272776391283094], ['Jiji', 'Nhk', 0.057930038185614055], ['Jiji', 'Akahata', 0.02732581393488521], ['Jiji', 'Nikkan', 0.08039037281026574], ['Jiji', 'Agora', 0.0209789451 ...

# %%
sum_engname_list1 = [['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']]
color_list10 = ['turquoise', 'burlywood', 'lime', 'yellow', 'lavender', 'coral', 'red', 'fuchsia', 'blue', 'lightcoral', 'lightyellow', 'bisque', 'aqua', 'olive', 'salmon', 'lightskyblue', 'chocolate', 'sateblue', 'palegreen', 'grey']

#セクション4.2.1 
#グラフリスト 
#Jaccard係数

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 1

Jaccard係数 = 0.08

matrix_condj = []
for i in range(len(matrix_j)):
  if matrix_j[i][2] >= Jaccard係数 and matrix_j[i][2] != 1:
    matrix_condj.append(matrix_j[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_condj) #ここに三次元リストを入れて実行！
    
  if _DEBUG_:
    print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)                                                                         #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_condj)):
    node_list_del.append(matrix_condj[i][0])
    node_list_del.append(matrix_condj[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/500)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/500) for i in sum_list]

H.add_weighted_edges_from(matrix_condj)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(18,12))
plt.title('Jaccard index Threshold:{}'.format(Jaccard係数))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# Number of communities in decomposed G: 2
# Modularity of decomposed G: 0.4349017145263817
# Identified components: [{'Jiji', 'Nikkei', 'Yahoo_News', 'Sankei', 'Nhk', 'Mainichi', 'Asahi', 'Yomiuri'}, {'Nikkan', 'Litera', 'Moeruasia', 'Share_News_Japan', 'Zakzak', 'Anonymous', 'Akahata', 'Seijichishin', 'Tokyo'}]
# Number of communities in decomposed G: 3
# Modularity of decomposed G: 0.48335508690075296
# Identified components: [{'Jiji', 'Nikkei', 'Yahoo_News', 'Sankei', 'Nhk', 'Mainichi', 'Asahi', 'Yomiuri'}, {'Nikkan', 'Akahata', 'Tokyo', 'Litera'}, {'Moeruasia', 'Zakzak', 'Anonymous', 'Share_News_Japan', 'Seijichishin'}]
# Number of communities in decomposed G: 4
# Modularity of decomposed G: 0.27826195174263646
# Number of communities in decomposed G: 5
# Modularity of decomposed G: 0.23910780024699155
# Number of communities in decomposed G: 7
# Modularity of decomposed G: 0.2673810809146386
# Number of communities in decomposed G: 8
# Modularity of decomposed G: 0.21843509905747
# Number of communities in decomposed G: 17
# Modularity of decomposed G: -0.0701755729865415
# Max modularity found (Q): 0.48335508690075296 and number of communities: 3
# Graph communities: [{'Jiji', 'Nikkei', 'Yahoo_News', 'Sankei', 'Nhk', 'Mainichi', 'Asahi', 'Yomiuri'}, {'Nikkan', 'Akahata', 'Tokyo', 'Litera'}, {'Moeruasia', 'Zakzak', 'Anonymous', 'Share_News_Japan', 'Seijichishin'}]
# <ipython-input-7-7217c7df0eee>:112: DeprecationWarning: nx.nx_pydot.graphviz_layout depends on the pydot package, which hasknown issues and is not actively maintained. Consider usingnx.nx_agraph.graphviz_layout instead.
#
# See https://github.com/networkx/networkx/issues/5723
#   pos=nx.nx_pydot.graphviz_layout(H)
# /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:304: UserWarning:
#
# The connectionstyle keyword argument is not applicable when drawing edges
# with LineCollection.
#
# To make this warning go away, either specify `arrows=True` to
# force FancyArrowPatches or use the default value for connectionstyle.
# Note that using FancyArrowPatches may be slow for large graphs.
#
#   draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)

# %%
#セクション4.2 ② 重複なし
#グラフリスト Dice係数

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['現代ビジネス', '沖縄タイムス', '毎日新聞', '朝日新聞', '時事ドットコム',  '日本経済新聞', '産経ニュース', '東京新聞', '読売新聞オンライン', 'zakzak', 'NHKニュース', 'しんぶん赤旗', '日刊ゲンダイ', 'アゴラ', 'アノニマス_ポスト', 'ハム速', '政治知新', 'litera', 'Share_News_Japan', 'もえるあじあ', 'BuzzFeed_Japan', 'Yahoo_ニュース']
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_d = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Dice_media.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_dt=[]
      for row in csvreader:
        a_b_dt += row
  a_b_d = []
  for i in a_b_dt:
    a_b_d.append(float(i))

if data_import == 0:
  a_b_d = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_list = set(a) & set(b)
        a_b_d.append((len(a_b_list)*2)/((len(a)-1)+(len(b)-1)))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_d[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_d[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_d[e][2] = a_b_d[e]
      
print(matrix_d)
# Out:
# [['Gendai_biz', 'Okinawa', 0.04840648474871422], ['Gendai_biz', 'Mainichi', 0.07523640646131599], ['Gendai_biz', 'Asahi', 0.06872927519298075], ['Gendai_biz', 'Jiji', 0.07945974675121817], ['Gendai_biz', 'Nikkei', 0.045363344406109424], ['Gendai_biz', 'Sankei', 0.06162281909587716], ['Gendai_biz', 'Tokyo', 0.06589066803530781], ['Gendai_biz', 'Yomiuri', 0.08920733466614009], ['Gendai_biz', 'Zakzak', 0.08923234823557823], ['Gendai_biz', 'Nhk', 0.04088329581672718], ['Gendai_biz', 'Akahata', 0.046033319175043656], ['Gendai_biz', 'Nikkan', 0.12405728624249499], ['Gendai_biz', 'Agora', 0.07892122630838685], ['Gendai_biz', 'Anonymous', 0.03232317438237856], ['Gendai_biz', 'Hamusoku', 0.021427902888068753], ['Gendai_biz', 'Seijichishin', 0.027426829483180912], ['Gendai_biz', 'Litera', 0.07900902154415443], ['Gendai_biz', 'Share_News_Japan', 0.0403150266636458], ['Gendai_biz', 'Moeruasia', 0.011052065334333127], ['Gendai_biz', 'BuzzFeed_Japan', 0.04524876452902349], ['Gendai_biz', 'Yahoo_News', 0.048031572215670504], ['Okinawa', 'Mainichi', 0.04594927639007337], ['Okinawa', 'Asahi', 0.037826251767994735], ['Okinawa', 'Jiji', 0.06081795090019231], ['Okinawa', 'Nikkei', 0.014935266175735873], ['Okinawa', 'Sankei', 0.0377417909492415], ['Okinawa', 'Tokyo', 0.11073323729462609], ['Okinawa', 'Yomiuri', 0.03893569948412163], ['Okinawa', 'Zakzak', 0.049876533131976895], ['Okinawa', 'Nhk', 0.019854047641524993], ['Okinawa', 'Akahata', 0.1402687423652737], ['Okinawa', 'Nikkan', 0.14541051798750884], ['Okinawa', 'Agora', 0.03108857796329804], ['Okinawa', 'Anonymous', 0.020078338435206216], ['Okinawa', 'Hamusoku', 0.010168719008589188], ['Okinawa', 'Seijichishin', 0.019443383441730022], ['Okinawa', 'Litera', 0.140222749680482], ['Okinawa', 'Share_News_Japan', 0.026231930910266477], ['Okinawa', 'Moeruasia', 0.008612717933487678], ['Okinawa', 'BuzzFeed_Japan', 0.027672947894819673], ['Okinawa', 'Yahoo_News', 0.03208608062276859], ['Mainichi', 'Asahi', 0.505782258796359], ['Mainichi', 'Jiji', 0.2257483906387178], ['Mainichi', 'Nikkei', 0.2001607216527633], ['Mainichi', 'Sankei', 0.26195805232342695], ['Mainichi', 'Tokyo', 0.07386089584874111], ['Mainichi', 'Yomiuri', 0.44414111517152743], ['Mainichi', 'Zakzak', 0.04501679861201106], ['Mainichi', 'Nhk', 0.22740330497059089], ['Mainichi', 'Akahata', 0.03629729343254291], ['Mainichi', 'Nikkan', 0.10179303424619142], ['Mainichi', 'Agora', 0.023065898731634157], ['Mainichi', 'Anonymous', 0.02149375889175234], ['Mainichi', 'Hamusoku', 0.028219286693164626], ['Mainichi', 'Seijichishin', 0.01618455995312541], ['Mainichi', 'Litera', 0.06204426034882458], ['Mainichi', 'Share_News_Japan', 0.03723837405246273], ['Mainichi', 'Moeruasia', 0.005102604741812459], ['Mainichi', 'BuzzFeed_Japan', 0.0332097574217326], ['Mainichi', 'Yahoo_News', 0.1632168452908206], ['Asahi', 'Jiji', 0.18142434872286498], ['Asahi', 'Nikkei', 0.282865363977126], ['Asahi', 'Sankei', 0.2303988164177511], ['Asahi', 'Tokyo', 0.0740347481476821], ['Asahi', 'Yomiuri', 0.4793805844835365], ['Asahi', 'Zakzak', 0.035604541890000695], ['Asahi', 'Nhk', 0.322764048372799], ['Asahi', 'Akahata', 0.02982873745285248], ['Asahi', 'Nikkan', 0.08209452915294574], ['Asahi', 'Agora', 0.01985645933014354], ['Asahi', 'Anonymous', 0.01764201600393806], ['Asahi', 'Hamusoku', 0.024518919045788873], ['Asahi', 'Seijichishin', 0.013291092674102062], ['Asahi', 'Litera', 0.05055930263805054], ['Asahi', 'Share_News_Japan', 0.029123217683956457], ['Asahi', 'Moeruasia', 0.004179023594287824], ['Asahi', 'BuzzFeed_Japan', 0.02804641524412342], ['Asahi', 'Yahoo_News', 0.1551631678398055], ['Jiji', 'Nikkei', 0.10164580142722147], ['Jiji', 'Sankei', 0.33405928577991423], ['Jiji', 'Tokyo', 0.11996388485146829], ['Jiji', 'Yomiuri', 0.24653667879183924], ['Jiji', 'Zakzak', 0.08195382417457689], ['Jiji', 'Nhk', 0.10951582069635916], ['Jiji', 'Akahata', 0.0531979505707567], ['Jiji', 'Nikkan', 0.14881726981916304], ['Jiji', 'Agora', 0.04109574496323627], ['Jiji', 'Anonymous', 0.0 ...

# %%
sum_engname_list1 = [['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']]
#セクション4.2.1 
#グラフリスト 
#Dice係数

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 0

Dice係数 = 0.2

matrix_condt = []
for i in range(len(matrix_d)):
  if matrix_d[i][2] >= Dice係数 and matrix_d[i][2] != 1:
    matrix_condt.append(matrix_d[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_condt) #ここに三次元リストを入れて実行！

  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))    #
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))  #
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)        
                                                                     #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_condt)):
    node_list_del.append(matrix_condt[i][0])
    node_list_del.append(matrix_condt[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/800)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/800) for i in sum_list]

H.add_weighted_edges_from(matrix_condt)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
  if BestQ == 0.0:
    a = sum_engname_list1
    e = len(sum_engname_list1)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = media, BLUE = political party, LIME = politician')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(18,12))
plt.title('Dice index Threshold:{}'.format(Dice係数))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# Number of communities in decomposed G: 4
# Modularity of decomposed G: 0.5020340228102418
# Identified components: [{'Jiji', 'Nikkei', 'Sankei', 'Nhk', 'Mainichi', 'Asahi', 'Yomiuri'}, {'Yahoo_News'}, {'Nikkan', 'Akahata', 'Litera', 'Tokyo'}, {'Share_News_Japan', 'Moeruasia', 'Seijichishin', 'Anonymous'}]
# Number of communities in decomposed G: 5
# Modularity of decomposed G: 0.40106144135066596
# Number of communities in decomposed G: 14
# Modularity of decomposed G: 0.005087095115156273
# Number of communities in decomposed G: 16
# Modularity of decomposed G: -0.07932941390350305
# Max modularity found (Q): 0.5020340228102418 and number of communities: 4
# Graph communities: [{'Jiji', 'Nikkei', 'Sankei', 'Nhk', 'Mainichi', 'Asahi', 'Yomiuri'}, {'Yahoo_News'}, {'Nikkan', 'Akahata', 'Litera', 'Tokyo'}, {'Share_News_Japan', 'Moeruasia', 'Seijichishin', 'Anonymous'}]
# note : nodes in color gray are not in any community as it have no edges
# <ipython-input-9-8d1d6e6e9466>:113: DeprecationWarning: nx.nx_pydot.graphviz_layout depends on the pydot package, which hasknown issues and is not actively maintained. Consider usingnx.nx_agraph.graphviz_layout instead.
#
# See https://github.com/networkx/networkx/issues/5723
#   pos=nx.nx_pydot.graphviz_layout(H)
# /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:304: UserWarning:
#
# The connectionstyle keyword argument is not applicable when drawing edges
# with LineCollection.
#
# To make this warning go away, either specify `arrows=True` to
# force FancyArrowPatches or use the default value for connectionstyle.
# Note that using FancyArrowPatches may be slow for large graphs.
#
#   draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)

# %%
#セクション4.3 ② 重複なし
#グラフリスト Simpson係数

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['現代ビジネス', '沖縄タイムス', '毎日新聞', '朝日新聞', '時事ドットコム',  '日本経済新聞', '産経ニュース', '東京新聞', '読売新聞オンライン', 'zakzak', 'NHKニュース', 'しんぶん赤旗', '日刊ゲンダイ', 'アゴラ', 'アノニマス_ポスト', 'ハム速', '政治知新', 'litera', 'Share_News_Japan', 'もえるあじあ', 'BuzzFeed_Japan', 'Yahoo_ニュース']
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_s = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Simpson_media.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_st=[]
      for row in csvreader:
        a_b_st += row
  a_b_s = []
  for i in a_b_st:
    a_b_s.append(float(i))

if data_import == 0:
  a_b_s = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_s.append(len(set(a) & set(b))/min((len(a)-1), (len(b)-1)))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_s[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_s[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_s[e][2] = a_b_s[e]
      
print(matrix_s)
# Out:
# [['Gendai_biz', 'Okinawa', 0.055416552325299843], ['Gendai_biz', 'Mainichi', 0.2640831627895333], ['Gendai_biz', 'Asahi', 0.3180688809197474], ['Gendai_biz', 'Jiji', 0.12257248893812232], ['Gendai_biz', 'Nikkei', 0.5199364137611636], ['Gendai_biz', 'Sankei', 0.15755117878622882], ['Gendai_biz', 'Tokyo', 0.08809109765551341], ['Gendai_biz', 'Yomiuri', 0.2728387876056902], ['Gendai_biz', 'Zakzak', 0.1434832052811139], ['Gendai_biz', 'Nhk', 0.45450392094277864], ['Gendai_biz', 'Akahata', 0.09359587003665534], ['Gendai_biz', 'Nikkan', 0.140464865977097], ['Gendai_biz', 'Agora', 0.18420992217452192], ['Gendai_biz', 'Anonymous', 0.037834662190516156], ['Gendai_biz', 'Hamusoku', 0.03653705337864479], ['Gendai_biz', 'Seijichishin', 0.046309932907871054], ['Gendai_biz', 'Litera', 0.09897678450290194], ['Gendai_biz', 'Share_News_Japan', 0.04385087319219056], ['Gendai_biz', 'Moeruasia', 0.04192949907235621], ['Gendai_biz', 'BuzzFeed_Japan', 0.04916668231288685], ['Gendai_biz', 'Yahoo_News', 0.20047814848888806], ['Okinawa', 'Mainichi', 0.20134304024278035], ['Okinawa', 'Asahi', 0.22027797058871007], ['Okinawa', 'Jiji', 0.11218098758656314], ['Okinawa', 'Nikkei', 0.21859917028523462], ['Okinawa', 'Sankei', 0.1189769003535166], ['Okinawa', 'Tokyo', 0.1272287288650506], ['Okinawa', 'Yomiuri', 0.14793620558846793], ['Okinawa', 'Zakzak', 0.06778908828668904], ['Okinawa', 'Nhk', 0.2817721028588032], ['Okinawa', 'Akahata', 0.23689715393325272], ['Okinawa', 'Nikkan', 0.1468546707775751], ['Okinawa', 'Agora', 0.059758029339516516], ['Okinawa', 'Anonymous', 0.020478388585816198], ['Okinawa', 'Hamusoku', 0.02088814992978095], ['Okinawa', 'Seijichishin', 0.027640171970068877], ['Okinawa', 'Litera', 0.15195598100550237], ['Okinawa', 'Share_News_Japan', 0.02750649728002066], ['Okinawa', 'Moeruasia', 0.026303854875283448], ['Okinawa', 'BuzzFeed_Japan', 0.034770537054674006], ['Okinawa', 'Yahoo_News', 0.16806566691956287], ['Mainichi', 'Asahi', 0.5996956049850921], ['Mainichi', 'Jiji', 0.4387566745004817], ['Mainichi', 'Nikkei', 0.46454026788424674], ['Mainichi', 'Sankei', 0.3226707564221942], ['Mainichi', 'Tokyo', 0.4090699574682059], ['Mainichi', 'Yomiuri', 0.48333604451059986], ['Mainichi', 'Zakzak', 0.32277480376112944], ['Mainichi', 'Nhk', 0.5147529701385164], ['Mainichi', 'Akahata', 0.3531771163183449], ['Mainichi', 'Nikkan', 0.4383462990368711], ['Mainichi', 'Agora', 0.266213641268165], ['Mainichi', 'Anonymous', 0.09750734368443138], ['Mainichi', 'Hamusoku', 0.049351620559107176], ['Mainichi', 'Seijichishin', 0.12388985584861874], ['Mainichi', 'Litera', 0.31217494535313184], ['Mainichi', 'Share_News_Japan', 0.15037002162750665], ['Mainichi', 'Moeruasia', 0.10373118944547516], ['Mainichi', 'BuzzFeed_Japan', 0.10181218758835549], ['Mainichi', 'Yahoo_News', 0.1812148355144151], ['Asahi', 'Jiji', 0.44986808575776405], ['Asahi', 'Nikkei', 0.5170101908771068], ['Asahi', 'Sankei', 0.3464074662382161], ['Asahi', 'Tokyo', 0.5485553856146158], ['Asahi', 'Yomiuri', 0.626406703497908], ['Asahi', 'Zakzak', 0.3434804315868305], ['Asahi', 'Nhk', 0.5764672080878099], ['Asahi', 'Akahata', 0.39248085669871613], ['Asahi', 'Nikkan', 0.4695589550407965], ['Asahi', 'Agora', 0.3105902339355816], ['Asahi', 'Anonymous', 0.10647922786403693], ['Asahi', 'Hamusoku', 0.05425146839637095], ['Asahi', 'Seijichishin', 0.1370553844780649], ['Asahi', 'Litera', 0.33947011381623576], ['Asahi', 'Share_News_Japan', 0.1558651738292457], ['Asahi', 'Moeruasia', 0.11572871572871572], ['Asahi', 'BuzzFeed_Japan', 0.11270558486660656], ['Asahi', 'Yahoo_News', 0.16474965248439588], ['Jiji', 'Nikkei', 0.5851739797281276], ['Jiji', 'Sankei', 0.4965318109919531], ['Jiji', 'Tokyo', 0.2693331098493578], ['Jiji', 'Yomiuri', 0.4257693496732909], ['Jiji', 'Zakzak', 0.23031370482345437], ['Jiji', 'Nhk', 0.6123882330695049], ['Jiji', 'Akahata', 0.19667223213771662], ['Jiji', 'Nikkan', 0.27060201489407165], ['Jiji', 'Agora', 0.17771298698317226], ['Jiji', 'Anonymous', 0.1375577003776752], ['Jiji', 'Hamu ...

# %%
sum_engname_list1 = [['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']]
#セクション4.2.1 次数0のノード除去ver
#グラフリスト 
#Simpson係数

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 0

Simpson係数 = 0.5

matrix_cons = []
for i in range(len(matrix_s)):
  if matrix_s[i][2] >= Simpson係数 and matrix_s[i][2] != 1:
    matrix_cons.append(matrix_s[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_cons) #ここに三次元リストを入れて実行！

  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))    #
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))  #
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)                                                                         #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_cons)):
    node_list_del.append(matrix_cons[i][0])
    node_list_del.append(matrix_cons[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/800)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/800) for i in sum_list]

H.add_weighted_edges_from(matrix_cons)
edge_width = [d["weight"] * 5  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = media, BLUE = political party, LIME = politician')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(18,12))
plt.title('Simpson index Threshold:{}'.format(Simpson係数))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# Number of communities in decomposed G: 2
# Modularity of decomposed G: 0.38846609923277675
# Identified components: [{'Nikkan', 'Nikkei', 'Jiji', 'Nhk', 'Mainichi', 'Asahi', 'Gendai_biz', 'Yomiuri', 'Tokyo'}, {'Moeruasia', 'Sankei', 'Zakzak', 'Anonymous', 'Share_News_Japan', 'Seijichishin'}]
# Number of communities in decomposed G: 3
# Modularity of decomposed G: 0.4093502642236359
# Identified components: [{'Nikkei', 'Jiji', 'Gendai_biz'}, {'Nikkan', 'Nhk', 'Mainichi', 'Asahi', 'Yomiuri', 'Tokyo'}, {'Moeruasia', 'Sankei', 'Zakzak', 'Anonymous', 'Share_News_Japan', 'Seijichishin'}]
# Number of communities in decomposed G: 4
# Modularity of decomposed G: 0.36583969191216525
# Number of communities in decomposed G: 5
# Modularity of decomposed G: 0.34159034456437504
# Number of communities in decomposed G: 6
# Modularity of decomposed G: 0.28653708586927773
# Number of communities in decomposed G: 12
# Modularity of decomposed G: -0.06931578373803003
# Number of communities in decomposed G: 15
# Modularity of decomposed G: -0.09547671531342897
# Max modularity found (Q): 0.4093502642236359 and number of communities: 3
# Graph communities: [{'Nikkei', 'Jiji', 'Gendai_biz'}, {'Nikkan', 'Nhk', 'Mainichi', 'Asahi', 'Yomiuri', 'Tokyo'}, {'Moeruasia', 'Sankei', 'Zakzak', 'Anonymous', 'Share_News_Japan', 'Seijichishin'}]
# note : nodes in color gray are not in any community as it have no edges
# <ipython-input-11-567b23c626de>:109: DeprecationWarning: nx.nx_pydot.graphviz_layout depends on the pydot package, which hasknown issues and is not actively maintained. Consider usingnx.nx_agraph.graphviz_layout instead.
#
# See https://github.com/networkx/networkx/issues/5723
#   pos=nx.nx_pydot.graphviz_layout(H)
# /usr/local/lib/python3.8/dist-packages/networkx/drawing/nx_pylab.py:304: UserWarning:
#
# The connectionstyle keyword argument is not applicable when drawing edges
# with LineCollection.
#
# To make this warning go away, either specify `arrows=True` to
# force FancyArrowPatches or use the default value for connectionstyle.
# Note that using FancyArrowPatches may be slow for large graphs.
#
#   draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)

# %%
#セクション4.4 ② 重複なし
#グラフリスト Simpson係数の拡張

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['現代ビジネス', '沖縄タイムス', '毎日新聞', '朝日新聞', '時事ドットコム',  '日本経済新聞', '産経ニュース', '東京新聞', '読売新聞オンライン', 'zakzak', 'NHKニュース', 'しんぶん赤旗', '日刊ゲンダイ', 'アゴラ', 'アノニマス_ポスト', 'ハム速', '政治知新', 'litera', 'Share_News_Japan', 'もえるあじあ', 'BuzzFeed_Japan', 'Yahoo_ニュース']
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']
matrix_sk = [[0]*3 for i in range(len(sum_engname_list)**2)]

if data_import == 1:
  filename = 'Simpsonk_media.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_skt=[]
      for row in csvreader:
        a_b_skt += row
  a_b_sk = []
  for i in a_b_skt:
    a_b_sk.append(float(i))

if data_import == 0:
  a_b_sk = []
  for a in sum_list:
    for b in sum_list:
      if a == b:
        a_b_sk.append(1)
      else:
        a_b_sk.append(len(set(a) & set(b))/(len(a)-1))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        matrix_sk[i+k][n] = sum_engname_list[k//22]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        matrix_sk[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        t += 1
        matrix_sk[i+k][n] = a_b_sk[t]

print(matrix_sk)
# Out:
# [['Gendai_biz', 'Gendai_biz', 1.0], ['Gendai_biz', 'Okinawa', 0.04297077911918039], ['Gendai_biz', 'Mainichi', 0.2640831627895333], ['Gendai_biz', 'Asahi', 0.3180688809197474], ['Gendai_biz', 'Jiji', 0.12257248893812232], ['Gendai_biz', 'Nikkei', 0.5199364137611636], ['Gendai_biz', 'Sankei', 0.15755117878622882], ['Gendai_biz', 'Tokyo', 0.05262762621805824], ['Gendai_biz', 'Yomiuri', 0.2728387876056902], ['Gendai_biz', 'Zakzak', 0.06475031761826978], ['Gendai_biz', 'Nhk', 0.45450392094277864], ['Gendai_biz', 'Akahata', 0.0305226463390974], ['Gendai_biz', 'Nikkan', 0.11108190483343033], ['Gendai_biz', 'Agora', 0.05021810830939462], ['Gendai_biz', 'Anonymous', 0.028213264239624992], ['Gendai_biz', 'Hamusoku', 0.03653705337864479], ['Gendai_biz', 'Seijichishin', 0.019482673375765883], ['Gendai_biz', 'Litera', 0.06574541722210749], ['Gendai_biz', 'Share_News_Japan', 0.037306847411802256], ['Gendai_biz', 'Moeruasia', 0.006364882371716641], ['Gendai_biz', 'BuzzFeed_Japan', 0.04916668231288685], ['Gendai_biz', 'Yahoo_News', 0.20047814848888806], ['Okinawa', 'Gendai_biz', 0.055416552325299843], ['Okinawa', 'Okinawa', 1.0], ['Okinawa', 'Mainichi', 0.20134304024278035], ['Okinawa', 'Asahi', 0.22027797058871007], ['Okinawa', 'Jiji', 0.11218098758656314], ['Okinawa', 'Nikkei', 0.21859917028523462], ['Okinawa', 'Sankei', 0.1189769003535166], ['Okinawa', 'Tokyo', 0.09802418118129429], ['Okinawa', 'Yomiuri', 0.14793620558846793], ['Okinawa', 'Zakzak', 0.03945180713167283], ['Okinawa', 'Nhk', 0.2817721028588032], ['Okinawa', 'Akahata', 0.09963034108702319], ['Okinawa', 'Nikkan', 0.1468546707775751], ['Okinawa', 'Agora', 0.021009217259358504], ['Okinawa', 'Anonymous', 0.019693618944615732], ['Okinawa', 'Hamusoku', 0.02088814992978095], ['Okinawa', 'Seijichishin', 0.014996206557006569], ['Okinawa', 'Litera', 0.1301715927617879], ['Okinawa', 'Share_News_Japan', 0.02750649728002066], ['Okinawa', 'Moeruasia', 0.005149397084698704], ['Okinawa', 'BuzzFeed_Japan', 0.034770537054674006], ['Okinawa', 'Yahoo_News', 0.16806566691956287], ['Mainichi', 'Gendai_biz', 0.043866981041846], ['Mainichi', 'Okinawa', 0.025933873093892557], ['Mainichi', 'Mainichi', 1.0], ['Mainichi', 'Asahi', 0.5996956049850921], ['Mainichi', 'Jiji', 0.15196983495303085], ['Mainichi', 'Nikkei', 0.46454026788424674], ['Mainichi', 'Sankei', 0.220474307314213], ['Mainichi', 'Tokyo', 0.04059535839186284], ['Mainichi', 'Yomiuri', 0.410826191278168], ['Mainichi', 'Zakzak', 0.02419566112351701], ['Mainichi', 'Nhk', 0.5147529701385164], ['Mainichi', 'Akahata', 0.01913176727919926], ['Mainichi', 'Nikkan', 0.05758242992053294], ['Mainichi', 'Agora', 0.012055206942867717], ['Mainichi', 'Anonymous', 0.012078078153004237], ['Mainichi', 'Hamusoku', 0.019758646357032065], ['Mainichi', 'Seijichishin', 0.008657792637133697], ['Mainichi', 'Litera', 0.034445082066060374], ['Mainichi', 'Share_News_Japan', 0.02125047301820964], ['Mainichi', 'Moeruasia', 0.0026156347592493252], ['Mainichi', 'BuzzFeed_Japan', 0.01984077479343139], ['Mainichi', 'Yahoo_News', 0.1812148355144151], ['Asahi', 'Gendai_biz', 0.03852717074476109], ['Asahi', 'Okinawa', 0.020689534925150913], ['Asahi', 'Mainichi', 0.43730029314975655], ['Asahi', 'Asahi', 1.0], ['Asahi', 'Jiji', 0.11362339012114886], ['Asahi', 'Nikkei', 0.5170101908771068], ['Asahi', 'Sankei', 0.17259751000855872], ['Asahi', 'Tokyo', 0.039696130984193265], ['Asahi', 'Yomiuri', 0.38825248025010595], ['Asahi', 'Zakzak', 0.018775381485095], ['Asahi', 'Nhk', 0.5764672080878099], ['Asahi', 'Akahata', 0.015503505743597441], ['Asahi', 'Nikkan', 0.04497919447874759], ['Asahi', 'Agora', 0.010256072035848114], ['Asahi', 'Anonymous', 0.00961776819563937], ['Asahi', 'Hamusoku', 0.015838577355678517], ['Asahi', 'Seijichishin', 0.006984196294350556], ['Asahi', 'Litera', 0.027313642948599864], ['Asahi', 'Share_News_Japan', 0.016062211123922674], ['Asahi', 'Moeruasia', 0.0021279321608859234], ['Asahi', 'BuzzFeed_Japan', 0.016015968209133202], ['Asahi', 'Yahoo_News', 0.146630976233 ...

# %%
import csv
f = open('Simpsonk_media.csv', 'w')
data = a_b_sk
writer = csv.writer(f)
writer.writerow(data)
f.close()

# %%
#セクション4.3.3
#グラフリスト 
Simpson係数の拡張 = 0.25

matrix_consk = []
for i in range(len(matrix_sk)):
  if matrix_sk[i][2] >= Simpson係数の拡張 and matrix_sk[i][2] != 1:
    matrix_consk.append(matrix_sk[i])

H = nx.DiGraph()
for n in sum_engname_list:
    H.add_node(n)
size =[((len(i)-1)/800) for i in sum_list]
H.add_weighted_edges_from(matrix_consk)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]
#pos = nx.spring_layout(H, k=2) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(18,12))
plt.title('Enhanced Simpson index Threshold:{}'.format(Simpson係数の拡張))
nx.write_gexf(H, f'media.gexf')
nx.draw_networkx(H, pos,node_size = size, arrows=True, width=[v['weight'] * 7 for v in H.edges.values()], connectionstyle="arc3, rad=0.1")
# Out:
# <ipython-input-4-5c8d743a722a>:17: DeprecationWarning: nx.nx_pydot.graphviz_layout depends on the pydot package, which hasknown issues and is not actively maintained. Consider usingnx.nx_agraph.graphviz_layout instead.
#
# See https://github.com/networkx/networkx/issues/5723
#   pos=nx.nx_pydot.graphviz_layout(H)

# %% [markdown]
# - draw_circular 頂点を円周上に配置
# - draw_kamada_kawai 頂点を力学モデルにより配置
# - draw_random 頂点をランダムに配置
# - draw_spectral ネットワークを表す行列の固有ベクトルにより、頂点を配置
# - draw_spring 頂点を力学モデルにより配置
# - draw_shell 頂点を同心円上に配置

# %%
#セクション4.4 ②
#グラフリスト Simpson係数の拡張2nd 重み付き有向グラフを重み付き無向グラフに変換

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_sk2 = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Simpsonk2_media.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_sk2t=[]
      for row in csvreader:
        a_b_sk2t += row
  a_b_sk2 = []
  for i in a_b_sk2t:
    a_b_sk2.append(float(i))

if data_import == 0:
  a_b_sk2 = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_sk2.append(((len(set(a) & set(b))/(len(a)-1))+((len(set(a) & set(b)))/(len(b)-1)))/2)


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_sk2[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_sk2[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_sk2[e][2] = a_b_sk2[e]
      
print(matrix_sk2)
# Out:
# [['Gendai_biz', 'Okinawa', 0.04919366572224011], ['Gendai_biz', 'Mainichi', 0.15397507191568965], ['Gendai_biz', 'Asahi', 0.17829802583225424], ['Gendai_biz', 'Jiji', 0.09067805828238826], ['Gendai_biz', 'Nikkei', 0.2718263414721294], ['Gendai_biz', 'Sankei', 0.09792653910494488], ['Gendai_biz', 'Tokyo', 0.07035936193678582], ['Gendai_biz', 'Yomiuri', 0.16307964333715452], ['Gendai_biz', 'Zakzak', 0.10411676144969184], ['Gendai_biz', 'Nhk', 0.23795412200679922], ['Gendai_biz', 'Akahata', 0.06205925818787637], ['Gendai_biz', 'Nikkan', 0.12577338540526367], ['Gendai_biz', 'Agora', 0.11721401524195826], ['Gendai_biz', 'Anonymous', 0.033023963215070576], ['Gendai_biz', 'Hamusoku', 0.025848100529795606], ['Gendai_biz', 'Seijichishin', 0.03289630314181847], ['Gendai_biz', 'Litera', 0.08236110086250471], ['Gendai_biz', 'Share_News_Japan', 0.04057886030199641], ['Gendai_biz', 'Moeruasia', 0.024147190722036426], ['Gendai_biz', 'BuzzFeed_Japan', 0.04553792710598811], ['Gendai_biz', 'Yahoo_News', 0.11388119109145539], ['Okinawa', 'Mainichi', 0.11363845666833645], ['Okinawa', 'Asahi', 0.12048375275693049], ['Okinawa', 'Jiji', 0.07694915195980867], ['Okinawa', 'Nikkei', 0.11316546519699427], ['Okinawa', 'Sankei', 0.07070256591927411], ['Okinawa', 'Tokyo', 0.11262645502317245], ['Okinawa', 'Yomiuri', 0.08517708808416073], ['Okinawa', 'Zakzak', 0.05362044770918094], ['Okinawa', 'Nhk', 0.14603081694622427], ['Okinawa', 'Akahata', 0.16826374751013795], ['Okinawa', 'Nikkan', 0.14542458133090486], ['Okinawa', 'Agora', 0.04038362329943751], ['Okinawa', 'Anonymous', 0.020086003765215965], ['Okinawa', 'Hamusoku', 0.013804119003798434], ['Okinawa', 'Seijichishin', 0.021318189263537724], ['Okinawa', 'Litera', 0.14106378688364513], ['Okinawa', 'Share_News_Japan', 0.026288374947591727], ['Okinawa', 'Moeruasia', 0.015726625979991075], ['Okinawa', 'BuzzFeed_Japan', 0.028876148908019095], ['Okinawa', 'Yahoo_News', 0.09290086951963589], ['Mainichi', 'Asahi', 0.5184979490674243], ['Mainichi', 'Jiji', 0.2953632547267563], ['Mainichi', 'Nikkei', 0.29605130263574597], ['Mainichi', 'Sankei', 0.2715725318682036], ['Mainichi', 'Tokyo', 0.22483265793003437], ['Mainichi', 'Yomiuri', 0.44708111789438393], ['Mainichi', 'Zakzak', 0.17348523244232322], ['Mainichi', 'Nhk', 0.330345031425053], ['Mainichi', 'Akahata', 0.18615444179877208], ['Mainichi', 'Nikkan', 0.24796436447870202], ['Mainichi', 'Agora', 0.13913442410551635], ['Mainichi', 'Anonymous', 0.05479271091871781], ['Mainichi', 'Hamusoku', 0.03455513345806962], ['Mainichi', 'Seijichishin', 0.06627382424287621], ['Mainichi', 'Litera', 0.17331001370959612], ['Mainichi', 'Share_News_Japan', 0.08581024732285815], ['Mainichi', 'Moeruasia', 0.05317341210236224], ['Mainichi', 'BuzzFeed_Japan', 0.06082648119089344], ['Mainichi', 'Yahoo_News', 0.1648428834281171], ['Asahi', 'Jiji', 0.28174573793945645], ['Asahi', 'Nikkei', 0.35585136375951903], ['Asahi', 'Sankei', 0.2595024881233874], ['Asahi', 'Tokyo', 0.2941257582994045], ['Asahi', 'Yomiuri', 0.507329591874007], ['Asahi', 'Zakzak', 0.18112790653596275], ['Asahi', 'Nhk', 0.400296679921349], ['Asahi', 'Akahata', 0.20399218122115678], ['Asahi', 'Nikkan', 0.257269074759772], ['Asahi', 'Agora', 0.16042315298571486], ['Asahi', 'Anonymous', 0.05804849802983815], ['Asahi', 'Hamusoku', 0.035045022876024734], ['Asahi', 'Seijichishin', 0.07201979038620773], ['Asahi', 'Litera', 0.18339187838241783], ['Asahi', 'Share_News_Japan', 0.08596369247658418], ['Asahi', 'Moeruasia', 0.058928323944800826], ['Asahi', 'BuzzFeed_Japan', 0.06436077653786988], ['Asahi', 'Yahoo_News', 0.15569031435890596], ['Jiji', 'Nikkei', 0.32041535986264214], ['Jiji', 'Sankei', 0.3741156556679045], ['Jiji', 'Tokyo', 0.17325034523055788], ['Jiji', 'Yomiuri', 0.29963460114562424], ['Jiji', 'Zakzak', 0.14007948973610415], ['Jiji', 'Nhk', 0.33626161699011964], ['Jiji', 'Akahata', 0.11371560588039653], ['Jiji', 'Nikkan', 0.18661549760374213], ['Jiji', 'Agora', 0.10047365104731577], ['Jiji', 'Anonymous', 0.0933758289 ...

# %%
sum_engname_list1 = [['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News'],['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa'],['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']]
color_list10 = ['salmon', 'turquoise', 'burlywood', 'yellow', 'lavender', 'coral', 'red', 'lightcoral', 'blue', 'lime', 'lightyellow', 'bisque', 'aqua', 'olive', 'fuchsia', 'lightskyblue', 'chocolate', 'sateblue', 'palegreen', 'grey']
# color_list10 = ['turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise', 'turquoise']
# color_list10 = ['blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue']

#セクション4.2.1 
#グラフリスト 
#Simpson係数の拡張2

#community detection   on → 1, off → 0
sign1 = 0
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 1

Simpson係数の拡張2 = 0.25

matrix_consk2 = []
for i in range(len(matrix_sk2)):
  if matrix_sk2[i][2] >= Simpson係数の拡張2 and matrix_sk2[i][2] != 1:
    matrix_consk2.append(matrix_sk2[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_consk2) #ここに三次元リストを入れて実行！
    
  if _DEBUG_:
    print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)      
                                                                                                              #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_consk2)):
    node_list_del.append(matrix_consk2[i][0])
    node_list_del.append(matrix_consk2[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/450)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/450) for i in sum_list]

H.add_weighted_edges_from(matrix_consk2)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = media, BLUE = political party, LIME = politician')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(18,12))
nx.write_gexf(H, f'mediak2.gexf')
plt.title('Enhanced Simpson index 2nd Threshold:{}'.format(Simpson係数の拡張2))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# note : RED = media, BLUE = political party, LIME = politician
# <ipython-input-7-0076e3302bbf>:117: DeprecationWarning: nx.nx_pydot.graphviz_layout depends on the pydot package, which hasknown issues and is not actively maintained. Consider usingnx.nx_agraph.graphviz_layout instead.
#
# See https://github.com/networkx/networkx/issues/5723
#   pos=nx.nx_pydot.graphviz_layout(H)
# /usr/local/lib/python3.9/dist-packages/networkx/drawing/nx_pylab.py:304: UserWarning:
#
# The connectionstyle keyword argument is not applicable when drawing edges
# with LineCollection.
#
# To make this warning go away, either specify `arrows=True` to
# force FancyArrowPatches or use the default value for connectionstyle.
# Note that using FancyArrowPatches may be slow for large graphs.
#
#   draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
