# %%
#セクション2 ①
import csv

filename = '1.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    現代ビジネス_lists=[]
    for row in csvreader:
      現代ビジネス_lists += row

    print('データ取得終了時刻：', 現代ビジネス_lists[-2])
    del 現代ビジネス_lists[-1]
    del 現代ビジネス_lists[-1]

    unique_set = set(現代ビジネス_lists)
    現代ビジネス_list = list(unique_set)
    現代ビジネス_list.append('現代ビジネス')

    print('現代ビジネスのフォロワー数：', len(現代ビジネス_list)-1)
    print('\n')

filename = '2.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    沖縄タイムス_lists=[]
    for row in csvreader:
      沖縄タイムス_lists += row

    print('データ取得終了時刻：', 沖縄タイムス_lists[-2])
    del 沖縄タイムス_lists[-1]
    del 沖縄タイムス_lists[-1]

    unique_set = set(沖縄タイムス_lists)
    沖縄タイムス_list = list(unique_set)
    沖縄タイムス_list.append('沖縄タイムス')
        
    print('沖縄タイムスのフォロワー数：', len(沖縄タイムス_list)-1)
    print('\n')
    
filename = '3.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    毎日新聞_lists=[]
    for row in csvreader:
      毎日新聞_lists += row

    print('データ取得終了時刻：', 毎日新聞_lists[-2])
    del 毎日新聞_lists[-1]
    del 毎日新聞_lists[-1]

    unique_set = set(毎日新聞_lists)
    毎日新聞_list = list(unique_set)
    毎日新聞_list.append('毎日新聞')
        
    print('毎日新聞のフォロワー数：', len(毎日新聞_list)-1)
    print('\n')
    
filename = '4.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    朝日新聞_lists=[]
    for row in csvreader:
      朝日新聞_lists += row

    print('データ取得終了時刻：', 朝日新聞_lists[-2])
    del 朝日新聞_lists[-1]
    del 朝日新聞_lists[-1]

    unique_set = set(朝日新聞_lists)
    朝日新聞_list = list(unique_set)
    朝日新聞_list.append('朝日新聞')
        
    print('朝日新聞のフォロワー数：', len(朝日新聞_list)-1)
    print('\n')
    
filename = '5.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    時事ドットコム_lists=[]
    for row in csvreader:
      時事ドットコム_lists += row

    print('データ取得終了時刻：', 時事ドットコム_lists[-2])
    del 時事ドットコム_lists[-1]
    del 時事ドットコム_lists[-1]

    unique_set = set(時事ドットコム_lists)
    時事ドットコム_list = list(unique_set)
    時事ドットコム_list.append('時事ドットコム')
        
    print('時事ドットコムのフォロワー数：', len(時事ドットコム_list)-1)
    print('\n')
    
filename = '6.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本経済新聞_lists=[]
    for row in csvreader:
      日本経済新聞_lists += row

    print('データ取得終了時刻：', 日本経済新聞_lists[-2])
    del 日本経済新聞_lists[-1]
    del 日本経済新聞_lists[-1]

    unique_set = set(日本経済新聞_lists)
    日本経済新聞_list = list(unique_set)
    日本経済新聞_list.append('日本経済新聞')
        
    print('日本経済新聞のフォロワー数：', len(日本経済新聞_list)-1)
    print('\n')
    
filename = '7.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    産経ニュース_lists=[]
    for row in csvreader:
      産経ニュース_lists += row

    print('データ取得終了時刻：', 産経ニュース_lists[-2])
    del 産経ニュース_lists[-1]
    del 産経ニュース_lists[-1]

    unique_set = set(産経ニュース_lists)
    産経ニュース_list = list(unique_set)
    産経ニュース_list.append('産経ニュース')
        
    print('産経ニュースのフォロワー数：', len(産経ニュース_list)-1)
    print('\n')
    
filename = '8.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    東京新聞_lists=[]
    for row in csvreader:
      東京新聞_lists += row

    print('データ取得終了時刻：', 東京新聞_lists[-2])
    del 東京新聞_lists[-1]
    del 東京新聞_lists[-1]

    unique_set = set(東京新聞_lists)
    東京新聞_list = list(unique_set)
    東京新聞_list.append('東京新聞')
        
    print('東京新聞のフォロワー数：', len(東京新聞_list)-1)
    print('\n')
    
filename = '9.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    読売新聞オンライン_lists=[]
    for row in csvreader:
      読売新聞オンライン_lists += row

    print('データ取得終了時刻：', 読売新聞オンライン_lists[-2])
    del 読売新聞オンライン_lists[-1]
    del 読売新聞オンライン_lists[-1]

    unique_set = set(読売新聞オンライン_lists)
    読売新聞オンライン_list = list(unique_set)
    読売新聞オンライン_list.append('読売新聞オンライン')
        
    print('読売新聞オンラインのフォロワー数：', len(読売新聞オンライン_list)-1)
    print('\n')
    
filename = '10.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    zakzak_lists=[]
    for row in csvreader:
      zakzak_lists += row

    print('データ取得終了時刻：', zakzak_lists[-2])
    del zakzak_lists[-1]
    del zakzak_lists[-1]

    unique_set = set(zakzak_lists)
    zakzak_list = list(unique_set)
    zakzak_list.append('zakzak')
        
    print('zakzakのフォロワー数：', len(zakzak_list)-1)
    print('\n')
    
filename = '11.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    NHKニュース_lists=[]
    for row in csvreader:
      NHKニュース_lists += row

    print('データ取得終了時刻：', NHKニュース_lists[-2])
    del NHKニュース_lists[-1]
    del NHKニュース_lists[-1]

    unique_set = set(NHKニュース_lists)
    NHKニュース_list = list(unique_set)
    NHKニュース_list.append('NHKニュース')
        
    print('NHKニュースのフォロワー数：', len(NHKニュース_list)-1)
    print('\n')
    
filename = '12.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    しんぶん赤旗_lists=[]
    for row in csvreader:
      しんぶん赤旗_lists += row

    print('データ取得終了時刻：', しんぶん赤旗_lists[-2])
    del しんぶん赤旗_lists[-1]
    del しんぶん赤旗_lists[-1]

    unique_set = set(しんぶん赤旗_lists)
    しんぶん赤旗_list = list(unique_set)
    しんぶん赤旗_list.append('しんぶん赤旗')
        
    print('しんぶん赤旗のフォロワー数：', len(しんぶん赤旗_list)-1)
    print('\n')
    
filename = '13.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日刊ゲンダイ_lists=[]
    for row in csvreader:
      日刊ゲンダイ_lists += row

    print('データ取得終了時刻：', 日刊ゲンダイ_lists[-2])
    del 日刊ゲンダイ_lists[-1]
    del 日刊ゲンダイ_lists[-1]

    unique_set = set(日刊ゲンダイ_lists)
    日刊ゲンダイ_list = list(unique_set)
    日刊ゲンダイ_list.append('日刊ゲンダイ')
        
    print('日刊ゲンダイのフォロワー数：', len(日刊ゲンダイ_list)-1)
    print('\n')
    
filename = '14.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    アゴラ_lists=[]
    for row in csvreader:
      アゴラ_lists += row

    print('データ取得終了時刻：', アゴラ_lists[-2])
    del アゴラ_lists[-1]
    del アゴラ_lists[-1]

    unique_set = set(アゴラ_lists)
    アゴラ_list = list(unique_set)
    アゴラ_list.append('アゴラ')
        
    print('アゴラのフォロワー数：', len(アゴラ_list)-1)
    print('\n')
    
filename = '15.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    アノニマス_ポスト_lists=[]
    for row in csvreader:
      アノニマス_ポスト_lists += row

    print('データ取得終了時刻：', アノニマス_ポスト_lists[-2])
    del アノニマス_ポスト_lists[-1]
    del アノニマス_ポスト_lists[-1]

    unique_set = set(アノニマス_ポスト_lists)
    アノニマス_ポスト_list = list(unique_set)
    アノニマス_ポスト_list.append('アノニマス_ポスト')
        
    print('アノニマス_ポストのフォロワー数：', len(アノニマス_ポスト_list)-1)
    print('\n')
    
filename = '16.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    ハム速_lists=[]
    for row in csvreader:
      ハム速_lists += row

    print('データ取得終了時刻：', ハム速_lists[-2])
    del ハム速_lists[-1]
    del ハム速_lists[-1]

    unique_set = set(ハム速_lists)
    ハム速_list = list(unique_set)
    ハム速_list.append('ハム速')
        
    print('ハム速のフォロワー数：', len(ハム速_list)-1)
    print('\n')
    
filename = '17.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    政治知新_lists=[]
    for row in csvreader:
      政治知新_lists += row

    print('データ取得終了時刻：', 政治知新_lists[-2])
    del 政治知新_lists[-1]
    del 政治知新_lists[-1]

    unique_set = set(政治知新_lists)
    政治知新_list = list(unique_set)
    政治知新_list.append('政治知新')
        
    print('政治知新のフォロワー数：', len(政治知新_list)-1)
    print('\n')
    
filename = '18.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    litera_lists=[]
    for row in csvreader:
      litera_lists += row

    print('データ取得終了時刻：', litera_lists[-2])
    del litera_lists[-1]
    del litera_lists[-1]

    unique_set = set(litera_lists)
    litera_list = list(unique_set)
    litera_list.append('litera')
        
    print('literaのフォロワー数：', len(litera_list)-1)
    print('\n')
    
filename = '19.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    Share_News_Japan_lists=[]
    for row in csvreader:
      Share_News_Japan_lists += row

    print('データ取得終了時刻：', Share_News_Japan_lists[-2])
    del Share_News_Japan_lists[-1]
    del Share_News_Japan_lists[-1]

    unique_set = set(Share_News_Japan_lists)
    Share_News_Japan_list = list(unique_set)
    Share_News_Japan_list.append('Share_News_Japan')
        
    print('Share_News_Japanのフォロワー数：', len(Share_News_Japan_list)-1)
    print('\n')
    
filename = '20.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    もえるあじあ_lists=[]
    for row in csvreader:
      もえるあじあ_lists += row

    print('データ取得終了時刻：', もえるあじあ_lists[-2])
    del もえるあじあ_lists[-1]
    del もえるあじあ_lists[-1]

    unique_set = set(もえるあじあ_lists)
    もえるあじあ_list = list(unique_set)
    もえるあじあ_list.append('もえるあじあ')
        
    print('もえるあじあのフォロワー数：', len(もえるあじあ_list)-1)
    print('\n')
    
filename = '21.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    BuzzFeed_Japan_lists=[]
    for row in csvreader:
      BuzzFeed_Japan_lists += row

    print('データ取得終了時刻：', BuzzFeed_Japan_lists[-2])
    del BuzzFeed_Japan_lists[-1]
    del BuzzFeed_Japan_lists[-1]

    unique_set = set(BuzzFeed_Japan_lists)
    BuzzFeed_Japan_list = list(unique_set)
    BuzzFeed_Japan_list.append('BuzzFeed_Japan')
        
    print('BuzzFeed_Japanのフォロワー数：', len(BuzzFeed_Japan_list)-1)
    print('\n')
    
filename = '22.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    Yahoo_ニュース_lists=[]
    for row in csvreader:
      Yahoo_ニュース_lists += row

    print('データ取得終了時刻：', Yahoo_ニュース_lists[-2])
    del Yahoo_ニュース_lists[-1]
    del Yahoo_ニュース_lists[-1]

    unique_set = set(Yahoo_ニュース_lists)
    Yahoo_ニュース_list = list(unique_set)
    Yahoo_ニュース_list.append('Yahoo_ニュース')
        
    print('Yahoo_ニュースのフォロワー数：', len(Yahoo_ニュース_list)-1)
    print('\n')

sum_list = [現代ビジネス_list, 沖縄タイムス_list, 毎日新聞_list, 朝日新聞_list, 時事ドットコム_list, 日本経済新聞_list, 産経ニュース_list, 東京新聞_list, 読売新聞オンライン_list, zakzak_list, NHKニュース_list, しんぶん赤旗_list, 日刊ゲンダイ_list, アゴラ_list, アノニマス_ポスト_list, ハム速_list, 政治知新_list, litera_list, Share_News_Japan_list, もえるあじあ_list, BuzzFeed_Japan_list, Yahoo_ニュース_list]
# Out:
# データ取得終了時刻： 2022-04-21T18:41:46
# 現代ビジネスのフォロワー数： 159783
#
#
# データ取得終了時刻： 2022-04-21T18:56:54
# 沖縄タイムスのフォロワー数： 123898
#
#
# データ取得終了時刻： 2022-04-22T23:10:38
# 毎日新聞のフォロワー数： 961908
#
#
# データ取得終了時刻： 2022-04-24T15:42:25
# 朝日新聞のフォロワー数： 1319121
#
#
# データ取得終了時刻： 2022-04-22T08:29:02
# 時事ドットコムのフォロワー数： 333171
#
#
# データ取得終了時刻： 2022-04-26T04:51:54
# 日本経済新聞のフォロワー数： 3502954
#
#
# データ取得終了時刻： 2022-04-24T01:32:45
# 産経ニュースのフォロワー数： 657252
#
#
# データ取得終了時刻： 2022-04-22T16:12:21
# 東京新聞のフォロワー数： 95458
#
#
# データ取得終了時刻： 2022-04-23T21:16:17
# 読売新聞オンラインのフォロワー数： 817603
#
#
# データ取得終了時刻： 2022-04-21T23:06:11
# zakzakのフォロワー数： 72106
#
#
# データ取得終了時刻： 2022-04-27T10:29:08
# NHKニュースのフォロワー数： 3392866
#
#
# データ取得終了時刻： 2022-04-21T23:21:15
# しんぶん赤旗のフォロワー数： 52107
#
#
# データ取得終了時刻： 2022-04-21T23:51:22
# 日刊ゲンダイのフォロワー数： 126359
#
#
# データ取得終了時刻： 2022-04-22T00:06:26
# アゴラのフォロワー数： 43559
#
#
# データ取得終了時刻： 2022-04-22T00:21:32
# アノニマス_ポストのフォロワー数： 119150
#
#
# データ取得終了時刻： 2022-04-22T18:17:41
# ハム速のフォロワー数： 385114
#
#
# データ取得終了時刻： 2022-04-22T09:37:45
# 政治知新のフォロワー数： 67221
#
#
# データ取得終了時刻： 2022-04-22T10:07:54
# literaのフォロワー数： 106136
#
#
# データ取得終了時刻： 2022-04-22T10:38:05
# Share_News_Japanのフォロワー数： 135938
#
#
# データ取得終了時刻： 2022-04-22T10:38:06
# もえるあじあのフォロワー数： 24255
#
#
# データ取得終了時刻： 2022-04-23T14:28:59
# BuzzFeed_Japanのフォロワー数： 187453
#
#
# データ取得終了時刻： 2022-04-23T18:30:20
# Yahoo_ニュースのフォロワー数： 1174048

# %%
#セクション4.4 ②
#グラフリスト Simpson係数の拡張

import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['現代ビジネス', '沖縄タイムス', '毎日新聞', '朝日新聞', '時事ドットコム',  '日本経済新聞', '産経ニュース', '東京新聞', '読売新聞オンライン', 'zakzak', 'NHKニュース', 'しんぶん赤旗', '日刊ゲンダイ', 'アゴラ', 'アノニマス_ポスト', 'ハム速', '政治知新', 'litera', 'Share_News_Japan', 'もえるあじあ', 'BuzzFeed_Japan', 'Yahoo_ニュース']
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']
matrix_sk = [[0]*3 for i in range(len(sum_engname_list)**2)]

a_b_ = []

for a in sum_list:
  for b in sum_list:
    if a == b:
      a_b_.append(1)
    else:
      a_b_.append(len(set(a) & set(b))/(len(a)-1))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        matrix_sk[i+k][n] = sum_engname_list[k//22]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        matrix_sk[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        t += 1
        matrix_sk[i+k][n] = round(a_b_[t], 4)

print(matrix_sk)
# Out:
# [['Gendai_biz', 'Gendai_biz', 1], ['Gendai_biz', 'Okinawa', 0.043], ['Gendai_biz', 'Mainichi', 0.2641], ['Gendai_biz', 'Asahi', 0.3181], ['Gendai_biz', 'Jiji', 0.1226], ['Gendai_biz', 'Nikkei', 0.5199], ['Gendai_biz', 'Sankei', 0.1576], ['Gendai_biz', 'Tokyo', 0.0526], ['Gendai_biz', 'Yomiuri', 0.2728], ['Gendai_biz', 'Zakzak', 0.0648], ['Gendai_biz', 'Nhk', 0.4545], ['Gendai_biz', 'Akahata', 0.0305], ['Gendai_biz', 'Nikkan', 0.1111], ['Gendai_biz', 'Agora', 0.0502], ['Gendai_biz', 'Anonymous', 0.0282], ['Gendai_biz', 'Hamusoku', 0.0365], ['Gendai_biz', 'Seijichishin', 0.0195], ['Gendai_biz', 'Litera', 0.0657], ['Gendai_biz', 'Share_News_Japan', 0.0373], ['Gendai_biz', 'Moeruasia', 0.0064], ['Gendai_biz', 'BuzzFeed_Japan', 0.0492], ['Gendai_biz', 'Yahoo_News', 0.2005], ['Okinawa', 'Gendai_biz', 0.0554], ['Okinawa', 'Okinawa', 1], ['Okinawa', 'Mainichi', 0.2013], ['Okinawa', 'Asahi', 0.2203], ['Okinawa', 'Jiji', 0.1122], ['Okinawa', 'Nikkei', 0.2186], ['Okinawa', 'Sankei', 0.119], ['Okinawa', 'Tokyo', 0.098], ['Okinawa', 'Yomiuri', 0.1479], ['Okinawa', 'Zakzak', 0.0395], ['Okinawa', 'Nhk', 0.2818], ['Okinawa', 'Akahata', 0.0996], ['Okinawa', 'Nikkan', 0.1469], ['Okinawa', 'Agora', 0.021], ['Okinawa', 'Anonymous', 0.0197], ['Okinawa', 'Hamusoku', 0.0209], ['Okinawa', 'Seijichishin', 0.015], ['Okinawa', 'Litera', 0.1302], ['Okinawa', 'Share_News_Japan', 0.0275], ['Okinawa', 'Moeruasia', 0.0051], ['Okinawa', 'BuzzFeed_Japan', 0.0348], ['Okinawa', 'Yahoo_News', 0.1681], ['Mainichi', 'Gendai_biz', 0.0439], ['Mainichi', 'Okinawa', 0.0259], ['Mainichi', 'Mainichi', 1], ['Mainichi', 'Asahi', 0.5997], ['Mainichi', 'Jiji', 0.152], ['Mainichi', 'Nikkei', 0.4645], ['Mainichi', 'Sankei', 0.2205], ['Mainichi', 'Tokyo', 0.0406], ['Mainichi', 'Yomiuri', 0.4108], ['Mainichi', 'Zakzak', 0.0242], ['Mainichi', 'Nhk', 0.5148], ['Mainichi', 'Akahata', 0.0191], ['Mainichi', 'Nikkan', 0.0576], ['Mainichi', 'Agora', 0.0121], ['Mainichi', 'Anonymous', 0.0121], ['Mainichi', 'Hamusoku', 0.0198], ['Mainichi', 'Seijichishin', 0.0087], ['Mainichi', 'Litera', 0.0344], ['Mainichi', 'Share_News_Japan', 0.0213], ['Mainichi', 'Moeruasia', 0.0026], ['Mainichi', 'BuzzFeed_Japan', 0.0198], ['Mainichi', 'Yahoo_News', 0.1812], ['Asahi', 'Gendai_biz', 0.0385], ['Asahi', 'Okinawa', 0.0207], ['Asahi', 'Mainichi', 0.4373], ['Asahi', 'Asahi', 1], ['Asahi', 'Jiji', 0.1136], ['Asahi', 'Nikkei', 0.517], ['Asahi', 'Sankei', 0.1726], ['Asahi', 'Tokyo', 0.0397], ['Asahi', 'Yomiuri', 0.3883], ['Asahi', 'Zakzak', 0.0188], ['Asahi', 'Nhk', 0.5765], ['Asahi', 'Akahata', 0.0155], ['Asahi', 'Nikkan', 0.045], ['Asahi', 'Agora', 0.0103], ['Asahi', 'Anonymous', 0.0096], ['Asahi', 'Hamusoku', 0.0158], ['Asahi', 'Seijichishin', 0.007], ['Asahi', 'Litera', 0.0273], ['Asahi', 'Share_News_Japan', 0.0161], ['Asahi', 'Moeruasia', 0.0021], ['Asahi', 'BuzzFeed_Japan', 0.016], ['Asahi', 'Yahoo_News', 0.1466], ['Jiji', 'Gendai_biz', 0.0588], ['Jiji', 'Okinawa', 0.0417], ['Jiji', 'Mainichi', 0.4388], ['Jiji', 'Asahi', 0.4499], ['Jiji', 'Jiji', 1], ['Jiji', 'Nikkei', 0.5852], ['Jiji', 'Sankei', 0.4965], ['Jiji', 'Tokyo', 0.0772], ['Jiji', 'Yomiuri', 0.4258], ['Jiji', 'Zakzak', 0.0498], ['Jiji', 'Nhk', 0.6124], ['Jiji', 'Akahata', 0.0308], ['Jiji', 'Nikkan', 0.1026], ['Jiji', 'Agora', 0.0232], ['Jiji', 'Anonymous', 0.0492], ['Jiji', 'Hamusoku', 0.024], ['Jiji', 'Seijichishin', 0.033], ['Jiji', 'Litera', 0.0612], ['Jiji', 'Share_News_Japan', 0.0776], ['Jiji', 'Moeruasia', 0.012], ['Jiji', 'BuzzFeed_Japan', 0.0422], ['Jiji', 'Yahoo_News', 0.3619], ['Nikkei', 'Gendai_biz', 0.0237], ['Nikkei', 'Okinawa', 0.0077], ['Nikkei', 'Mainichi', 0.1276], ['Nikkei', 'Asahi', 0.1947], ['Nikkei', 'Jiji', 0.0557], ['Nikkei', 'Nikkei', 1], ['Nikkei', 'Sankei', 0.0888], ['Nikkei', 'Tokyo', 0.0135], ['Nikkei', 'Yomiuri', 0.1554], ['Nikkei', 'Zakzak', 0.0091], ['Nikkei', 'Nhk', 0.4357], ['Nikkei', 'Akahata', 0.0045], ['Nikkei', 'Nikkan', 0.0166], ['Nikkei', 'Agora', 0.0057], ['Nikkei', 'Anonymous', 0.0072], ['Nikkei', 'Ham ...

# %%
#セクション4.4 ②
#グラフリスト Simpson係数の拡張2nd 重み付き有向グラフを重み付き無向グラフに変換

import networkx as nx
import matplotlib.pyplot as plt
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']
matrix_sk = [[0]*3 for i in range(len(sum_engname_list)**2)]

a_b_ = []

for a in sum_list:
  for b in sum_list:
    if a == b:
      a_b_.append(1)
    else:
      a_b_.append(((len(set(a) & set(b))/(len(a)-1))+((len(set(a) & set(b)))/(len(b)-1)))/2)

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        matrix_sk[i+k][n] = sum_engname_list[k//22]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        matrix_sk[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 22):
      t += 1
      s = -1
      for i in range(22):
        s += 1
        if t <= s:
          matrix_sk[i+k][n] = round(100*a_b_[i+k], 4)
        else:
          matrix_sk[i+k][n] = 1

matrix_con = []
for i in range(len(matrix_sk)):
  if matrix_sk[i][2] != 1:
    matrix_con.append(matrix_sk[i])
  
print(matrix_con)
# Out:
# [['Gendai_biz', 'Gendai_biz', 100], ['Gendai_biz', 'Okinawa', 4.9194], ['Gendai_biz', 'Mainichi', 15.3975], ['Gendai_biz', 'Asahi', 17.8298], ['Gendai_biz', 'Jiji', 9.0678], ['Gendai_biz', 'Nikkei', 27.1826], ['Gendai_biz', 'Sankei', 9.7927], ['Gendai_biz', 'Tokyo', 7.0359], ['Gendai_biz', 'Yomiuri', 16.308], ['Gendai_biz', 'Zakzak', 10.4117], ['Gendai_biz', 'Nhk', 23.7954], ['Gendai_biz', 'Akahata', 6.2059], ['Gendai_biz', 'Nikkan', 12.5773], ['Gendai_biz', 'Agora', 11.7214], ['Gendai_biz', 'Anonymous', 3.3024], ['Gendai_biz', 'Hamusoku', 2.5848], ['Gendai_biz', 'Seijichishin', 3.2896], ['Gendai_biz', 'Litera', 8.2361], ['Gendai_biz', 'Share_News_Japan', 4.0579], ['Gendai_biz', 'Moeruasia', 2.4147], ['Gendai_biz', 'BuzzFeed_Japan', 4.5538], ['Gendai_biz', 'Yahoo_News', 11.3881], ['Okinawa', 'Okinawa', 100], ['Okinawa', 'Mainichi', 11.3638], ['Okinawa', 'Asahi', 12.0484], ['Okinawa', 'Jiji', 7.6949], ['Okinawa', 'Nikkei', 11.3165], ['Okinawa', 'Sankei', 7.0703], ['Okinawa', 'Tokyo', 11.2626], ['Okinawa', 'Yomiuri', 8.5177], ['Okinawa', 'Zakzak', 5.362], ['Okinawa', 'Nhk', 14.6031], ['Okinawa', 'Akahata', 16.8264], ['Okinawa', 'Nikkan', 14.5425], ['Okinawa', 'Agora', 4.0384], ['Okinawa', 'Anonymous', 2.0086], ['Okinawa', 'Hamusoku', 1.3804], ['Okinawa', 'Seijichishin', 2.1318], ['Okinawa', 'Litera', 14.1064], ['Okinawa', 'Share_News_Japan', 2.6288], ['Okinawa', 'Moeruasia', 1.5727], ['Okinawa', 'BuzzFeed_Japan', 2.8876], ['Okinawa', 'Yahoo_News', 9.2901], ['Mainichi', 'Mainichi', 100], ['Mainichi', 'Asahi', 51.8498], ['Mainichi', 'Jiji', 29.5363], ['Mainichi', 'Nikkei', 29.6051], ['Mainichi', 'Sankei', 27.1573], ['Mainichi', 'Tokyo', 22.4833], ['Mainichi', 'Yomiuri', 44.7081], ['Mainichi', 'Zakzak', 17.3485], ['Mainichi', 'Nhk', 33.0345], ['Mainichi', 'Akahata', 18.6154], ['Mainichi', 'Nikkan', 24.7964], ['Mainichi', 'Agora', 13.9134], ['Mainichi', 'Anonymous', 5.4793], ['Mainichi', 'Hamusoku', 3.4555], ['Mainichi', 'Seijichishin', 6.6274], ['Mainichi', 'Litera', 17.331], ['Mainichi', 'Share_News_Japan', 8.581], ['Mainichi', 'Moeruasia', 5.3173], ['Mainichi', 'BuzzFeed_Japan', 6.0826], ['Mainichi', 'Yahoo_News', 16.4843], ['Asahi', 'Asahi', 100], ['Asahi', 'Jiji', 28.1746], ['Asahi', 'Nikkei', 35.5851], ['Asahi', 'Sankei', 25.9502], ['Asahi', 'Tokyo', 29.4126], ['Asahi', 'Yomiuri', 50.733], ['Asahi', 'Zakzak', 18.1128], ['Asahi', 'Nhk', 40.0297], ['Asahi', 'Akahata', 20.3992], ['Asahi', 'Nikkan', 25.7269], ['Asahi', 'Agora', 16.0423], ['Asahi', 'Anonymous', 5.8048], ['Asahi', 'Hamusoku', 3.5045], ['Asahi', 'Seijichishin', 7.202], ['Asahi', 'Litera', 18.3392], ['Asahi', 'Share_News_Japan', 8.5964], ['Asahi', 'Moeruasia', 5.8928], ['Asahi', 'BuzzFeed_Japan', 6.4361], ['Asahi', 'Yahoo_News', 15.569], ['Jiji', 'Jiji', 100], ['Jiji', 'Nikkei', 32.0415], ['Jiji', 'Sankei', 37.4116], ['Jiji', 'Tokyo', 17.325], ['Jiji', 'Yomiuri', 29.9635], ['Jiji', 'Zakzak', 14.0079], ['Jiji', 'Nhk', 33.6262], ['Jiji', 'Akahata', 11.3716], ['Jiji', 'Nikkan', 18.6615], ['Jiji', 'Agora', 10.0474], ['Jiji', 'Anonymous', 9.3376], ['Jiji', 'Hamusoku', 2.2339], ['Jiji', 'Seijichishin', 9.8337], ['Jiji', 'Litera', 12.6643], ['Jiji', 'Share_News_Japan', 13.3864], ['Jiji', 'Moeruasia', 8.8327], ['Jiji', 'BuzzFeed_Japan', 5.8603], ['Jiji', 'Yahoo_News', 23.2308], ['Nikkei', 'Nikkei', 100], ['Nikkei', 'Sankei', 28.1133], ['Nikkei', 'Tokyo', 25.3934], ['Nikkei', 'Yomiuri', 41.0586], ['Nikkei', 'Zakzak', 22.5536], ['Nikkei', 'Nhk', 44.2781], ['Nikkei', 'Akahata', 15.4899], ['Nikkei', 'Nikkan', 23.8427], ['Nikkei', 'Agora', 23.1789], ['Nikkei', 'Anonymous', 10.9741], ['Nikkei', 'Hamusoku', 5.8736], ['Nikkei', 'Seijichishin', 12.7207], ['Nikkei', 'Litera', 15.3095], ['Nikkei', 'Share_News_Japan', 14.7394], ['Nikkei', 'Moeruasia', 10.9659], ['Nikkei', 'BuzzFeed_Japan', 9.3766], ['Nikkei', 'Yahoo_News', 17.6702], ['Sankei', 'Sankei', 100], ['Sankei', 'Tokyo', 16.3301], ['Sankei', 'Yomiuri', 31.9209], ['Sankei', 'Zakzak', 29.1986], ['Sankei', 'Nhk', 30.3755], ['Sankei' ...

# %%
Simpson係数の拡張 = 0.01

matrix_con2 = []
for i in range(len(matrix_con)):
  if matrix_con[i][2] >= Simpson係数の拡張 and matrix_con[i][2] != 1:
    matrix_con2.append(matrix_con[i])

H = nx.Graph()
for n in sum_engname_list:
    H.add_node(n)
size =[((len(i)-1)/1000) for i in sum_list]
H.add_weighted_edges_from(matrix_con2)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]
pos = nx.spring_layout(H, k=2) 
#pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(12,8))
nx.draw_networkx(H, pos,node_size = size, arrows=False, width=[v['weight'] * 7 for v in H.edges.values()], connectionstyle="arc3, rad=0.1")

# %%
import networkx as nx
import math
import csv
import random as rand
import sys

_DEBUG_ = False

                                                                                                               
def buildG(G, list):                                                                                            
    for line in list:
       G.add_edge(line[0], line[1],weight=float(line[2]))                                                       #これでファイルから重み付き無向グラフの情報を打ち込む 元々int関数がついてたが削除
                                                                                                                #もしファイルの情報に重みが付与されていなかったら重みを自動で1とする。
                                                                                                                #この作業はGの中にある塊の数が一つ増えるまでエッジを減らし続ける。得られる成果はエッジが減ったG
                                                                                                                # This method keeps removing edges from Graph until one of the connected components of Graph splits into two
                                                                                                                # compute the edge betweenness
def CmtyGirvanNewmanStep(G): #③
    if _DEBUG_:
        print("Running CmtyGirvanNewmanStep method ...")
    init_ncomp = nx.number_connected_components(G)                                                              #number of components　連結グループの数を取得
    ncomp = init_ncomp                                                                                          #ncompを更新し続けてある塊を分割できるまで繰り返す。
    while ncomp <= init_ncomp:
        bw = nx.edge_betweenness_centrality(G, weight='weight')                                                 #edge betweenness for G
                                                                                                                #find the edge with max centrality その段階のグラフで最大の中心性を持つエッジを取得。
                                                                                                                #bwの形式は形式は{('エッジ', 'エッジ'): edge_betweenness_centralityの値の値, ...}
        max_ = max(bw.values())
                                                                                                                #find the edge with the highest centrality and remove all of them if there is more than one!
        for k, v in bw.items():                                                                                 #この場合kはインデックスでvが中身
            if float(v) == max_:
                G.remove_edge(k[0],k[1])                                                                        #remove the central edge
        ncomp = nx.number_connected_components(G)                                                               #recalculate the no of components

                                                                                                                #渡されたグラフGのモジュラリティーを計算して引数Modとして渡す
                                                                                                                # This method compute the modularity of current split
def _GirvanNewmanGetModularity(G, deg_, m_): #②
    New_A = nx.adjacency_matrix(G)                                                                              #データは['エッジ', 'エッジ', 重み]というリストが並んでいる。
    New_deg = {}
    New_deg = UpdateDeg(New_A, G.nodes())                                                                       #（重複）UpdateDegでは辞書型で{'ノード名': 重みの総和, ...}が取得できる。
                                                                                                                #Let's compute the Q
    comps = nx.connected_components(G)                                                                                                             #list of components データの形式の確認は困難 
    print('Number of communities in decomposed G: {}'.format(nx.number_connected_components(G)))                #元々Noと記載されてたが、Numberに修正
    Mod = 0                                                                                                     #Modularity of a given partitionning
    for c in comps:
        EWC = 0                                                                                                 #number of edges within a community
        RE = 0                                                                                                  #number of random edges
        for u in c:
            EWC += New_deg[u]
            RE += deg_[u]                                                                                       #count the probability of a random edge
        Mod += ( float(EWC) - float(RE*RE)/float(2*m_) )                                                        #モジュラリティーの計算
    Mod = Mod/float(2*m_)
    if _DEBUG_:
        print("Modularity: {}".format(Mod))
    return Mod

                                                                                                                #（重複）UpdateDegでは辞書型で{'ノード名': 重みの総和, ...}がdeg_dictに格納されている。
def UpdateDeg(A, nodes): #                                                                                      #nodes = G.nodes()でノードが並ぶリストが格納される。
    deg_dict = {}
    n = len(nodes)                                                                                              #len(A) ---> some ppl get issues when trying len() on sparse matrixes!
    B = A.sum(axis = 1)                                                                                         #グラフのノードが持つそれぞれのエッジの重みを足し合わせたものが格納され、それはノードごとにあり、ノードの番号順に並べられる。
    i = 0
    for node_id in list(nodes): 
        deg_dict[node_id] = B[i, 0]                                                                             #Bは縦に一列なのでB[i, 0]はi番目の要素のこと。つまりdeg_dictは
        i += 1
    return deg_dict
   


                                                                                                                # This method runs GirvanNewman algorithm and find the best community split by maximizing modularity measure
def runGirvanNewman(G, Orig_deg, m_): #④
                                                                                                                #let's find the best split of the graph
    BestQ = 0.0
    Q = 0.0
    while True:    
        CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
        Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
        print("Modularity of decomposed G: {}".format(Q))
        if Q > BestQ:
            BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
            Bestcomps = list(nx.connected_components(G))    #Best Split
            print("Identified components: {}".format(Bestcomps))
        if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
            break
    if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
        print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
        print("Graph communities: {}".format(Bestcomps))
    else:
        print("Max modularity (Q):", BestQ)                                                                     #モジュラリティーが0の場合は別処理


def main(argv):
    if len(argv) < 2:
        sys.stderr.write("Usage: %s <input graph>\n" % (argv[0],))
        return 1
    graph_fn = argv[1]
    G = nx.Graph()                                                                                              #let's create the graph first グラフ情報を取り込んでグラフGを作成。
    buildG(G, graph_fn, ',')                                                                                    #グラフのデータは’,’で区切られている
    
    if _DEBUG_:
        print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
    n = G.number_of_nodes()                                                                                     #|V|
    A = nx.adjacency_matrix(G)                                                                                  #adjacenct matrix

    m_ = 0.0                                                                                                    #the weighted version for number of edges
    for i in range(0,n):                                                                                        #エッジの数だけ処理
        for j in range(0,n):                                                                                    #エッジの数だけ処理
            m_ += A[i,j]                                                                                        #これでAの隣接行列のiからjに行くエッジの重みを取得、ちなAのノードは数字に変換される。
    m_ = m_/2.0                                                                                                 #一つのエッジについて2回計算しているから2で割っている。
                                                                                                                #ここではグラフの全ての重みを足し合わせた値：m_を得た。
    if _DEBUG_:
        print("m: {}".format(m_))

                                                                                                                #calculate the weighted degree for each node
    Orig_deg = {}
    Orig_deg = UpdateDeg(A, G.nodes())                                                                          #G.nodes()でノードが並ぶリストが作られる。
                                                                                                                #(重複)上のOrig_degには辞書型で{'ノード名': 重みの総和, ...}が格納されている。
    #run Newman alg
    runGirvanNewman(G, Orig_deg, m_)

# %%
import networkx as nx
import math
import csv
import random as rand
import sys

_DEBUG_ = False

                                                                                                                # This method reads the graph structure from the input file
def buildG(G, file_, delimiter_):
                                                                                                                #construct the weighted version of the contact graph from cgraph.dat file
                                                                                                                #reader = csv.reader(open("/home/kazem/Data/UCI/karate.txt"), delimiter=" ")
    reader = csv.reader(open(file_), delimiter=delimiter_)
    for line in reader:
        if len(line) > 2:
            if float(line[2]) != 0.0:
                                                                                                                #line format: u,v,w
                G.add_edge(line[0], line[1],weight=float(line[2]))                                              #これでファイルから重み付き無向グラフの情報を打ち込む 元々int関数がついてたが削除
        else:
            #line format: u,v
            G.add_edge(int(line[0]),int(line[1]),weight=1.0)                                                    #もしファイルの情報に重みが付与されていなかったら重みを自動で1とする。

                                                                                                                #この作業はGの中にある塊の数が一つ増えるまでエッジを減らし続ける。得られる成果はエッジが減ったG
                                                                                                                # This method keeps removing edges from Graph until one of the connected components of Graph splits into two
                                                                                                                # compute the edge betweenness
def CmtyGirvanNewmanStep(G): #③
    if _DEBUG_:
        print("Running CmtyGirvanNewmanStep method ...")
    init_ncomp = nx.number_connected_components(G)                                                              #number of components　連結グループの数を取得
    ncomp = init_ncomp                                                                                          #ncompを更新し続けてある塊を分割できるまで繰り返す。
    while ncomp <= init_ncomp:
        bw = nx.edge_betweenness_centrality(G, weight='weight')                                                 #edge betweenness for G
                                                                                                                #find the edge with max centrality その段階のグラフで最大の中心性を持つエッジを取得。
                                                                                                                #bwの形式は形式は{('エッジ', 'エッジ'): edge_betweenness_centralityの値の値, ...}
        max_ = max(bw.values())
                                                                                                                #find the edge with the highest centrality and remove all of them if there is more than one!
        for k, v in bw.items():                                                                                 #この場合kはインデックスでvが中身
            if float(v) == max_:
                G.remove_edge(k[0],k[1])                                                                        #remove the central edge
        ncomp = nx.number_connected_components(G)                                                               #recalculate the no of components

                                                                                                                #渡されたグラフGのモジュラリティーを計算して引数Modとして渡す
                                                                                                                # This method compute the modularity of current split
def _GirvanNewmanGetModularity(G, deg_, m_): #②
    New_A = nx.adjacency_matrix(G)                                                                              #データは['エッジ', 'エッジ', 重み]というリストが並んでいる。
    New_deg = {}
    New_deg = UpdateDeg(New_A, G.nodes())                                                                       #（重複）UpdateDegでは辞書型で{'ノード名': 重みの総和, ...}が取得できる。
                                                                                                                #Let's compute the Q
    comps = nx.connected_components(G)                                                                                                             #list of components データの形式の確認は困難 
    print('Number of communities in decomposed G: {}'.format(nx.number_connected_components(G)))                #元々Noと記載されてたが、Numberに修正
    Mod = 0                                                                                                     #Modularity of a given partitionning
    for c in comps:
        EWC = 0                                                                                                 #number of edges within a community
        RE = 0                                                                                                  #number of random edges
        for u in c:
            EWC += New_deg[u]
            RE += deg_[u]                                                                                       #count the probability of a random edge
        Mod += ( float(EWC) - float(RE*RE)/float(2*m_) )                                                        #モジュラリティーの計算
    Mod = Mod/float(2*m_)
    if _DEBUG_:
        print("Modularity: {}".format(Mod))
    return Mod

                                                                                                                #（重複）UpdateDegでは辞書型で{'ノード名': 重みの総和, ...}がdeg_dictに格納されている。
def UpdateDeg(A, nodes): #                                                                                      #nodes = G.nodes()でノードが並ぶリストが格納される。
    deg_dict = {}
    n = len(nodes)                                                                                              #len(A) ---> some ppl get issues when trying len() on sparse matrixes!
    B = A.sum(axis = 1)                                                                                         #グラフのノードが持つそれぞれのエッジの重みを足し合わせたものが格納され、それはノードごとにあり、ノードの番号順に並べられる。
    i = 0
    for node_id in list(nodes): 
        deg_dict[node_id] = B[i, 0]                                                                             #Bは縦に一列なのでB[i, 0]はi番目の要素のこと。つまりdeg_dictは
        i += 1
    return deg_dict
   


                                                                                                                # This method runs GirvanNewman algorithm and find the best community split by maximizing modularity measure
def runGirvanNewman(G, Orig_deg, m_): #④
                                                                                                                #let's find the best split of the graph
    BestQ = 0.0
    Q = 0.0
    while True:    
        CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
        Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
        print("Modularity of decomposed G: {}".format(Q))
        if Q > BestQ:
            BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
            Bestcomps = list(nx.connected_components(G))    #Best Split
            print("Identified components: {}".format(Bestcomps))
        if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
            break
    if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
        print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
        print("Graph communities: {}".format(Bestcomps))
    else:
        print("Max modularity (Q):", BestQ)                                                                     #モジュラリティーが0の場合は別処理


def main(argv):
    if len(argv) < 2:
        sys.stderr.write("Usage: %s <input graph>\n" % (argv[0],))
        return 1
    graph_fn = argv[1]
    G = nx.Graph()                                                                                              #let's create the graph first グラフ情報を取り込んでグラフGを作成。
    buildG(G, graph_fn, ',')                                                                                    #グラフのデータは’,’で区切られている
    
    if _DEBUG_:
        print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
    n = G.number_of_nodes()                                                                                     #|V|
    A = nx.adjacency_matrix(G)                                                                                  #adjacenct matrix

    m_ = 0.0                                                                                                    #the weighted version for number of edges
    for i in range(0,n):                                                                                        #エッジの数だけ処理
        for j in range(0,n):                                                                                    #エッジの数だけ処理
            m_ += A[i,j]                                                                                        #これでAの隣接行列のiからjに行くエッジの重みを取得、ちなAのノードは数字に変換される。
    m_ = m_/2.0                                                                                                 #一つのエッジについて2回計算しているから2で割っている。
                                                                                                                #ここではグラフの全ての重みを足し合わせた値：m_を得た。
    if _DEBUG_:
        print("m: {}".format(m_))

                                                                                                                #calculate the weighted degree for each node
    Orig_deg = {}
    Orig_deg = UpdateDeg(A, G.nodes())                                                                          #G.nodes()でノードが並ぶリストが作られる。
                                                                                                                #(重複)上のOrig_degには辞書型で{'ノード名': 重みの総和, ...}が格納されている。
    #run Newman alg
    runGirvanNewman(G, Orig_deg, m_)

# %%
    G = nx.Graph()  #let's create the graph first
    buildG(G, 'media_community_detection.csv', ',')
    
    if _DEBUG_:
        print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
    n = G.number_of_nodes()    #|V|
    A = nx.adjacency_matrix(G)    #adjacenct matrix

    m_ = 0.0    #the weighted version for number of edges
    for i in range(0,n):
        for j in range(0,n):
            m_ += A[i,j]
    m_ = m_/2.0
    if _DEBUG_:
        print("m: {}".format(m_))

    #calculate the weighted degree for each node
    Orig_deg = {}
    Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
    runGirvanNewman(G, Orig_deg, m_)
# Out:
# Number of communities in decomposed G: 2
# Modularity of decomposed G: -0.07621948112460433
# Number of communities in decomposed G: 3
# Modularity of decomposed G: -0.1016682303347408
# Number of communities in decomposed G: 4
# Modularity of decomposed G: -0.06323393796365451
# Number of communities in decomposed G: 5
# Modularity of decomposed G: -0.045964443597402704
# Number of communities in decomposed G: 6
# Modularity of decomposed G: -0.03973405290413905
# Number of communities in decomposed G: 7
# Modularity of decomposed G: -0.0258308887011856
# Number of communities in decomposed G: 8
# Modularity of decomposed G: -0.09552261881532792
# Number of communities in decomposed G: 9
# Modularity of decomposed G: -0.05119906468273965
# Number of communities in decomposed G: 10
# Modularity of decomposed G: -0.059592700398967725
# Number of communities in decomposed G: 11
# Modularity of decomposed G: -0.0415050620174058
# Number of communities in decomposed G: 12
# Modularity of decomposed G: -0.04251901864956838
# Number of communities in decomposed G: 13
# Modularity of decomposed G: -0.04692781582208989
# Number of communities in decomposed G: 14
# Modularity of decomposed G: -0.029591768785228754
# Number of communities in decomposed G: 22
# Modularity of decomposed G: -0.051598029232403586
# Max modularity (Q): 0.0

# %%
    G = nx.Graph()  #let's create the graph first
    buildG(G, matrix_con)
    
    if _DEBUG_:
        print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
    n = G.number_of_nodes()    #|V|
    A = nx.adjacency_matrix(G)    #adjacenct matrix

    m_ = 0.0    #the weighted version for number of edges
    for i in range(0,n):
        for j in range(0,n):
            m_ += A[i,j]
    m_ = m_/2.0
    if _DEBUG_:
        print("m: {}".format(m_))

    #calculate the weighted degree for each node
    Orig_deg = {}
    Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
    runGirvanNewman(G, Orig_deg, m_)
# Out:
# Number of communities in decomposed G: 2
# Modularity of decomposed G: -0.042052846793808635
# Number of communities in decomposed G: 3
# Modularity of decomposed G: 0.1081124319348708
# Identified components: [{'Mainichi', 'Jiji', 'Gendai_biz', 'Nikkei', 'Akahata', 'Yomiuri', 'Okinawa', 'Sankei', 'Agora', 'Nikkan', 'BuzzFeed_Japan', 'Yahoo_News', 'Asahi', 'Zakzak', 'Tokyo', 'Nhk', 'Litera'}, {'Seijichishin', 'Moeruasia', 'Anonymous', 'Share_News_Japan'}, {'Hamusoku'}]
# Number of communities in decomposed G: 4
# Modularity of decomposed G: 0.13287368962157345
# Identified components: [{'Mainichi', 'Jiji', 'Gendai_biz', 'Nikkei', 'Akahata', 'Yomiuri', 'Okinawa', 'Sankei', 'Agora', 'Nikkan', 'Yahoo_News', 'Asahi', 'Zakzak', 'Tokyo', 'Nhk', 'Litera'}, {'Seijichishin', 'Moeruasia', 'Anonymous', 'Share_News_Japan'}, {'Hamusoku'}, {'BuzzFeed_Japan'}]
# Number of communities in decomposed G: 5
# Modularity of decomposed G: 0.1670268429585228
# Identified components: [{'Zakzak', 'Agora', 'Gendai_biz', 'Yomiuri'}, {'Mainichi', 'Jiji', 'Nikkei', 'Akahata', 'Okinawa', 'Sankei', 'Nikkan', 'Yahoo_News', 'Asahi', 'Tokyo', 'Nhk', 'Litera'}, {'Seijichishin', 'Moeruasia', 'Anonymous', 'Share_News_Japan'}, {'Hamusoku'}, {'BuzzFeed_Japan'}]
# Number of communities in decomposed G: 6
# Modularity of decomposed G: 0.21629291798037698
# Identified components: [{'Zakzak', 'Agora', 'Gendai_biz', 'Yomiuri'}, {'Mainichi', 'Akahata', 'Okinawa', 'Nikkan', 'Yahoo_News', 'Asahi', 'Tokyo', 'Litera'}, {'Nikkei', 'Sankei', 'Nhk', 'Jiji'}, {'Seijichishin', 'Moeruasia', 'Anonymous', 'Share_News_Japan'}, {'Hamusoku'}, {'BuzzFeed_Japan'}]
# Number of communities in decomposed G: 7
# Modularity of decomposed G: 0.21632944316837577
# Identified components: [{'Zakzak', 'Agora', 'Gendai_biz', 'Yomiuri'}, {'Mainichi', 'Akahata', 'Okinawa', 'Nikkan', 'Yahoo_News', 'Asahi', 'Tokyo'}, {'Nikkei', 'Sankei', 'Nhk', 'Jiji'}, {'Seijichishin', 'Moeruasia', 'Anonymous', 'Share_News_Japan'}, {'Hamusoku'}, {'Litera'}, {'BuzzFeed_Japan'}]
# Number of communities in decomposed G: 8
# Modularity of decomposed G: 0.22506482584013723
# Identified components: [{'Zakzak', 'Agora', 'Gendai_biz', 'Yomiuri'}, {'Mainichi', 'Akahata', 'Okinawa', 'Nikkan', 'Yahoo_News', 'Tokyo'}, {'Asahi'}, {'Nikkei', 'Sankei', 'Nhk', 'Jiji'}, {'Seijichishin', 'Moeruasia', 'Anonymous', 'Share_News_Japan'}, {'Hamusoku'}, {'Litera'}, {'BuzzFeed_Japan'}]
# Number of communities in decomposed G: 22
# Modularity of decomposed G: 0.19817231096874086
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-fde2d49efe53> in <module>()
#      21
#      22 #run Newman alg
# ---> 23 runGirvanNewman(G, Orig_deg, m_)
#
# <ipython-input-24-81f2fd16c392> in runGirvanNewman(G, Orig_deg, m_)
#      72     Q = 0.0
#      73     while True:
# ---> 74         CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
#      75         Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
#      76         print("Modularity of decomposed G: {}".format(Q))
#
# <ipython-input-24-81f2fd16c392> in CmtyGirvanNewmanStep(G)
#      24                                                                                                                 #find the edge with max centrality その段階のグラフで最大の中心性を持つエッジを取得。
#      25                                                                                                                 #bwの形式は形式は{('エッジ', 'エッジ'): edge_betweenness_centralityの値の値, ...}
# ---> 26         max_ = max(bw.values())
#      27                                                                                                                 #find the edge with the highest centrality and remove all of them if there is more than one!
#      28         for k, v in bw.items():                                                                                 #この場合kはインデックスでvが中身
#
# ValueError: max() arg is an empty sequence

# %%
スライドバーで人数を変更→一万、十万、〜一億一億
人数ごとにコミュニティー中抽出を行い、それぞれのコミュニティーの人数に比例して情報量を表示。表示。
→国レベル、地域ごと、
