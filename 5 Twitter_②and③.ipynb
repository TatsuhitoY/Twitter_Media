# %%
#セクション2
import csv

filename = '23.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_lists=[]
    for row in csvreader:
      自由民主党_lists += row

    print('データ取得終了時刻：', 自由民主党_lists[-2])
    del 自由民主党_lists[-1]
    del 自由民主党_lists[-1]

    unique_set = set(自由民主党_lists)
    自由民主党_list = list(unique_set)
    自由民主党_list.append('自由民主党')

    print('自由民主党のフォロワー数：', len(自由民主党_list)-1)
    print('\n')

filename = '24.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_lists=[]
    for row in csvreader:
      立憲民主党_lists += row

    print('データ取得終了時刻：', 立憲民主党_lists[-2])
    del 立憲民主党_lists[-1]
    del 立憲民主党_lists[-1]

    unique_set = set(立憲民主党_lists)
    立憲民主党_list = list(unique_set)
    立憲民主党_list.append('立憲民主党')

    print('立憲民主党のフォロワー数：', len(立憲民主党_list)-1)
    print('\n')

filename = '25.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    公明党_lists=[]
    for row in csvreader:
      公明党_lists += row

    print('データ取得終了時刻：', 公明党_lists[-2])
    del 公明党_lists[-1]
    del 公明党_lists[-1]

    unique_set = set(公明党_lists)
    公明党_list = list(unique_set)
    公明党_list.append('公明党')

    print('公明党のフォロワー数：', len(公明党_list)-1)
    print('\n')

filename = '26.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本共産党_lists=[]
    for row in csvreader:
      日本共産党_lists += row

    print('データ取得終了時刻：', 日本共産党_lists[-2])
    del 日本共産党_lists[-1]
    del 日本共産党_lists[-1]

    unique_set = set(日本共産党_lists)
    日本共産党_list = list(unique_set)
    日本共産党_list.append('日本共産党')

    print('日本共産党のフォロワー数：', len(日本共産党_list)-1)
    print('\n')

filename = '27.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_lists=[]
    for row in csvreader:
      日本維新の会_lists += row

    print('データ取得終了時刻：', 日本維新の会_lists[-2])
    del 日本維新の会_lists[-1]
    del 日本維新の会_lists[-1]

    unique_set = set(日本維新の会_lists)
    日本維新の会_list = list(unique_set)
    日本維新の会_list.append('日本維新の会')

    print('日本維新の会のフォロワー数：', len(日本維新の会_list)-1)
    print('\n')

filename = '28.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    国民民主党_lists=[]
    for row in csvreader:
      国民民主党_lists += row

    print('データ取得終了時刻：', 国民民主党_lists[-2])
    del 国民民主党_lists[-1]
    del 国民民主党_lists[-1]

    unique_set = set(国民民主党_lists)
    国民民主党_list = list(unique_set)
    国民民主党_list.append('国民民主党')

    print('国民民主党のフォロワー数：', len(国民民主党_list)-1)
    print('\n')

filename = '29.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    社会民主党_lists=[]
    for row in csvreader:
      社会民主党_lists += row

    print('データ取得終了時刻：', 社会民主党_lists[-2])
    del 社会民主党_lists[-1]
    del 社会民主党_lists[-1]

    unique_set = set(社会民主党_lists)
    社会民主党_list = list(unique_set)
    社会民主党_list.append('社会民主党')

    print('社会民主党のフォロワー数：', len(社会民主党_list)-1)
    print('\n')

filename = '30.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    れいわ新選組_lists=[]
    for row in csvreader:
      れいわ新選組_lists += row

    print('データ取得終了時刻：', れいわ新選組_lists[-2])
    del れいわ新選組_lists[-1]
    del れいわ新選組_lists[-1]

    unique_set = set(れいわ新選組_lists)
    れいわ新選組_list = list(unique_set)
    れいわ新選組_list.append('れいわ新選組')

    print('れいわ新選組のフォロワー数：', len(れいわ新選組_list)-1)
    print('\n')

filename = '31.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_党首_lists=[]
    for row in csvreader:
      自由民主党_党首_lists += row

    print('データ取得終了時刻：', 自由民主党_党首_lists[-2])
    del 自由民主党_党首_lists[-1]
    del 自由民主党_党首_lists[-1]

    unique_set = set(自由民主党_党首_lists)
    自由民主党_党首_list = list(unique_set)
    自由民主党_党首_list.append('自由民主党_党首')

    print('自由民主党_党首のフォロワー数：', len(自由民主党_党首_list)-1)
    print('\n')

filename = '32.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_党首_lists=[]
    for row in csvreader:
      立憲民主党_党首_lists += row

    print('データ取得終了時刻：', 立憲民主党_党首_lists[-2])
    del 立憲民主党_党首_lists[-1]
    del 立憲民主党_党首_lists[-1]

    unique_set = set(立憲民主党_党首_lists)
    立憲民主党_党首_list = list(unique_set)
    立憲民主党_党首_list.append('立憲民主党_党首')

    print('立憲民主党_党首のフォロワー数：', len(立憲民主党_党首_list)-1)
    print('\n')

filename = '33.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    公明党_党首_lists=[]
    for row in csvreader:
      公明党_党首_lists += row

    print('データ取得終了時刻：', 公明党_党首_lists[-2])
    del 公明党_党首_lists[-1]
    del 公明党_党首_lists[-1]

    unique_set = set(公明党_党首_lists)
    公明党_党首_list = list(unique_set)
    公明党_党首_list.append('公明党_党首')

    print('公明党_党首のフォロワー数：', len(公明党_党首_list)-1)
    print('\n')

filename = '34.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本共産党_党首_lists=[]
    for row in csvreader:
      日本共産党_党首_lists += row

    print('データ取得終了時刻：', 日本共産党_党首_lists[-2])
    del 日本共産党_党首_lists[-1]
    del 日本共産党_党首_lists[-1]

    unique_set = set(日本共産党_党首_lists)
    日本共産党_党首_list = list(unique_set)
    日本共産党_党首_list.append('日本共産党_党首')

    print('日本共産党_党首のフォロワー数：', len(日本共産党_党首_list)-1)
    print('\n')

filename = '35.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_党首_lists=[]
    for row in csvreader:
      日本維新の会_党首_lists += row

    print('データ取得終了時刻：', 日本維新の会_党首_lists[-2])
    del 日本維新の会_党首_lists[-1]
    del 日本維新の会_党首_lists[-1]

    unique_set = set(日本維新の会_党首_lists)
    日本維新の会_党首_list = list(unique_set)
    日本維新の会_党首_list.append('日本維新の会_党首')

    print('日本維新の会_党首のフォロワー数：', len(日本維新の会_党首_list)-1)
    print('\n')

filename = '36.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    国民民主党_党首_lists=[]
    for row in csvreader:
      国民民主党_党首_lists += row

    print('データ取得終了時刻：', 国民民主党_党首_lists[-2])
    del 国民民主党_党首_lists[-1]
    del 国民民主党_党首_lists[-1]

    unique_set = set(国民民主党_党首_lists)
    国民民主党_党首_list = list(unique_set)
    国民民主党_党首_list.append('国民民主党_党首')

    print('国民民主党_党首のフォロワー数：', len(国民民主党_党首_list)-1)
    print('\n')

filename = '37.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    社会民主党_党首_lists=[]
    for row in csvreader:
      社会民主党_党首_lists += row

    print('データ取得終了時刻：', 社会民主党_党首_lists[-2])
    del 社会民主党_党首_lists[-1]
    del 社会民主党_党首_lists[-1]

    unique_set = set(社会民主党_党首_lists)
    社会民主党_党首_list = list(unique_set)
    社会民主党_党首_list.append('社会民主党_党首')

    print('社会民主党_党首のフォロワー数：', len(社会民主党_党首_list)-1)
    print('\n')

filename = '38.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    れいわ新選組_党首_lists=[]
    for row in csvreader:
      れいわ新選組_党首_lists += row

    print('データ取得終了時刻：', れいわ新選組_党首_lists[-2])
    del れいわ新選組_党首_lists[-1]
    del れいわ新選組_党首_lists[-1]

    unique_set = set(れいわ新選組_党首_lists)
    れいわ新選組_党首_list = list(unique_set)
    れいわ新選組_党首_list.append('れいわ新選組_党首')

    print('れいわ新選組_党首のフォロワー数：', len(れいわ新選組_党首_list)-1)
    print('\n')

filename = '39.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_菅_lists=[]
    for row in csvreader:
      自由民主党_菅_lists += row

    print('データ取得終了時刻：', 自由民主党_菅_lists[-2])
    del 自由民主党_菅_lists[-1]
    del 自由民主党_菅_lists[-1]

    unique_set = set(自由民主党_菅_lists)
    自由民主党_菅_list = list(unique_set)
    自由民主党_菅_list.append('自由民主党_菅')

    print('自由民主党_菅のフォロワー数：', len(自由民主党_菅_list)-1)
    print('\n')

filename = '40.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_河野_lists=[]
    for row in csvreader:
      自由民主党_河野_lists += row

    print('データ取得終了時刻：', 自由民主党_河野_lists[-2])
    del 自由民主党_河野_lists[-1]
    del 自由民主党_河野_lists[-1]

    unique_set = set(自由民主党_河野_lists)
    自由民主党_河野_list = list(unique_set)
    自由民主党_河野_list.append('自由民主党_河野')

    print('自由民主党_河野のフォロワー数：', len(自由民主党_河野_list)-1)
    print('\n')

filename = '41.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_枝野_lists=[]
    for row in csvreader:
      立憲民主党_枝野_lists += row

    print('データ取得終了時刻：', 立憲民主党_枝野_lists[-2])
    del 立憲民主党_枝野_lists[-1]
    del 立憲民主党_枝野_lists[-1]

    unique_set = set(立憲民主党_枝野_lists)
    立憲民主党_枝野_list = list(unique_set)
    立憲民主党_枝野_list.append('立憲民主党_枝野')

    print('立憲民主党_枝野のフォロワー数：', len(立憲民主党_枝野_list)-1)
    print('\n')

filename = '42.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_蓮舫_lists=[]
    for row in csvreader:
      立憲民主党_蓮舫_lists += row

    print('データ取得終了時刻：', 立憲民主党_蓮舫_lists[-2])
    del 立憲民主党_蓮舫_lists[-1]
    del 立憲民主党_蓮舫_lists[-1]

    unique_set = set(立憲民主党_蓮舫_lists)
    立憲民主党_蓮舫_list = list(unique_set)
    立憲民主党_蓮舫_list.append('立憲民主党_蓮舫')

    print('立憲民主党_蓮舫のフォロワー数：', len(立憲民主党_蓮舫_list)-1)
    print('\n')

filename = '43.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_吉村_lists=[]
    for row in csvreader:
      日本維新の会_吉村_lists += row

    print('データ取得終了時刻：', 日本維新の会_吉村_lists[-2])
    del 日本維新の会_吉村_lists[-1]
    del 日本維新の会_吉村_lists[-1]

    unique_set = set(日本維新の会_吉村_lists)
    日本維新の会_吉村_list = list(unique_set)
    日本維新の会_吉村_list.append('日本維新の会_吉村')

    print('日本維新の会_吉村のフォロワー数：', len(日本維新の会_吉村_list)-1)
    print('\n')

filename = '44.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_橋下_lists=[]
    for row in csvreader:
      日本維新の会_橋下_lists += row

    print('データ取得終了時刻：', 日本維新の会_橋下_lists[-2])
    del 日本維新の会_橋下_lists[-1]
    del 日本維新の会_橋下_lists[-1]

    unique_set = set(日本維新の会_橋下_lists)
    日本維新の会_橋下_list = list(unique_set)
    日本維新の会_橋下_list.append('日本維新の会_橋下')

    print('日本維新の会_橋下のフォロワー数：', len(日本維新の会_橋下_list)-1)
    print('\n')

sum_list = [自由民主党_list, 立憲民主党_list, 公明党_list, 日本共産党_list, 日本維新の会_list, 国民民主党_list, 社会民主党_list, れいわ新選組_list, 自由民主党_党首_list, 立憲民主党_党首_list, 公明党_党首_list, 日本共産党_党首_list, 日本維新の会_党首_list, 国民民主党_党首_list, 社会民主党_党首_list, れいわ新選組_党首_list, 自由民主党_菅_list, 自由民主党_河野_list, 立憲民主党_枝野_list, 立憲民主党_蓮舫_list, 日本維新の会_吉村_list, 日本維新の会_橋下_list]
# Out:
# データ取得終了時刻： 2022-04-27T20:04:33
# 自由民主党のフォロワー数： 239712
#
#
# データ取得終了時刻： 2022-04-27T21:50:12
# 立憲民主党のフォロワー数： 191978
#
#
# データ取得終了時刻： 2022-04-27T22:20:20
# 公明党のフォロワー数： 103607
#
#
# データ取得終了時刻： 2022-04-27T22:50:29
# 日本共産党のフォロワー数： 127694
#
#
# データ取得終了時刻： 2022-04-27T22:50:32
# 日本維新の会のフォロワー数： 64812
#
#
# データ取得終了時刻： 2022-04-27T23:05:35
# 国民民主党のフォロワー数： 43724
#
#
# データ取得終了時刻： 2022-04-28T00:14:47
# 社会民主党のフォロワー数： 45234
#
#
# データ取得終了時刻： 2022-04-28T00:44:56
# れいわ新選組のフォロワー数： 113374
#
#
# データ取得終了時刻： 2022-05-05T23:41:24
# 自由民主党_党首のフォロワー数： 516553
#
#
# データ取得終了時刻： 2022-05-06T01:11:52
# 立憲民主党_党首のフォロワー数： 27834
#
#
# データ取得終了時刻： 2022-05-06T19:36:57
# 公明党_党首のフォロワー数： 48960
#
#
# データ取得終了時刻： 2022-05-06T20:22:11
# 日本共産党_党首のフォロワー数： 205336
#
#
# データ取得終了時刻： 2022-05-06T23:25:57
# 日本維新の会_党首のフォロワー数： 425594
#
#
# データ取得終了時刻： 2022-05-07T14:13:43
# 国民民主党_党首のフォロワー数： 219035
#
#
# データ取得終了時刻： 2022-05-07T14:59:00
# 社会民主党_党首のフォロワー数： 233406
#
#
# データ取得終了時刻： 2022-05-07T16:44:33
# れいわ新選組_党首のフォロワー数： 462013
#
#
# データ取得終了時刻： 2022-05-06T15:24:20
# 自由民主党_菅のフォロワー数： 545750
#
#
# データ取得終了時刻： 2022-05-06T09:59:52
# 自由民主党_河野のフォロワー数： 2457515
#
#
# データ取得終了時刻： 2022-05-06T01:42:05
# 立憲民主党_枝野のフォロワー数： 184142
#
#
# データ取得終了時刻： 2022-05-06T17:24:58
# 立憲民主党_蓮舫のフォロワー数： 528100
#
#
# データ取得終了時刻： 2022-05-07T04:25:25
# 日本維新の会_吉村のフォロワー数： 1263583
#
#
# データ取得終了時刻： 2022-05-07T13:28:28
# 日本維新の会_橋下のフォロワー数： 2697434

# %%
import networkx as nx
import math
import csv
import random as rand
import sys

_DEBUG_ = False

                                                                                                               
def buildG(G, list):                                                                                            
    for line in list:
       G.add_edge(line[0], line[1],weight=float(line[2]))                                                       #これでファイルから重み付き無向グラフの情報を打ち込む 元々int関数がついてたが削除
                                                                                                                #もしファイルの情報に重みが付与されていなかったら重みを自動で1とする。
                                                                                                                #この作業はGの中にある塊の数が一つ増えるまでエッジを減らし続ける。得られる成果はエッジが減ったG
                                                                                                                # This method keeps removing edges from Graph until one of the connected components of Graph splits into two
                                                                                                                # compute the edge betweenness
def CmtyGirvanNewmanStep(G): #③
    if _DEBUG_:
        print("Running CmtyGirvanNewmanStep method ...")
    init_ncomp = nx.number_connected_components(G)                                                              #number of components　連結グループの数を取得
    ncomp = init_ncomp                                                                                          #ncompを更新し続けてある塊を分割できるまで繰り返す。
    while ncomp <= init_ncomp:
        bw = nx.edge_betweenness_centrality(G, weight='weight')                                                 #edge betweenness for G
                                                                                                                #find the edge with max centrality その段階のグラフで最大の中心性を持つエッジを取得。
                                                                                                                #bwの形式は形式は{('エッジ', 'エッジ'): edge_betweenness_centralityの値の値, ...}
        max_ = max(bw.values())
                                                                                                                #find the edge with the highest centrality and remove all of them if there is more than one!
        for k, v in bw.items():                                                                                 #この場合kはインデックスでvが中身
            if float(v) == max_:
                G.remove_edge(k[0],k[1])                                                                        #remove the central edge
        ncomp = nx.number_connected_components(G)                                                               #recalculate the no of components

                                                                                                                #渡されたグラフGのモジュラリティーを計算して引数Modとして渡す
                                                                                                                # This method compute the modularity of current split
def _GirvanNewmanGetModularity(G, deg_, m_): #②
    New_A = nx.adjacency_matrix(G)                                                                              #データは['エッジ', 'エッジ', 重み]というリストが並んでいる。
    New_deg = {}
    New_deg = UpdateDeg(New_A, G.nodes())                                                                       #（重複）UpdateDegでは辞書型で{'ノード名': 重みの総和, ...}が取得できる。
                                                                                                                #Let's compute the Q
    comps = nx.connected_components(G)                                                                                                             #list of components データの形式の確認は困難 
    print('Number of communities in decomposed G: {}'.format(nx.number_connected_components(G)))                #元々Noと記載されてたが、Numberに修正
    Mod = 0                                                                                                     #Modularity of a given partitionning
    for c in comps:
        EWC = 0                                                                                                 #number of edges within a community
        RE = 0                                                                                                  #number of random edges
        for u in c:
            EWC += New_deg[u]     #EWCはその連結部のノードの最新の重みの総和
            RE += deg_[u]         #REはその連結部のノードの初期の重みの総和                                           #count the probability of a random edge
        Mod += ( float(EWC) - float(RE*RE)/float(2*m_) )                                                        #モジュラリティーの計算
    Mod = Mod/float(2*m_) 
    if _DEBUG_:
        print("Modularity: {}".format(Mod))
    return Mod

                                                                                                                #（重複）UpdateDegでは辞書型で{'ノード名': 重みの総和, ...}がdeg_dictに格納されている。
def UpdateDeg(A, nodes): #                                                                                      #nodes = G.nodes()でノードが並ぶリストが格納される。
    deg_dict = {}
    n = len(nodes)                                                                                              #len(A) ---> some ppl get issues when trying len() on sparse matrixes!
    B = A.sum(axis = 1)                                                                                         #グラフのノードが持つそれぞれのエッジの重みを足し合わせたものが格納され、それはノードごとにあり、ノードの番号順に並べられる。
    i = 0
    for node_id in list(nodes): 
        deg_dict[node_id] = B[i]                                                                             #Bは縦に一列なのでB[i, 0]はi番目の要素のこと。つまりdeg_dictは
        i += 1
    return deg_dict

# %%
#セクション3.1 
#フォロワー総数（重複ありあり/なし）

sum_totalcount_list = 自由民主党_list + 立憲民主党_list + 公明党_list + 日本共産党_list + 日本維新の会_list + 国民民主党_list + 社会民主党_list + れいわ新選組_list + 自由民主党_党首_list + 立憲民主党_党首_list + 公明党_党首_list + 日本共産党_党首_list + 日本維新の会_党首_list + 国民民主党_党首_list + 社会民主党_党首_list + れいわ新選組_党首_list + 自由民主党_菅_list + 自由民主党_河野_list + 立憲民主党_枝野_list + 立憲民主党_蓮舫_list + 日本維新の会_吉村_list + 日本維新の会_橋下_list

print('収集したフォロワーIDの総数：', len(sum_totalcount_list)-22)
print('フォロワーの総数', len(set(sum_totalcount_list))-22)
# Out:
# 収集したフォロワーIDの総数： 10745390
# フォロワーの総数 6421493

# %%
#セクション4.1 ②
#グラフリスト Jaccard係数

# if csv is ready, data_import = 1, otherwise 0
data_import = 0

import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa', 'Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_j = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Jaccard_②&③.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_jt=[]
      for row in csvreader:
        a_b_jt += row
  a_b_j = []
  for i in a_b_jt:
    a_b_j.append(float(i))

if data_import == 0:
  a_b_j = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_list = set(a) & set(b)
        a_b_j.append((len(a_b_list))/((len(a)-1)+(len(b)-1)-(len(a_b_list))))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_j[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_j[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_j[e][2] = a_b_j[e]
      
print(matrix_j)
# Out:
# [['Jiyuminsyu', 'Rikkenminsyu', 0.08354019884188782], ['Jiyuminsyu', 'Komei', 0.14108372026549584], ['Jiyuminsyu', 'Kyosan', 0.08212403872491701], ['Jiyuminsyu', 'Ishin', 0.09269405901159349], ['Jiyuminsyu', 'Kokuminminsyu', 0.05745496873554299], ['Jiyuminsyu', 'Syakaiminsyu', 0.06642265286416814], ['Jiyuminsyu', 'Reiwa', 0.030754544578763456], ['Jiyuminsyu', 'Jiyuminsyu_Leader', 0.07661043490639903], ['Jiyuminsyu', 'Rikkenminsyu_Leader', 0.027588405418588664], ['Jiyuminsyu', 'Komei_Leader', 0.04926231921459441], ['Jiyuminsyu', 'Kyosan_Leader', 0.05282232404978248], ['Jiyuminsyu', 'Ishin_Leader', 0.09038135961282223], ['Jiyuminsyu', 'Kokuminminsyu_Leader', 0.09668589515255688], ['Jiyuminsyu', 'Syakaiminsyu_Leader', 0.09385122247268944], ['Jiyuminsyu', 'Reiwa_Leader', 0.04748363598366957], ['Jiyuminsyu', 'Jiyuminsyu_Suga', 0.12788266580892702], ['Jiyuminsyu', 'Jiyuminsyu_Kono', 0.0490136329181321], ['Jiyuminsyu', 'Rikkenminsyu_Edano', 0.07580160867435386], ['Jiyuminsyu', 'Rikkenminsyu_Renho', 0.07379986070748291], ['Jiyuminsyu', 'Ishin_Yoshimura', 0.041668976412871754], ['Jiyuminsyu', 'Ishin_Hashimoto', 0.03747731403869806], ['Rikkenminsyu', 'Komei', 0.05422997360724731], ['Rikkenminsyu', 'Kyosan', 0.21426862111272757], ['Rikkenminsyu', 'Ishin', 0.05304813535968243], ['Rikkenminsyu', 'Kokuminminsyu', 0.08171291940687572], ['Rikkenminsyu', 'Syakaiminsyu', 0.14051358979166967], ['Rikkenminsyu', 'Reiwa', 0.13142780919068334], ['Rikkenminsyu', 'Jiyuminsyu_Leader', 0.03583829056880165], ['Rikkenminsyu', 'Rikkenminsyu_Leader', 0.0719660578869084], ['Rikkenminsyu', 'Komei_Leader', 0.026080216682139907], ['Rikkenminsyu', 'Kyosan_Leader', 0.17742552075461634], ['Rikkenminsyu', 'Ishin_Leader', 0.0369375374639213], ['Rikkenminsyu', 'Kokuminminsyu_Leader', 0.09771490227708546], ['Rikkenminsyu', 'Syakaiminsyu_Leader', 0.1698071698071698], ['Rikkenminsyu', 'Reiwa_Leader', 0.13196583977789625], ['Rikkenminsyu', 'Jiyuminsyu_Suga', 0.03695041043517373], ['Rikkenminsyu', 'Jiyuminsyu_Kono', 0.021020475955954382], ['Rikkenminsyu', 'Rikkenminsyu_Edano', 0.3788906404663269], ['Rikkenminsyu', 'Rikkenminsyu_Renho', 0.09818544512870254], ['Rikkenminsyu', 'Ishin_Yoshimura', 0.019033530433905967], ['Rikkenminsyu', 'Ishin_Hashimoto', 0.017101698131073713], ['Komei', 'Kyosan', 0.07875884970197841], ['Komei', 'Ishin', 0.06001900769748809], ['Komei', 'Kokuminminsyu', 0.05389242973740495], ['Komei', 'Syakaiminsyu', 0.09322942680024679], ['Komei', 'Reiwa', 0.0268665051300496], ['Komei', 'Jiyuminsyu_Leader', 0.017987465569712507], ['Komei', 'Rikkenminsyu_Leader', 0.02754108100501884], ['Komei', 'Komei_Leader', 0.2434959084536889], ['Komei', 'Kyosan_Leader', 0.03574829019713021], ['Komei', 'Ishin_Leader', 0.027030331494178814], ['Komei', 'Kokuminminsyu_Leader', 0.03749746769095218], ['Komei', 'Syakaiminsyu_Leader', 0.06756439984288086], ['Komei', 'Reiwa_Leader', 0.028199968369789878], ['Komei', 'Jiyuminsyu_Suga', 0.025722152105681337], ['Komei', 'Jiyuminsyu_Kono', 0.01307160069554871], ['Komei', 'Rikkenminsyu_Edano', 0.04557676794837322], ['Komei', 'Rikkenminsyu_Renho', 0.040091741759788725], ['Komei', 'Ishin_Yoshimura', 0.010468387155900922], ['Komei', 'Ishin_Hashimoto', 0.012585739559963647], ['Kyosan', 'Ishin', 0.05773689820767261], ['Kyosan', 'Kokuminminsyu', 0.08253972263621896], ['Kyosan', 'Syakaiminsyu', 0.24464149476745023], ['Kyosan', 'Reiwa', 0.14184215761502827], ['Kyosan', 'Jiyuminsyu_Leader', 0.022575330463601388], ['Kyosan', 'Rikkenminsyu_Leader', 0.06231344557904443], ['Kyosan', 'Komei_Leader', 0.03736545090462796], ['Kyosan', 'Kyosan_Leader', 0.26073229455321856], ['Kyosan', 'Ishin_Leader', 0.028988229517891914], ['Kyosan', 'Kokuminminsyu_Leader', 0.07812067598451516], ['Kyosan', 'Syakaiminsyu_Leader', 0.16537252547941314], ['Kyosan', 'Reiwa_Leader', 0.1075433001656506], ['Kyosan', 'Jiyuminsyu_Suga', 0.027694354917472408], ['Kyosan', 'Jiyuminsyu_Kono', 0.01257052659202582], ['Kyosan', 'Rikkenminsyu_Edano', 0.18639644198247624], ['Kyosan', 'Rikken ...

# %%
import csv
f = open('Jaccard_②&③.csv', 'w')
data = a_b_j
writer = csv.writer(f)
writer.writerow(data)
f.close()

# %%
sum_engname_list1 = [['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa'],['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']]
color_list10 = ['burlywood', 'lightcoral', 'lime', 'yellow', 'aqua', 'coral', 'red', 'fuchsia', 'bisque', 'blue', 'lightyellow', 'turquoise', 'lavender', 'olive', 'salmon', 'lightskyblue', 'chocolate', 'sateblue', 'palegreen', 'grey']
#セクション4.2.1 
#グラフリスト 
#Jaccard係数

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 0

Jaccard係数 = 0.1

matrix_condj = []
for i in range(len(matrix_j)):
  if matrix_j[i][2] >= Jaccard係数 and matrix_j[i][2] != 1:
    matrix_condj.append(matrix_j[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_condj) #ここに三次元リストを入れて実行！
    
  if _DEBUG_:
    print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)                                                                         #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_condj)):
    node_list_del.append(matrix_condj[i][0])
    node_list_del.append(matrix_condj[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/800)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/800) for i in sum_list]

H.add_weighted_edges_from(matrix_condj)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = media, BLUE = political party, LIME = politician')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(21,14))
plt.title('Jaccard index Threshold:{}'.format(Jaccard係数))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# Number of communities in decomposed G: 2
# Modularity of decomposed G: 0.34891182571927254
# Identified components: [{'Ishin_Yoshimura', 'Komei', 'Jiyuminsyu_Kono', 'Komei_Leader', 'Jiyuminsyu_Suga', 'Ishin', 'Ishin_Hashimoto', 'Jiyuminsyu_Leader', 'Jiyuminsyu', 'Ishin_Leader'}, {'Reiwa_Leader', 'Kyosan_Leader', 'Kokuminminsyu', 'Rikkenminsyu_Leader', 'Kokuminminsyu_Leader', 'Reiwa', 'Syakaiminsyu_Leader', 'Rikkenminsyu_Renho', 'Kyosan', 'Rikkenminsyu_Edano', 'Rikkenminsyu', 'Syakaiminsyu'}]
# Number of communities in decomposed G: 3
# Modularity of decomposed G: 0.35477523350061374
# Identified components: [{'Komei_Leader', 'Komei', 'Jiyuminsyu'}, {'Ishin_Yoshimura', 'Jiyuminsyu_Kono', 'Ishin', 'Jiyuminsyu_Suga', 'Ishin_Hashimoto', 'Jiyuminsyu_Leader', 'Ishin_Leader'}, {'Reiwa_Leader', 'Kyosan_Leader', 'Kokuminminsyu', 'Rikkenminsyu_Leader', 'Kokuminminsyu_Leader', 'Reiwa', 'Syakaiminsyu_Leader', 'Rikkenminsyu_Renho', 'Kyosan', 'Rikkenminsyu_Edano', 'Rikkenminsyu', 'Syakaiminsyu'}]
# Number of communities in decomposed G: 4
# Modularity of decomposed G: 0.40992485527280165
# Identified components: [{'Komei_Leader', 'Komei', 'Jiyuminsyu'}, {'Ishin_Yoshimura', 'Jiyuminsyu_Kono', 'Ishin', 'Jiyuminsyu_Suga', 'Ishin_Hashimoto', 'Jiyuminsyu_Leader', 'Ishin_Leader'}, {'Reiwa_Leader', 'Kyosan_Leader', 'Reiwa', 'Syakaiminsyu_Leader', 'Rikkenminsyu_Renho', 'Kyosan', 'Rikkenminsyu_Edano', 'Rikkenminsyu', 'Syakaiminsyu'}, {'Rikkenminsyu_Leader', 'Kokuminminsyu_Leader', 'Kokuminminsyu'}]
# Number of communities in decomposed G: 5
# Modularity of decomposed G: 0.3956340406667847
# Number of communities in decomposed G: 6
# Modularity of decomposed G: 0.33133308367688663
# Number of communities in decomposed G: 7
# Modularity of decomposed G: 0.3265323652681854
# Number of communities in decomposed G: 8
# Modularity of decomposed G: 0.30085633484717667
# Number of communities in decomposed G: 12
# Modularity of decomposed G: 0.07334775321883755
# Number of communities in decomposed G: 13
# Modularity of decomposed G: 0.09117658367802853
# Number of communities in decomposed G: 14
# Modularity of decomposed G: 0.08885888056542524
# Number of communities in decomposed G: 22
# Modularity of decomposed G: -0.06573903306382864
# Max modularity found (Q): 0.40992485527280165 and number of communities: 4
# Graph communities: [{'Komei_Leader', 'Komei', 'Jiyuminsyu'}, {'Ishin_Yoshimura', 'Jiyuminsyu_Kono', 'Ishin', 'Jiyuminsyu_Suga', 'Ishin_Hashimoto', 'Jiyuminsyu_Leader', 'Ishin_Leader'}, {'Reiwa_Leader', 'Kyosan_Leader', 'Reiwa', 'Syakaiminsyu_Leader', 'Rikkenminsyu_Renho', 'Kyosan', 'Rikkenminsyu_Edano', 'Rikkenminsyu', 'Syakaiminsyu'}, {'Rikkenminsyu_Leader', 'Kokuminminsyu_Leader', 'Kokuminminsyu'}]
# note : nodes in color gray are not in any community as it have no edges

# %%
#セクション4.2 ②
#グラフリスト Dice係数

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa', 'Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_d = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Dice_②&③.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_dt=[]
      for row in csvreader:
        a_b_dt += row
  a_b_d = []
  for i in a_b_dt:
    a_b_d.append(float(i))

if data_import == 0:
  a_b_d = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_list = set(a) & set(b)
        a_b_d.append((len(a_b_list)*2)/((len(a)-1)+(len(b)-1)))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_d[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_d[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_d[e][2] = a_b_d[e]
      
print(matrix_d)
# Out:
# [['Jiyuminsyu', 'Rikkenminsyu', 0.15419861474669322], ['Jiyuminsyu', 'Komei', 0.24728022626187307], ['Jiyuminsyu', 'Kyosan', 0.15178304110439134], ['Jiyuminsyu', 'Ishin', 0.16966150451195966], ['Jiyuminsyu', 'Kokuminminsyu', 0.10866650672462214], ['Jiyuminsyu', 'Syakaiminsyu', 0.12457097134193847], ['Jiyuminsyu', 'Reiwa', 0.05967384716471341], ['Jiyuminsyu', 'Jiyuminsyu_Leader', 0.14231783832386796], ['Jiyuminsyu', 'Rikkenminsyu_Leader', 0.053695439288944706], ['Jiyuminsyu', 'Komei_Leader', 0.09389895798691941], ['Jiyuminsyu', 'Kyosan_Leader', 0.10034423253222124], ['Jiyuminsyu', 'Ishin_Leader', 0.1657793556649121], ['Jiyuminsyu', 'Kokuminminsyu_Leader', 0.17632376887478282], ['Jiyuminsyu', 'Syakaiminsyu_Leader', 0.1715977832168719], ['Jiyuminsyu', 'Reiwa_Leader', 0.09066229648366525], ['Jiyuminsyu', 'Jiyuminsyu_Suga', 0.22676590337915775], ['Jiyuminsyu', 'Jiyuminsyu_Kono', 0.09344708472813004], ['Jiyuminsyu', 'Rikkenminsyu_Edano', 0.1409211662506429], ['Jiyuminsyu', 'Rikkenminsyu_Renho', 0.13745552296655952], ['Jiyuminsyu', 'Ishin_Yoshimura', 0.08000425731476524], ['Jiyuminsyu', 'Ishin_Hashimoto', 0.07224700440495638], ['Rikkenminsyu', 'Komei', 0.10288072804776968], ['Rikkenminsyu', 'Kyosan', 0.35291799094071424], ['Rikkenminsyu', 'Ishin', 0.10075158689980139], ['Rikkenminsyu', 'Kokuminminsyu', 0.1510806017768199], ['Rikkenminsyu', 'Syakaiminsyu', 0.24640406050284133], ['Rikkenminsyu', 'Reiwa', 0.23232204144724777], ['Rikkenminsyu', 'Jiyuminsyu_Leader', 0.06919669005308166], ['Rikkenminsyu', 'Rikkenminsyu_Leader', 0.13426928466143795], ['Rikkenminsyu', 'Komei_Leader', 0.05083465455843412], ['Rikkenminsyu', 'Kyosan_Leader', 0.3013787583624035], ['Rikkenminsyu', 'Ishin_Leader', 0.07124351492619484], ['Rikkenminsyu', 'Kokuminminsyu_Leader', 0.17803329821684472], ['Rikkenminsyu', 'Syakaiminsyu_Leader', 0.2903165140202734], ['Rikkenminsyu', 'Reiwa_Leader', 0.23316223006126996], ['Rikkenminsyu', 'Jiyuminsyu_Suga', 0.07126745900928255], ['Rikkenminsyu', 'Jiyuminsyu_Kono', 0.041175424883175764], ['Rikkenminsyu', 'Rikkenminsyu_Edano', 0.549558651494204], ['Rikkenminsyu', 'Rikkenminsyu_Renho', 0.17881396182080275], ['Rikkenminsyu', 'Ishin_Yoshimura', 0.03735604347739463], ['Rikkenminsyu', 'Ishin_Hashimoto', 0.03362829530714208], ['Komei', 'Kyosan', 0.1460175269454088], ['Komei', 'Ishin', 0.11324138012932032], ['Komei', 'Kokuminminsyu', 0.10227311292260284], ['Komei', 'Syakaiminsyu', 0.17055784360492068], ['Komei', 'Reiwa', 0.05232716228609878], ['Komei', 'Jiyuminsyu_Leader', 0.03533926728586171], ['Komei', 'Rikkenminsyu_Leader', 0.05360580032105659], ['Komei', 'Komei_Leader', 0.3916312177600661], ['Komei', 'Kyosan_Leader', 0.06902891471889637], ['Komei', 'Ishin_Leader', 0.05263784459968897], ['Komei', 'Kokuminminsyu_Leader', 0.07228445149732521], ['Komei', 'Syakaiminsyu_Leader', 0.12657671959241928], ['Komei', 'Reiwa_Leader', 0.05485308157420176], ['Komei', 'Jiyuminsyu_Suga', 0.050154229491635574], ['Komei', 'Jiyuminsyu_Kono', 0.0258058772678537], ['Komei', 'Rikkenminsyu_Edano', 0.08718014658608718], ['Komei', 'Rikkenminsyu_Renho', 0.0770927027878431], ['Komei', 'Ishin_Yoshimura', 0.020719870683665036], ['Komei', 'Ishin_Hashimoto', 0.024858615064899087], ['Kyosan', 'Ishin', 0.1091706232533012], ['Kyosan', 'Kokuminminsyu', 0.15249273705211822], ['Kyosan', 'Syakaiminsyu', 0.3931115840118431], ['Kyosan', 'Reiwa', 0.24844442232067301], ['Kyosan', 'Jiyuminsyu_Leader', 0.044153872660641025], ['Kyosan', 'Rikkenminsyu_Leader', 0.11731649606501723], ['Kyosan', 'Komei_Leader', 0.07203912733365789], ['Kyosan', 'Kyosan_Leader', 0.41362039455904875], ['Kyosan', 'Ishin_Leader', 0.056343170283830485], ['Kyosan', 'Kokuminminsyu_Leader', 0.14492009609810544], ['Kyosan', 'Syakaiminsyu_Leader', 0.2838105787870396], ['Kyosan', 'Reiwa_Leader', 0.19420152719910058], ['Kyosan', 'Jiyuminsyu_Suga', 0.05389609232541978], ['Kyosan', 'Jiyuminsyu_Kono', 0.02482894032938923], ['Kyosan', 'Rikkenminsyu_Edano', 0.31422286073448863], ['Kyosan', 'Rikkenminsyu_Renho', 0. ...

# %%
import csv
f = open('Dice_②&③.csv', 'w')
data = a_b_d
writer = csv.writer(f)
writer.writerow(data)
f.close()

# %%
sum_engname_list1 = [['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News'],['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa'],['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']]
color_list10 = ['burlywood', 'lightcoral', 'lime', 'yellow', 'aqua', 'coral', 'red', 'fuchsia', 'bisque', 'blue', 'lightyellow', 'turquoise', 'lavender', 'olive', 'salmon', 'lightskyblue', 'chocolate', 'sateblue', 'palegreen', 'grey']
#セクション4.2.1 
#グラフリスト 
#Dice係数

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 0

Dice係数 = 0.2

matrix_condt = []
for i in range(len(matrix_d)):
  if matrix_d[i][2] >= Dice係数 and matrix_d[i][2] != 1:
    matrix_condt.append(matrix_d[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_condt) #ここに三次元リストを入れて実行！

  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))    #
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))  #
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)                                                                         #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_condt)):
    node_list_del.append(matrix_condt[i][0])
    node_list_del.append(matrix_condt[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/800)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/800) for i in sum_list]

H.add_weighted_edges_from(matrix_condt)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = media, BLUE = political party, LIME = politician')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(21,14))
plt.title('Dice index Threshold:{}'.format(Dice係数))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# Number of communities in decomposed G: 4
# Modularity of decomposed G: 0.34326161654435816
# Identified components: [{'Komei', 'Jiyuminsyu', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Leader', 'Komei_Leader'}, {'Rikkenminsyu', 'Rikkenminsyu_Edano', 'Syakaiminsyu_Leader', 'Kyosan_Leader', 'Kyosan', 'Rikkenminsyu_Renho', 'Reiwa', 'Reiwa_Leader', 'Syakaiminsyu'}, {'Kokuminminsyu', 'Kokuminminsyu_Leader'}, {'Ishin_Leader', 'Ishin_Yoshimura', 'Ishin_Hashimoto', 'Jiyuminsyu_Kono'}]
# Number of communities in decomposed G: 6
# Modularity of decomposed G: 0.3043532160029541
# Number of communities in decomposed G: 7
# Modularity of decomposed G: 0.289936834809838
# Number of communities in decomposed G: 8
# Modularity of decomposed G: 0.24322285144710776
# Number of communities in decomposed G: 9
# Modularity of decomposed G: 0.2031099387168295
# Number of communities in decomposed G: 10
# Modularity of decomposed G: 0.1443999075530814
# Number of communities in decomposed G: 12
# Modularity of decomposed G: 0.09078355473949097
# Number of communities in decomposed G: 14
# Modularity of decomposed G: 0.07835064796110873
# Number of communities in decomposed G: 20
# Modularity of decomposed G: -0.07709325836567492
# Max modularity found (Q): 0.34326161654435816 and number of communities: 4
# Graph communities: [{'Komei', 'Jiyuminsyu', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Leader', 'Komei_Leader'}, {'Rikkenminsyu', 'Rikkenminsyu_Edano', 'Syakaiminsyu_Leader', 'Kyosan_Leader', 'Kyosan', 'Rikkenminsyu_Renho', 'Reiwa', 'Reiwa_Leader', 'Syakaiminsyu'}, {'Kokuminminsyu', 'Kokuminminsyu_Leader'}, {'Ishin_Leader', 'Ishin_Yoshimura', 'Ishin_Hashimoto', 'Jiyuminsyu_Kono'}]
# note : nodes in color gray are not in any community as it have no edges

# %%
#セクション4.3 ② 重複なし
#グラフリスト Simpson係数

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa', 'Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_s = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Simpson_②&③.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_st=[]
      for row in csvreader:
        a_b_st += row
  a_b_s = []
  for i in a_b_st:
    a_b_s.append(float(i))

if data_import == 0:
  a_b_s = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_s.append(len(set(a) & set(b))/min((len(a)-1), (len(b)-1)))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_s[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_s[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_s[e][2] = a_b_s[e]
      
print(matrix_s)
# Out:
# [['Jiyuminsyu', 'Rikkenminsyu', 0.1733688235110273], ['Jiyuminsyu', 'Komei', 0.40970204715897574], ['Jiyuminsyu', 'Kyosan', 0.21835794947295878], ['Jiyuminsyu', 'Ishin', 0.3985835956304388], ['Jiyuminsyu', 'Kokuminminsyu', 0.35220931296313235], ['Jiyuminsyu', 'Syakaiminsyu', 0.3923597294070832], ['Jiyuminsyu', 'Reiwa', 0.09292253955933459], ['Jiyuminsyu', 'Jiyuminsyu_Leader', 0.2244985649446002], ['Jiyuminsyu', 'Rikkenminsyu_Leader', 0.2580656750736509], ['Jiyuminsyu', 'Komei_Leader', 0.27681781045751636], ['Jiyuminsyu', 'Kyosan_Leader', 0.10874371761405696], ['Jiyuminsyu', 'Ishin_Leader', 0.23005523294620212], ['Jiyuminsyu', 'Kokuminminsyu_Leader', 0.18464628940580272], ['Jiyuminsyu', 'Syakaiminsyu_Leader', 0.17391583763913523], ['Jiyuminsyu', 'Reiwa_Leader', 0.13270090775597385], ['Jiyuminsyu', 'Jiyuminsyu_Suga', 0.371520824989988], ['Jiyuminsyu', 'Jiyuminsyu_Kono', 0.5257308770524629], ['Jiyuminsyu', 'Rikkenminsyu_Edano', 0.16218461839232767], ['Jiyuminsyu', 'Rikkenminsyu_Renho', 0.22013916700040048], ['Jiyuminsyu', 'Ishin_Yoshimura', 0.25086353624349217], ['Jiyuminsyu', 'Ishin_Hashimoto', 0.4426144706981711], ['Rikkenminsyu', 'Komei', 0.1467564932871331], ['Rikkenminsyu', 'Kyosan', 0.44175137437937567], ['Rikkenminsyu', 'Ishin', 0.19959266802443992], ['Rikkenminsyu', 'Kokuminminsyu', 0.40721342969536184], ['Rikkenminsyu', 'Syakaiminsyu', 0.646084803466419], ['Rikkenminsyu', 'Reiwa', 0.31285832730608426], ['Rikkenminsyu', 'Jiyuminsyu_Leader', 0.12769171467563992], ['Rikkenminsyu', 'Rikkenminsyu_Leader', 0.5301789178702306], ['Rikkenminsyu', 'Komei_Leader', 0.12508169934640523], ['Rikkenminsyu', 'Kyosan_Leader', 0.31186385940055633], ['Rikkenminsyu', 'Ishin_Leader', 0.11459125524799717], ['Rikkenminsyu', 'Kokuminminsyu_Leader', 0.19057912885851505], ['Rikkenminsyu', 'Syakaiminsyu_Leader', 0.32164102136703165], ['Rikkenminsyu', 'Reiwa_Leader', 0.39714446446988716], ['Rikkenminsyu', 'Jiyuminsyu_Suga', 0.13693235683255373], ['Rikkenminsyu', 'Jiyuminsyu_Kono', 0.284131515069435], ['Rikkenminsyu', 'Rikkenminsyu_Edano', 0.5612516427539617], ['Rikkenminsyu', 'Rikkenminsyu_Renho', 0.3353509256268947], ['Rikkenminsyu', 'Ishin_Yoshimura', 0.14161518507328966], ['Rikkenminsyu', 'Ishin_Hashimoto', 0.2530654554167665], ['Komei', 'Kyosan', 0.16299091760209253], ['Komei', 'Ishin', 0.14713324692958094], ['Komei', 'Kokuminminsyu', 0.1723081145366389], ['Komei', 'Syakaiminsyu', 0.28060750762700626], ['Komei', 'Reiwa', 0.054793595027363015], ['Komei', 'Jiyuminsyu_Leader', 0.10576505448473558], ['Komei', 'Rikkenminsyu_Leader', 0.12657181863907452], ['Komei', 'Komei_Leader', 0.6101919934640523], ['Komei', 'Kyosan_Leader', 0.1029177565222427], ['Komei', 'Ishin_Leader', 0.13443107125966391], ['Komei', 'Kokuminminsyu_Leader', 0.11255031030721863], ['Komei', 'Syakaiminsyu_Leader', 0.20586446861698535], ['Komei', 'Reiwa_Leader', 0.14972926539712567], ['Komei', 'Jiyuminsyu_Suga', 0.15717084752960708], ['Komei', 'Jiyuminsyu_Kono', 0.3189552829442026], ['Komei', 'Rikkenminsyu_Edano', 0.12106324862219735], ['Komei', 'Rikkenminsyu_Renho', 0.23502273012441244], ['Komei', 'Ishin_Yoshimura', 0.13670890962965823], ['Komei', 'Ishin_Hashimoto', 0.33602941886165993], ['Kyosan', 'Ishin', 0.16213046966611122], ['Kyosan', 'Kokuminminsyu', 0.2989205013265026], ['Kyosan', 'Syakaiminsyu', 0.7514259185568378], ['Kyosan', 'Reiwa', 0.2641346340430787], ['Kyosan', 'Jiyuminsyu_Leader', 0.11138346359265118], ['Kyosan', 'Rikkenminsyu_Leader', 0.32776460444061223], ['Kyosan', 'Komei_Leader', 0.12996323529411766], ['Kyosan', 'Kyosan_Leader', 0.5393675505505349], ['Kyosan', 'Ishin_Leader', 0.12206524973765408], ['Kyosan', 'Kokuminminsyu_Leader', 0.19675160931602112], ['Kyosan', 'Syakaiminsyu_Leader', 0.4012874528168904], ['Kyosan', 'Reiwa_Leader', 0.4484235751092455], ['Kyosan', 'Jiyuminsyu_Suga', 0.14212100803483327], ['Kyosan', 'Jiyuminsyu_Kono', 0.25133522326812535], ['Kyosan', 'Rikkenminsyu_Edano', 0.3836750356320579], ['Kyosan', 'Rikkenminsyu_Renho', 0.3349883314799442], [ ...

# %%
import csv
f = open('Simpson_②&③.csv', 'w')
data = a_b_s
writer = csv.writer(f)
writer.writerow(data)
f.close()

# %%
sum_engname_list1 = [['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa'],['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']]
color_list10 = ['burlywood', 'blue', 'lime', 'yellow', 'aqua', 'coral', 'red', 'fuchsia', 'bisque', 'lightcoral', 'lightyellow', 'turquoise', 'lavender', 'olive', 'salmon', 'lightskyblue', 'chocolate', 'sateblue', 'palegreen', 'grey']
#セクション4.2.1 
#グラフリスト 
#Simpson係数

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 0

Simpson係数 = 0.5

matrix_cons = []
for i in range(len(matrix_s)):
  if matrix_s[i][2] >= Simpson係数 and matrix_s[i][2] != 1:
    matrix_cons.append(matrix_s[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_cons) #ここに三次元リストを入れて実行！

  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))    #
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))  #
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)                                                                         #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_cons)):
    node_list_del.append(matrix_cons[i][0])
    node_list_del.append(matrix_cons[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/800)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/800) for i in sum_list]

H.add_weighted_edges_from(matrix_cons)
edge_width = [d["weight"] * 5  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = media, BLUE = political party, LIME = politician')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(21,14))
plt.title('Simpson index Threshold:{}'.format(Simpson係数))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# Number of communities in decomposed G: 3
# Modularity of decomposed G: 0.4716718253251202
# Identified components: [{'Ishin_Yoshimura', 'Kokuminminsyu', 'Kokuminminsyu_Leader', 'Jiyuminsyu_Kono', 'Ishin', 'Jiyuminsyu_Suga', 'Ishin_Hashimoto', 'Jiyuminsyu_Leader', 'Jiyuminsyu', 'Ishin_Leader'}, {'Reiwa_Leader', 'Kyosan_Leader', 'Rikkenminsyu_Leader', 'Reiwa', 'Rikkenminsyu_Renho', 'Syakaiminsyu_Leader', 'Kyosan', 'Rikkenminsyu_Edano', 'Rikkenminsyu', 'Syakaiminsyu'}, {'Komei_Leader', 'Komei'}]
# Number of communities in decomposed G: 4
# Modularity of decomposed G: 0.5372481973190275
# Identified components: [{'Kokuminminsyu', 'Kokuminminsyu_Leader', 'Jiyuminsyu_Kono', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Leader', 'Jiyuminsyu'}, {'Reiwa_Leader', 'Kyosan_Leader', 'Rikkenminsyu_Leader', 'Reiwa', 'Rikkenminsyu_Renho', 'Syakaiminsyu_Leader', 'Kyosan', 'Rikkenminsyu_Edano', 'Rikkenminsyu', 'Syakaiminsyu'}, {'Komei_Leader', 'Komei'}, {'Ishin', 'Ishin_Yoshimura', 'Ishin_Hashimoto', 'Ishin_Leader'}]
# Number of communities in decomposed G: 5
# Modularity of decomposed G: 0.5469873687456722
# Identified components: [{'Kokuminminsyu', 'Kokuminminsyu_Leader', 'Jiyuminsyu_Kono', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Leader', 'Jiyuminsyu'}, {'Kyosan_Leader', 'Rikkenminsyu_Leader', 'Rikkenminsyu_Renho', 'Syakaiminsyu_Leader', 'Kyosan', 'Rikkenminsyu_Edano', 'Rikkenminsyu', 'Syakaiminsyu'}, {'Komei_Leader', 'Komei'}, {'Ishin', 'Ishin_Yoshimura', 'Ishin_Hashimoto', 'Ishin_Leader'}, {'Reiwa_Leader', 'Reiwa'}]
# Number of communities in decomposed G: 6
# Modularity of decomposed G: 0.5319331624092256
# Number of communities in decomposed G: 9
# Modularity of decomposed G: 0.4632825866247732
# Number of communities in decomposed G: 11
# Modularity of decomposed G: 0.3749727705299871
# Number of communities in decomposed G: 14
# Modularity of decomposed G: 0.2080357133636199
# Number of communities in decomposed G: 22
# Modularity of decomposed G: -0.06236722358388819
# Max modularity found (Q): 0.5469873687456722 and number of communities: 5
# Graph communities: [{'Kokuminminsyu', 'Kokuminminsyu_Leader', 'Jiyuminsyu_Kono', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Leader', 'Jiyuminsyu'}, {'Kyosan_Leader', 'Rikkenminsyu_Leader', 'Rikkenminsyu_Renho', 'Syakaiminsyu_Leader', 'Kyosan', 'Rikkenminsyu_Edano', 'Rikkenminsyu', 'Syakaiminsyu'}, {'Komei_Leader', 'Komei'}, {'Ishin', 'Ishin_Yoshimura', 'Ishin_Hashimoto', 'Ishin_Leader'}, {'Reiwa_Leader', 'Reiwa'}]
# note : nodes in color gray are not in any community as it have no edges

# %%
#セクション4.4 ② 重複なし
#グラフリスト Simpson係数の拡張

# if csv is ready, data_import = 1, otherwise 0
data_import = 0

import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa', 'Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
matrix_sk = [[0]*3 for i in range(len(sum_engname_list)**2)]

if data_import == 1:
  filename = 'Simpsonk_②&③.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_skt=[]
      for row in csvreader:
        a_b_skt += row
  a_b_sk = []
  for i in a_b_skt:
    a_b_sk.append(float(i))

if data_import == 0:
  a_b_sk = []
  for a in sum_list:
    for b in sum_list:
      if a == b:
        a_b_sk.append(1)
      else:
        a_b_sk.append(len(set(a) & set(b))/(len(a)-1))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        matrix_sk[i+k][n] = sum_engname_list[k//22]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        matrix_sk[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 22):
      for i in range(22):
        t += 1
        matrix_sk[i+k][n] = a_b_sk[t]

print(matrix_sk)
# Out:
# [['Jiyuminsyu', 'Jiyuminsyu', 1], ['Jiyuminsyu', 'Rikkenminsyu', 0.1388], ['Jiyuminsyu', 'Komei', 0.1771], ['Jiyuminsyu', 'Kyosan', 0.1163], ['Jiyuminsyu', 'Ishin', 0.1078], ['Jiyuminsyu', 'Kokuminminsyu', 0.0642], ['Jiyuminsyu', 'Syakaiminsyu', 0.074], ['Jiyuminsyu', 'Reiwa', 0.0439], ['Jiyuminsyu', 'Jiyuminsyu_Leader', 0.2245], ['Jiyuminsyu', 'Rikkenminsyu_Leader', 0.03], ['Jiyuminsyu', 'Komei_Leader', 0.0565], ['Jiyuminsyu', 'Kyosan_Leader', 0.0931], ['Jiyuminsyu', 'Ishin_Leader', 0.2301], ['Jiyuminsyu', 'Kokuminminsyu_Leader', 0.1687], ['Jiyuminsyu', 'Syakaiminsyu_Leader', 0.1693], ['Jiyuminsyu', 'Reiwa_Leader', 0.1327], ['Jiyuminsyu', 'Jiyuminsyu_Suga', 0.3715], ['Jiyuminsyu', 'Jiyuminsyu_Kono', 0.5257], ['Jiyuminsyu', 'Rikkenminsyu_Edano', 0.1246], ['Jiyuminsyu', 'Rikkenminsyu_Renho', 0.2201], ['Jiyuminsyu', 'Ishin_Yoshimura', 0.2509], ['Jiyuminsyu', 'Ishin_Hashimoto', 0.4426], ['Rikkenminsyu', 'Jiyuminsyu', 0.1734], ['Rikkenminsyu', 'Rikkenminsyu', 1], ['Rikkenminsyu', 'Komei', 0.0792], ['Rikkenminsyu', 'Kyosan', 0.2938], ['Rikkenminsyu', 'Ishin', 0.0674], ['Rikkenminsyu', 'Kokuminminsyu', 0.0927], ['Rikkenminsyu', 'Syakaiminsyu', 0.1522], ['Rikkenminsyu', 'Reiwa', 0.1848], ['Rikkenminsyu', 'Jiyuminsyu_Leader', 0.1277], ['Rikkenminsyu', 'Rikkenminsyu_Leader', 0.0769], ['Rikkenminsyu', 'Komei_Leader', 0.0319], ['Rikkenminsyu', 'Kyosan_Leader', 0.3119], ['Rikkenminsyu', 'Ishin_Leader', 0.1146], ['Rikkenminsyu', 'Kokuminminsyu_Leader', 0.1906], ['Rikkenminsyu', 'Syakaiminsyu_Leader', 0.3216], ['Rikkenminsyu', 'Reiwa_Leader', 0.3971], ['Rikkenminsyu', 'Jiyuminsyu_Suga', 0.1369], ['Rikkenminsyu', 'Jiyuminsyu_Kono', 0.2841], ['Rikkenminsyu', 'Rikkenminsyu_Edano', 0.5383], ['Rikkenminsyu', 'Rikkenminsyu_Renho', 0.3354], ['Rikkenminsyu', 'Ishin_Yoshimura', 0.1416], ['Rikkenminsyu', 'Ishin_Hashimoto', 0.2531], ['Komei', 'Jiyuminsyu', 0.4097], ['Komei', 'Rikkenminsyu', 0.1468], ['Komei', 'Komei', 1], ['Komei', 'Kyosan', 0.163], ['Komei', 'Ishin', 0.092], ['Komei', 'Kokuminminsyu', 0.0727], ['Komei', 'Syakaiminsyu', 0.1225], ['Komei', 'Reiwa', 0.0548], ['Komei', 'Jiyuminsyu_Leader', 0.1058], ['Komei', 'Rikkenminsyu_Leader', 0.034], ['Komei', 'Komei_Leader', 0.2883], ['Komei', 'Kyosan_Leader', 0.1029], ['Komei', 'Ishin_Leader', 0.1344], ['Komei', 'Kokuminminsyu_Leader', 0.1126], ['Komei', 'Syakaiminsyu_Leader', 0.2059], ['Komei', 'Reiwa_Leader', 0.1497], ['Komei', 'Jiyuminsyu_Suga', 0.1572], ['Komei', 'Jiyuminsyu_Kono', 0.319], ['Komei', 'Rikkenminsyu_Edano', 0.1211], ['Komei', 'Rikkenminsyu_Renho', 0.235], ['Komei', 'Ishin_Yoshimura', 0.1367], ['Komei', 'Ishin_Hashimoto', 0.336], ['Kyosan', 'Jiyuminsyu', 0.2184], ['Kyosan', 'Rikkenminsyu', 0.4418], ['Kyosan', 'Komei', 0.1322], ['Kyosan', 'Kyosan', 1], ['Kyosan', 'Ishin', 0.0823], ['Kyosan', 'Kokuminminsyu', 0.1024], ['Kyosan', 'Syakaiminsyu', 0.2662], ['Kyosan', 'Reiwa', 0.2345], ['Kyosan', 'Jiyuminsyu_Leader', 0.1114], ['Kyosan', 'Rikkenminsyu_Leader', 0.0714], ['Kyosan', 'Komei_Leader', 0.0498], ['Kyosan', 'Kyosan_Leader', 0.5394], ['Kyosan', 'Ishin_Leader', 0.1221], ['Kyosan', 'Kokuminminsyu_Leader', 0.1968], ['Kyosan', 'Syakaiminsyu_Leader', 0.4013], ['Kyosan', 'Reiwa_Leader', 0.4484], ['Kyosan', 'Jiyuminsyu_Suga', 0.1421], ['Kyosan', 'Jiyuminsyu_Kono', 0.2513], ['Kyosan', 'Rikkenminsyu_Edano', 0.3837], ['Kyosan', 'Rikkenminsyu_Renho', 0.335], ['Kyosan', 'Ishin_Yoshimura', 0.1325], ['Kyosan', 'Ishin_Hashimoto', 0.2301], ['Ishin', 'Jiyuminsyu', 0.3986], ['Ishin', 'Rikkenminsyu', 0.1996], ['Ishin', 'Komei', 0.1471], ['Ishin', 'Kyosan', 0.1621], ['Ishin', 'Ishin', 1], ['Ishin', 'Kokuminminsyu', 0.1508], ['Ishin', 'Syakaiminsyu', 0.1144], ['Ishin', 'Reiwa', 0.0848], ['Ishin', 'Jiyuminsyu_Leader', 0.2519], ['Ishin', 'Rikkenminsyu_Leader', 0.065], ['Ishin', 'Komei_Leader', 0.0594], ['Ishin', 'Kyosan_Leader', 0.1299], ['Ishin', 'Ishin_Leader', 0.7172], ['Ishin', 'Kokuminminsyu_Leader', 0.2767], ['Ishin', 'Syakaiminsyu_Leader', 0.1605], ['Ishin', 'Reiwa_Leader', 0.1672], ['Ishin', 'Ji ...

# %%
import csv
f = open('Simpsonk_②&③.csv', 'w')
data = a_b_sk
writer = csv.writer(f)
writer.writerow(data)
f.close()

# %%
sum_engname_list1 = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']
sum_engname_list2 = ['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa']
sum_engname_list3 = ['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']

#セクション4.3.3
#グラフリスト 
Simpson係数の拡張 = 0.4

matrix_con = []
for i in range(len(matrix_sk)):
  if matrix_sk[i][2] >= Simpson係数の拡張 and matrix_sk[i][2] != 1:
    matrix_con.append(matrix_sk[i])

H = nx.DiGraph()
for n in sum_engname_list:
    H.add_node(n)
size =[((len(i)-1)/800) for i in sum_list]
H.add_weighted_edges_from(matrix_con)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]

c = []
for i in H.nodes():
  if i in sum_engname_list1:
    c.append('blue')
  elif i in sum_engname_list2:
    c.append('green')
  else:
    c.append('red')


pos = nx.spring_layout(H, k=0.7) 
# pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(12,8))
plt.title('Enhanced Simpson index Threshold:{}'.format(Simpson係数の拡張))
nx.draw_networkx(H, pos,node_size = size, node_color=c, arrows=True, width=[v['weight'] * 7 for v in H.edges.values()], connectionstyle="arc3, rad=0.1")

# %%
#セクション4.4 ②
#グラフリスト Simpson係数の拡張2nd 重み付き有向グラフを重み付き無向グラフに変換

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt
sum_engname_list = ['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa', 'Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_sk2 = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Simpsonk2_②&③.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_sk2t=[]
      for row in csvreader:
        a_b_sk2t += row
  a_b_sk2 = []
  for i in a_b_sk2t:
    a_b_sk2.append(float(i))

if data_import == 0:
  a_b_sk2 = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_sk2.append(((len(set(a) & set(b))/(len(a)-1))+((len(set(a) & set(b)))/(len(b)-1)))/2)


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_sk2[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_sk2[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_sk2[e][2] = a_b_sk2[e]
      
print(matrix_sk2)
# Out:
# [['Jiyuminsyu', 'Rikkenminsyu', 0.15610730255780975], ['Jiyuminsyu', 'Komei', 0.29339060440981757], ['Jiyuminsyu', 'Kyosan', 0.16733834931931213], ['Jiyuminsyu', 'Ishin', 0.25317520790732995], ['Jiyuminsyu', 'Kokuminminsyu', 0.20822653607040612], ['Jiyuminsyu', 'Syakaiminsyu', 0.23319928801151116], ['Jiyuminsyu', 'Reiwa', 0.06843555558930553], ['Jiyuminsyu', 'Jiyuminsyu_Leader', 0.1643397746386412], ['Jiyuminsyu', 'Rikkenminsyu_Leader', 0.14401539994504867], ['Jiyuminsyu', 'Komei_Leader', 0.16667824510327425], ['Jiyuminsyu', 'Kyosan_Leader', 0.10094649837450946], ['Jiyuminsyu', 'Ishin_Leader', 0.1798158888641592], ['Jiyuminsyu', 'Kokuminminsyu_Leader', 0.17668270951400802], ['Jiyuminsyu', 'Syakaiminsyu_Leader', 0.171628273244878], ['Jiyuminsyu', 'Reiwa_Leader', 0.1007758921232311], ['Jiyuminsyu', 'Jiyuminsyu_Suga', 0.26735271666356936], ['Jiyuminsyu', 'Jiyuminsyu_Kono', 0.28850597378237436], ['Jiyuminsyu', 'Rikkenminsyu_Edano', 0.14338581139880702], ['Jiyuminsyu', 'Rikkenminsyu_Renho', 0.16003171188497584], ['Jiyuminsyu', 'Ishin_Yoshimura', 0.14922719746829474], ['Jiyuminsyu', 'Ishin_Hashimoto', 0.2409740742782308], ['Rikkenminsyu', 'Komei', 0.11297913841241507], ['Rikkenminsyu', 'Kyosan', 0.36779095873121864], ['Rikkenminsyu', 'Ishin', 0.13348769448060696], ['Rikkenminsyu', 'Kokuminminsyu', 0.2499792158634223], ['Rikkenminsyu', 'Syakaiminsyu', 0.3991578941333804], ['Rikkenminsyu', 'Reiwa', 0.24880954057123067], ['Rikkenminsyu', 'Jiyuminsyu_Leader', 0.08757430340240578], ['Rikkenminsyu', 'Rikkenminsyu_Leader', 0.3035235503414223], ['Rikkenminsyu', 'Komei_Leader', 0.07849059391473029], ['Rikkenminsyu', 'Kyosan_Leader', 0.30171980907846807], ['Rikkenminsyu', 'Ishin_Leader', 0.08314068183058984], ['Rikkenminsyu', 'Kokuminminsyu_Leader', 0.17880818017559943], ['Rikkenminsyu', 'Syakaiminsyu_Leader', 0.29309645903103043], ['Rikkenminsyu', 'Reiwa_Leader', 0.2810839797398839], ['Rikkenminsyu', 'Jiyuminsyu_Suga', 0.09255046609378488], ['Rikkenminsyu', 'Jiyuminsyu_Kono', 0.1531637569365523], ['Rikkenminsyu', 'Rikkenminsyu_Edano', 0.5497972889409726], ['Rikkenminsyu', 'Rikkenminsyu_Renho', 0.22862982751710198], ['Rikkenminsyu', 'Ishin_Yoshimura', 0.081565492888264], ['Rikkenminsyu', 'Ishin_Hashimoto', 0.13553813803538292], ['Komei', 'Kyosan', 0.14761837765392893], ['Komei', 'Ishin', 0.11958668002467542], ['Komei', 'Kokuminminsyu', 0.12251260447072856], ['Komei', 'Syakaiminsyu', 0.20155926743709998], ['Komei', 'Reiwa', 0.052433402026179965], ['Komei', 'Jiyuminsyu_Leader', 0.06348937687831996], ['Komei', 'Rikkenminsyu_Leader', 0.08028765630574475], ['Komei', 'Komei_Leader', 0.4492706181379157], ['Komei', 'Kyosan_Leader', 0.07742363845904086], ['Komei', 'Ishin_Leader', 0.0835785482662883], ['Komei', 'Kokuminminsyu_Leader', 0.08289418864140807], ['Komei', 'Syakaiminsyu_Leader', 0.1486230048970808], ['Komei', 'Reiwa_Leader', 0.09165312133416399], ['Komei', 'Jiyuminsyu_Suga', 0.09350434268372246], ['Komei', 'Jiyuminsyu_Kono', 0.16620109992505072], ['Komei', 'Rikkenminsyu_Edano', 0.09458957958474618], ['Komei', 'Rikkenminsyu_Renho', 0.1405657108300532], ['Komei', 'Ishin_Yoshimura', 0.07395915193405278], ['Komei', 'Ishin_Hashimoto', 0.17446806473071869], ['Kyosan', 'Ishin', 0.12221047266725299], ['Kyosan', 'Kokuminminsyu', 0.20063728325679525], ['Kyosan', 'Syakaiminsyu', 0.5088045689076889], ['Kyosan', 'Reiwa', 0.24932419674963935], ['Kyosan', 'Jiyuminsyu_Leader', 0.06945895413362689], ['Kyosan', 'Rikkenminsyu_Leader', 0.19960441915610577], ['Kyosan', 'Komei_Leader', 0.08989664889363266], ['Kyosan', 'Kyosan_Leader', 0.43739425955469236], ['Kyosan', 'Ishin_Leader', 0.07934467814025474], ['Kyosan', 'Kokuminminsyu_Leader', 0.15572736947641858], ['Kyosan', 'Syakaiminsyu_Leader', 0.31041382657724975], ['Kyosan', 'Reiwa_Leader', 0.2861808230579528], ['Kyosan', 'Jiyuminsyu_Suga', 0.08768716457628059], ['Kyosan', 'Jiyuminsyu_Kono', 0.13219737849204727], ['Kyosan', 'Rikkenminsyu_Edano', 0.32486800515731995], ['Kyosan', 'Rikkenminsyu_Renho', 0.20799407106 ...

# %%
import csv
f = open('Simpsonk2_②&③.csv', 'w')
data = a_b_sk2
writer = csv.writer(f)
writer.writerow(data)
f.close()

# %%
sum_engname_list1 = [['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa'],['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']]
color_list10 = ['burlywood', 'salmon', 'lime', 'yellow', 'aqua', 'coral', 'red', 'fuchsia', 'bisque', 'lightcoral', 'lightyellow', 'turquoise', 'lavender', 'olive', 'blue', 'lightskyblue', 'chocolate', 'sateblue', 'palegreen', 'grey']
# color_list10 = ['salmon', 'salmon','salmon', 'salmon','salmon', 'salmon']
#セクション4.2.1 
#グラフリスト 
#Simpson係数の拡張2

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 0

Simpson係数の拡張2 = 0.25

matrix_consk2 = []
for i in range(len(matrix_sk2)):
  if matrix_sk2[i][2] >= Simpson係数の拡張2 and matrix_sk2[i][2] != 1:
    matrix_consk2.append(matrix_sk2[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_consk2) #ここに三次元リストを入れて実行！
    
  if _DEBUG_:
    print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)      
                                                                                                              #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_consk2)):
    node_list_del.append(matrix_consk2[i][0])
    node_list_del.append(matrix_consk2[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてsum_engname_listの順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/800)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/800) for i in sum_list]

H.add_weighted_edges_from(matrix_consk2)
edge_width = [d["weight"] * 5  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = politician, BROWN = political party')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(18,12))
plt.title('Enhanced Simpson index 2nd Threshold:{}'.format(Simpson係数の拡張2))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# Number of communities in decomposed G: 3
# Modularity of decomposed G: 0.45532127420037016
# Identified components: [{'Jiyuminsyu', 'Jiyuminsyu_Suga', 'Komei', 'Komei_Leader', 'Jiyuminsyu_Kono', 'Ishin_Leader', 'Jiyuminsyu_Leader', 'Ishin_Yoshimura', 'Ishin_Hashimoto', 'Ishin'}, {'Kyosan_Leader', 'Kyosan', 'Rikkenminsyu_Leader', 'Syakaiminsyu', 'Rikkenminsyu', 'Rikkenminsyu_Renho', 'Reiwa_Leader', 'Reiwa', 'Syakaiminsyu_Leader', 'Rikkenminsyu_Edano'}, {'Kokuminminsyu_Leader', 'Kokuminminsyu'}]
# Number of communities in decomposed G: 4
# Modularity of decomposed G: 0.4426238500712921
# Number of communities in decomposed G: 5
# Modularity of decomposed G: 0.4650983251350688
# Identified components: [{'Jiyuminsyu', 'Jiyuminsyu_Kono', 'Jiyuminsyu_Leader', 'Jiyuminsyu_Suga'}, {'Komei', 'Komei_Leader'}, {'Ishin_Yoshimura', 'Ishin_Leader', 'Ishin_Hashimoto', 'Ishin'}, {'Kyosan_Leader', 'Kyosan', 'Rikkenminsyu_Leader', 'Syakaiminsyu', 'Rikkenminsyu', 'Rikkenminsyu_Renho', 'Reiwa_Leader', 'Reiwa', 'Syakaiminsyu_Leader', 'Rikkenminsyu_Edano'}, {'Kokuminminsyu_Leader', 'Kokuminminsyu'}]
# Number of communities in decomposed G: 6
# Modularity of decomposed G: 0.44718011771955585
# Number of communities in decomposed G: 7
# Modularity of decomposed G: 0.4168791154537695
# Number of communities in decomposed G: 8
# Modularity of decomposed G: 0.401786017316703
# Number of communities in decomposed G: 11
# Modularity of decomposed G: 0.3242292871150875
# Number of communities in decomposed G: 22
# Modularity of decomposed G: -0.05686549598270196
# Max modularity found (Q): 0.4650983251350688 and number of communities: 5
# Graph communities: [{'Jiyuminsyu', 'Jiyuminsyu_Kono', 'Jiyuminsyu_Leader', 'Jiyuminsyu_Suga'}, {'Komei', 'Komei_Leader'}, {'Ishin_Yoshimura', 'Ishin_Leader', 'Ishin_Hashimoto', 'Ishin'}, {'Kyosan_Leader', 'Kyosan', 'Rikkenminsyu_Leader', 'Syakaiminsyu', 'Rikkenminsyu', 'Rikkenminsyu_Renho', 'Reiwa_Leader', 'Reiwa', 'Syakaiminsyu_Leader', 'Rikkenminsyu_Edano'}, {'Kokuminminsyu_Leader', 'Kokuminminsyu'}]
# note : nodes in color gray are not in any community as it have no edges
