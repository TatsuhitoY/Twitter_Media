# %%
#セクション1 ①
import csv

filename = '1.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    現代ビジネス_lists=[]
    for row in csvreader:
      現代ビジネス_lists += row

    print('データ取得終了時刻：', 現代ビジネス_lists[-2])
    del 現代ビジネス_lists[-1]
    del 現代ビジネス_lists[-1]

    unique_set = set(現代ビジネス_lists)
    現代ビジネス_list = list(unique_set)
    現代ビジネス_list.append('現代ビジネス')

    print('現代ビジネスのフォロワー数：', len(現代ビジネス_list)-1)
    print('\n')

filename = '2.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    沖縄タイムス_lists=[]
    for row in csvreader:
      沖縄タイムス_lists += row

    print('データ取得終了時刻：', 沖縄タイムス_lists[-2])
    del 沖縄タイムス_lists[-1]
    del 沖縄タイムス_lists[-1]

    unique_set = set(沖縄タイムス_lists)
    沖縄タイムス_list = list(unique_set)
    沖縄タイムス_list.append('沖縄タイムス')
        
    print('沖縄タイムスのフォロワー数：', len(沖縄タイムス_list)-1)
    print('\n')
    
filename = '3.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    毎日新聞_lists=[]
    for row in csvreader:
      毎日新聞_lists += row

    print('データ取得終了時刻：', 毎日新聞_lists[-2])
    del 毎日新聞_lists[-1]
    del 毎日新聞_lists[-1]

    unique_set = set(毎日新聞_lists)
    毎日新聞_list = list(unique_set)
    毎日新聞_list.append('毎日新聞')
        
    print('毎日新聞のフォロワー数：', len(毎日新聞_list)-1)
    print('\n')
    
filename = '4.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    朝日新聞_lists=[]
    for row in csvreader:
      朝日新聞_lists += row

    print('データ取得終了時刻：', 朝日新聞_lists[-2])
    del 朝日新聞_lists[-1]
    del 朝日新聞_lists[-1]

    unique_set = set(朝日新聞_lists)
    朝日新聞_list = list(unique_set)
    朝日新聞_list.append('朝日新聞')
        
    print('朝日新聞のフォロワー数：', len(朝日新聞_list)-1)
    print('\n')
    
filename = '5.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    時事ドットコム_lists=[]
    for row in csvreader:
      時事ドットコム_lists += row

    print('データ取得終了時刻：', 時事ドットコム_lists[-2])
    del 時事ドットコム_lists[-1]
    del 時事ドットコム_lists[-1]

    unique_set = set(時事ドットコム_lists)
    時事ドットコム_list = list(unique_set)
    時事ドットコム_list.append('時事ドットコム')
        
    print('時事ドットコムのフォロワー数：', len(時事ドットコム_list)-1)
    print('\n')
    
filename = '6.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本経済新聞_lists=[]
    for row in csvreader:
      日本経済新聞_lists += row

    print('データ取得終了時刻：', 日本経済新聞_lists[-2])
    del 日本経済新聞_lists[-1]
    del 日本経済新聞_lists[-1]

    unique_set = set(日本経済新聞_lists)
    日本経済新聞_list = list(unique_set)
    日本経済新聞_list.append('日本経済新聞')
        
    print('日本経済新聞のフォロワー数：', len(日本経済新聞_list)-1)
    print('\n')
    
filename = '7.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    産経ニュース_lists=[]
    for row in csvreader:
      産経ニュース_lists += row

    print('データ取得終了時刻：', 産経ニュース_lists[-2])
    del 産経ニュース_lists[-1]
    del 産経ニュース_lists[-1]

    unique_set = set(産経ニュース_lists)
    産経ニュース_list = list(unique_set)
    産経ニュース_list.append('産経ニュース')
        
    print('産経ニュースのフォロワー数：', len(産経ニュース_list)-1)
    print('\n')
    
filename = '8.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    東京新聞_lists=[]
    for row in csvreader:
      東京新聞_lists += row

    print('データ取得終了時刻：', 東京新聞_lists[-2])
    del 東京新聞_lists[-1]
    del 東京新聞_lists[-1]

    unique_set = set(東京新聞_lists)
    東京新聞_list = list(unique_set)
    東京新聞_list.append('東京新聞')
        
    print('東京新聞のフォロワー数：', len(東京新聞_list)-1)
    print('\n')
    
filename = '9.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    読売新聞オンライン_lists=[]
    for row in csvreader:
      読売新聞オンライン_lists += row

    print('データ取得終了時刻：', 読売新聞オンライン_lists[-2])
    del 読売新聞オンライン_lists[-1]
    del 読売新聞オンライン_lists[-1]

    unique_set = set(読売新聞オンライン_lists)
    読売新聞オンライン_list = list(unique_set)
    読売新聞オンライン_list.append('読売新聞オンライン')
        
    print('読売新聞オンラインのフォロワー数：', len(読売新聞オンライン_list)-1)
    print('\n')
    
filename = '10.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    zakzak_lists=[]
    for row in csvreader:
      zakzak_lists += row

    print('データ取得終了時刻：', zakzak_lists[-2])
    del zakzak_lists[-1]
    del zakzak_lists[-1]

    unique_set = set(zakzak_lists)
    zakzak_list = list(unique_set)
    zakzak_list.append('zakzak')
        
    print('zakzakのフォロワー数：', len(zakzak_list)-1)
    print('\n')
    
filename = '11.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    NHKニュース_lists=[]
    for row in csvreader:
      NHKニュース_lists += row

    print('データ取得終了時刻：', NHKニュース_lists[-2])
    del NHKニュース_lists[-1]
    del NHKニュース_lists[-1]

    unique_set = set(NHKニュース_lists)
    NHKニュース_list = list(unique_set)
    NHKニュース_list.append('NHKニュース')
        
    print('NHKニュースのフォロワー数：', len(NHKニュース_list)-1)
    print('\n')
    
filename = '12.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    しんぶん赤旗_lists=[]
    for row in csvreader:
      しんぶん赤旗_lists += row

    print('データ取得終了時刻：', しんぶん赤旗_lists[-2])
    del しんぶん赤旗_lists[-1]
    del しんぶん赤旗_lists[-1]

    unique_set = set(しんぶん赤旗_lists)
    しんぶん赤旗_list = list(unique_set)
    しんぶん赤旗_list.append('しんぶん赤旗')
        
    print('しんぶん赤旗のフォロワー数：', len(しんぶん赤旗_list)-1)
    print('\n')
    
filename = '13.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日刊ゲンダイ_lists=[]
    for row in csvreader:
      日刊ゲンダイ_lists += row

    print('データ取得終了時刻：', 日刊ゲンダイ_lists[-2])
    del 日刊ゲンダイ_lists[-1]
    del 日刊ゲンダイ_lists[-1]

    unique_set = set(日刊ゲンダイ_lists)
    日刊ゲンダイ_list = list(unique_set)
    日刊ゲンダイ_list.append('日刊ゲンダイ')
        
    print('日刊ゲンダイのフォロワー数：', len(日刊ゲンダイ_list)-1)
    print('\n')
    
filename = '14.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    アゴラ_lists=[]
    for row in csvreader:
      アゴラ_lists += row

    print('データ取得終了時刻：', アゴラ_lists[-2])
    del アゴラ_lists[-1]
    del アゴラ_lists[-1]

    unique_set = set(アゴラ_lists)
    アゴラ_list = list(unique_set)
    アゴラ_list.append('アゴラ')
        
    print('アゴラのフォロワー数：', len(アゴラ_list)-1)
    print('\n')
    
filename = '15.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    アノニマス_ポスト_lists=[]
    for row in csvreader:
      アノニマス_ポスト_lists += row

    print('データ取得終了時刻：', アノニマス_ポスト_lists[-2])
    del アノニマス_ポスト_lists[-1]
    del アノニマス_ポスト_lists[-1]

    unique_set = set(アノニマス_ポスト_lists)
    アノニマス_ポスト_list = list(unique_set)
    アノニマス_ポスト_list.append('アノニマス_ポスト')
        
    print('アノニマス_ポストのフォロワー数：', len(アノニマス_ポスト_list)-1)
    print('\n')
    
filename = '16.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    ハム速_lists=[]
    for row in csvreader:
      ハム速_lists += row

    print('データ取得終了時刻：', ハム速_lists[-2])
    del ハム速_lists[-1]
    del ハム速_lists[-1]

    unique_set = set(ハム速_lists)
    ハム速_list = list(unique_set)
    ハム速_list.append('ハム速')
        
    print('ハム速のフォロワー数：', len(ハム速_list)-1)
    print('\n')
    
filename = '17.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    政治知新_lists=[]
    for row in csvreader:
      政治知新_lists += row

    print('データ取得終了時刻：', 政治知新_lists[-2])
    del 政治知新_lists[-1]
    del 政治知新_lists[-1]

    unique_set = set(政治知新_lists)
    政治知新_list = list(unique_set)
    政治知新_list.append('政治知新')
        
    print('政治知新のフォロワー数：', len(政治知新_list)-1)
    print('\n')
    
filename = '18.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    litera_lists=[]
    for row in csvreader:
      litera_lists += row

    print('データ取得終了時刻：', litera_lists[-2])
    del litera_lists[-1]
    del litera_lists[-1]

    unique_set = set(litera_lists)
    litera_list = list(unique_set)
    litera_list.append('litera')
        
    print('literaのフォロワー数：', len(litera_list)-1)
    print('\n')
    
filename = '19.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    Share_News_Japan_lists=[]
    for row in csvreader:
      Share_News_Japan_lists += row

    print('データ取得終了時刻：', Share_News_Japan_lists[-2])
    del Share_News_Japan_lists[-1]
    del Share_News_Japan_lists[-1]

    unique_set = set(Share_News_Japan_lists)
    Share_News_Japan_list = list(unique_set)
    Share_News_Japan_list.append('Share_News_Japan')
        
    print('Share_News_Japanのフォロワー数：', len(Share_News_Japan_list)-1)
    print('\n')
    
filename = '20.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    もえるあじあ_lists=[]
    for row in csvreader:
      もえるあじあ_lists += row

    print('データ取得終了時刻：', もえるあじあ_lists[-2])
    del もえるあじあ_lists[-1]
    del もえるあじあ_lists[-1]

    unique_set = set(もえるあじあ_lists)
    もえるあじあ_list = list(unique_set)
    もえるあじあ_list.append('もえるあじあ')
        
    print('もえるあじあのフォロワー数：', len(もえるあじあ_list)-1)
    print('\n')
    
filename = '21.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    BuzzFeed_Japan_lists=[]
    for row in csvreader:
      BuzzFeed_Japan_lists += row

    print('データ取得終了時刻：', BuzzFeed_Japan_lists[-2])
    del BuzzFeed_Japan_lists[-1]
    del BuzzFeed_Japan_lists[-1]

    unique_set = set(BuzzFeed_Japan_lists)
    BuzzFeed_Japan_list = list(unique_set)
    BuzzFeed_Japan_list.append('BuzzFeed_Japan')
        
    print('BuzzFeed_Japanのフォロワー数：', len(BuzzFeed_Japan_list)-1)
    print('\n')
    
filename = '22.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    Yahoo_ニュース_lists=[]
    for row in csvreader:
      Yahoo_ニュース_lists += row

    print('データ取得終了時刻：', Yahoo_ニュース_lists[-2])
    del Yahoo_ニュース_lists[-1]
    del Yahoo_ニュース_lists[-1]

    unique_set = set(Yahoo_ニュース_lists)
    Yahoo_ニュース_list = list(unique_set)
    Yahoo_ニュース_list.append('Yahoo_ニュース')
        
    print('Yahoo_ニュースのフォロワー数：', len(Yahoo_ニュース_list)-1)
    print('\n')

filename = '23.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_lists=[]
    for row in csvreader:
      自由民主党_lists += row

    print('データ取得終了時刻：', 自由民主党_lists[-2])
    del 自由民主党_lists[-1]
    del 自由民主党_lists[-1]

    unique_set = set(自由民主党_lists)
    自由民主党_list = list(unique_set)
    自由民主党_list.append('自由民主党')

    print('自由民主党のフォロワー数：', len(自由民主党_list)-1)
    print('\n')

filename = '24.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_lists=[]
    for row in csvreader:
      立憲民主党_lists += row

    print('データ取得終了時刻：', 立憲民主党_lists[-2])
    del 立憲民主党_lists[-1]
    del 立憲民主党_lists[-1]

    unique_set = set(立憲民主党_lists)
    立憲民主党_list = list(unique_set)
    立憲民主党_list.append('立憲民主党')

    print('立憲民主党のフォロワー数：', len(立憲民主党_list)-1)
    print('\n')

filename = '25.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    公明党_lists=[]
    for row in csvreader:
      公明党_lists += row

    print('データ取得終了時刻：', 公明党_lists[-2])
    del 公明党_lists[-1]
    del 公明党_lists[-1]

    unique_set = set(公明党_lists)
    公明党_list = list(unique_set)
    公明党_list.append('公明党')

    print('公明党のフォロワー数：', len(公明党_list)-1)
    print('\n')

filename = '26.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本共産党_lists=[]
    for row in csvreader:
      日本共産党_lists += row

    print('データ取得終了時刻：', 日本共産党_lists[-2])
    del 日本共産党_lists[-1]
    del 日本共産党_lists[-1]

    unique_set = set(日本共産党_lists)
    日本共産党_list = list(unique_set)
    日本共産党_list.append('日本共産党')

    print('日本共産党のフォロワー数：', len(日本共産党_list)-1)
    print('\n')

filename = '27.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_lists=[]
    for row in csvreader:
      日本維新の会_lists += row

    print('データ取得終了時刻：', 日本維新の会_lists[-2])
    del 日本維新の会_lists[-1]
    del 日本維新の会_lists[-1]

    unique_set = set(日本維新の会_lists)
    日本維新の会_list = list(unique_set)
    日本維新の会_list.append('日本維新の会')

    print('日本維新の会のフォロワー数：', len(日本維新の会_list)-1)
    print('\n')

filename = '28.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    国民民主党_lists=[]
    for row in csvreader:
      国民民主党_lists += row

    print('データ取得終了時刻：', 国民民主党_lists[-2])
    del 国民民主党_lists[-1]
    del 国民民主党_lists[-1]

    unique_set = set(国民民主党_lists)
    国民民主党_list = list(unique_set)
    国民民主党_list.append('国民民主党')

    print('国民民主党のフォロワー数：', len(国民民主党_list)-1)
    print('\n')

filename = '29.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    社会民主党_lists=[]
    for row in csvreader:
      社会民主党_lists += row

    print('データ取得終了時刻：', 社会民主党_lists[-2])
    del 社会民主党_lists[-1]
    del 社会民主党_lists[-1]

    unique_set = set(社会民主党_lists)
    社会民主党_list = list(unique_set)
    社会民主党_list.append('社会民主党')

    print('社会民主党のフォロワー数：', len(社会民主党_list)-1)
    print('\n')

filename = '30.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    れいわ新選組_lists=[]
    for row in csvreader:
      れいわ新選組_lists += row

    print('データ取得終了時刻：', れいわ新選組_lists[-2])
    del れいわ新選組_lists[-1]
    del れいわ新選組_lists[-1]

    unique_set = set(れいわ新選組_lists)
    れいわ新選組_list = list(unique_set)
    れいわ新選組_list.append('れいわ新選組')

    print('れいわ新選組のフォロワー数：', len(れいわ新選組_list)-1)
    print('\n')

sum_list = [現代ビジネス_list, 沖縄タイムス_list, 毎日新聞_list, 朝日新聞_list, 時事ドットコム_list, 日本経済新聞_list, 産経ニュース_list, 東京新聞_list, 読売新聞オンライン_list, zakzak_list, NHKニュース_list, しんぶん赤旗_list, 日刊ゲンダイ_list, アゴラ_list, アノニマス_ポスト_list, ハム速_list, 政治知新_list, litera_list, Share_News_Japan_list, もえるあじあ_list, BuzzFeed_Japan_list, Yahoo_ニュース_list, 自由民主党_list, 立憲民主党_list, 公明党_list, 日本共産党_list, 日本維新の会_list, 国民民主党_list, 社会民主党_list, れいわ新選組_list]

#セクション4.4 ②
#グラフリスト Simpson係数の拡張

import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['現代ビジネス', '沖縄タイムス', '毎日新聞', '朝日新聞', '時事ドットコム',  '日本経済新聞', '産経ニュース', '東京新聞', '読売新聞オンライン', 'zakzak', 'NHKニュース', 'しんぶん赤旗', '日刊ゲンダイ', 'アゴラ', 'アノニマス_ポスト', 'ハム速', '政治知新', 'litera', 'Share_News_Japan', 'もえるあじあ', 'BuzzFeed_Japan', 'Yahoo_ニュース', '自由民主党', '立憲民主党', '公明党', '日本共産党',  '日本維新の会', '国民民主党', '社会民主党', 'れいわ新選組']
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News', 'Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa']
matrix_sk = [[0]*3 for i in range(len(sum_engname_list)**2)]

a_b_ = []

for a in sum_list:
  for b in sum_list:
    if a == b:
      a_b_.append(1)
    else:
      a_b_.append(len(set(a) & set(b))/(len(a)-1))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        matrix_sk[i+k][n] = sum_engname_list[k//30]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        matrix_sk[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        t += 1
        matrix_sk[i+k][n] = round(a_b_[t], 4)

print(matrix_sk)
# Out:
# データ取得終了時刻： 2022-04-21T18:41:46
# 現代ビジネスのフォロワー数： 159783
#
#
# データ取得終了時刻： 2022-04-21T18:56:54
# 沖縄タイムスのフォロワー数： 123898
#
#
# データ取得終了時刻： 2022-04-22T23:10:38
# 毎日新聞のフォロワー数： 961908
#
#
# データ取得終了時刻： 2022-04-24T15:42:25
# 朝日新聞のフォロワー数： 1319121
#
#
# データ取得終了時刻： 2022-04-22T08:29:02
# 時事ドットコムのフォロワー数： 333171
#
#
# データ取得終了時刻： 2022-04-26T04:51:54
# 日本経済新聞のフォロワー数： 3502954
#
#
# データ取得終了時刻： 2022-04-24T01:32:45
# 産経ニュースのフォロワー数： 657252
#
#
# データ取得終了時刻： 2022-04-22T16:12:21
# 東京新聞のフォロワー数： 95458
#
#
# データ取得終了時刻： 2022-04-23T21:16:17
# 読売新聞オンラインのフォロワー数： 817603
#
#
# データ取得終了時刻： 2022-04-21T23:06:11
# zakzakのフォロワー数： 72106
#
#
# データ取得終了時刻： 2022-04-27T10:29:08
# NHKニュースのフォロワー数： 3392866
#
#
# データ取得終了時刻： 2022-04-21T23:21:15
# しんぶん赤旗のフォロワー数： 52107
#
#
# データ取得終了時刻： 2022-04-21T23:51:22
# 日刊ゲンダイのフォロワー数： 126359
#
#
# データ取得終了時刻： 2022-04-22T00:06:26
# アゴラのフォロワー数： 43559
#
#
# データ取得終了時刻： 2022-04-22T00:21:32
# アノニマス_ポストのフォロワー数： 119150
#
#
# データ取得終了時刻： 2022-04-22T18:17:41
# ハム速のフォロワー数： 385114
#
#
# データ取得終了時刻： 2022-04-22T09:37:45
# 政治知新のフォロワー数： 67221
#
#
# データ取得終了時刻： 2022-04-22T10:07:54
# literaのフォロワー数： 106136
#
#
# データ取得終了時刻： 2022-04-22T10:38:05
# Share_News_Japanのフォロワー数： 135938
#
#
# データ取得終了時刻： 2022-04-22T10:38:06
# もえるあじあのフォロワー数： 24255
#
#
# データ取得終了時刻： 2022-04-23T14:28:59
# BuzzFeed_Japanのフォロワー数： 187453
#
#
# データ取得終了時刻： 2022-04-23T18:30:20
# Yahoo_ニュースのフォロワー数： 1174048
#
#
# データ取得終了時刻： 2022-04-27T20:04:33
# 自由民主党のフォロワー数： 239712
#
#
# データ取得終了時刻： 2022-04-27T21:50:12
# 立憲民主党のフォロワー数： 191978
#
#
# データ取得終了時刻： 2022-04-27T22:20:20
# 公明党のフォロワー数： 103607
#
#
# データ取得終了時刻： 2022-04-27T22:50:29
# 日本共産党のフォロワー数： 127694
#
#
# データ取得終了時刻： 2022-04-27T22:50:32
# 日本維新の会のフォロワー数： 64812
#
#
# データ取得終了時刻： 2022-04-27T23:05:35
# 国民民主党のフォロワー数： 43724
#
#
# データ取得終了時刻： 2022-04-28T00:14:47
# 社会民主党のフォロワー数： 45234
#
#
# データ取得終了時刻： 2022-04-28T00:44:56
# れいわ新選組のフォロワー数： 113374
#
#
# [['Gendai_biz', 'Gendai_biz', 1], ['Gendai_biz', 'Okinawa', 0.043], ['Gendai_biz', 'Mainichi', 0.2641], ['Gendai_biz', 'Asahi', 0.3181], ['Gendai_biz', 'Jiji', 0.1226], ['Gendai_biz', 'Nikkei', 0.5199], ['Gendai_biz', 'Sankei', 0.1576], ['Gendai_biz', 'Tokyo', 0.0526], ['Gendai_biz', 'Yomiuri', 0.2728], ['Gendai_biz', 'Zakzak', 0.0648], ['Gendai_biz', 'Nhk', 0.4545], ['Gendai_biz', 'Akahata', 0.0305], ['Gendai_biz', 'Nikkan', 0.1111], ['Gendai_biz', 'Agora', 0.0502], ['Gendai_biz', 'Anonymous', 0.0282], ['Gendai_biz', 'Hamusoku', 0.0365], ['Gendai_biz', 'Seijichishin', 0.0195], ['Gendai_biz', 'Litera', 0.0657], ['Gendai_biz', 'Share_News_Japan', 0.0373], ['Gendai_biz', 'Moeruasia', 0.0064], ['Gendai_biz', 'BuzzFeed_Japan', 0.0492], ['Gendai_biz', 'Yahoo_News', 0.2005], ['Gendai_biz', 'Jiyuminsyu', 0.0794], ['Gendai_biz', 'Rikkenminsyu', 0.059], ['Gendai_biz', 'Komei', 0.0321], ['Gendai_biz', 'Kyosan', 0.0414], ['Gendai_biz', 'Ishin', 0.0201], ['Gendai_biz', 'Kokuminminsyu', 0.016], ['Gendai_biz', 'Syakaiminsyu', 0.0248], ['Gendai_biz', 'Reiwa', 0.0291], ['Okinawa', 'Gendai_biz', 0.0554], ['Okinawa', 'Okinawa', 1], ['Okinawa', 'Mainichi', 0.2013], ['Okinawa', 'Asahi', 0.2203], ['Okinawa', 'Jiji', 0.1122], ['Okinawa', 'Nikkei', 0.2186], ['Okinawa', 'Sankei', 0.119], ['Okinawa', 'Tokyo', 0.098], ['Okinawa', 'Yomiuri', 0.1479], ['Okinawa', 'Zakzak', 0.0395], ['Okinawa', 'Nhk', 0.2818], ['Okinawa', 'Akahata', 0.0996], ['Okinawa', 'Nikkan', 0.1469], ['Okinawa', 'Agora', 0.021], ['Okinawa', 'Anonymous', 0.0197], ['Okinawa', 'Hamusoku', 0.0209], ['Okinawa', 'Seijichishin', 0.015], ['Okinawa', 'Litera', 0.1302], ['Okinawa', 'Share_News_Japan', 0.0275], ['Okinawa', 'Moeruasia', 0.0051], ['Okinawa', 'BuzzFeed_Japan', 0.0348], ['Okinawa', 'Yahoo_News', 0.1681], ['Okinawa', 'Jiyuminsyu', 0.0671], ['Okinawa', 'Rikkenminsyu', 0.1404], ['Okinawa', 'Komei', 0.0355], ['Okinawa', 'Kyosan', 0.1245], ['Okinawa', 'Ishin', 0.0197], ['Okinawa', 'Kokuminminsyu', 0.0273], ['Okinawa', 'Syakaiminsyu', 0.0748], ['Okinawa', 'Reiwa', 0.0796], ['Mainichi', 'Gendai_biz', 0.0439], ['Mainichi', 'Okinawa', 0.0259], ['Mainichi', 'Mainichi', 1], ['Mainichi', 'Asahi', 0.5997], ['Mainichi', 'Jiji', 0.152], ['Mainichi', 'Nikkei', 0.4645], ['Mainichi', 'Sankei', 0.2205], ['Mainichi', 'Tokyo', 0.0406], ['Mainichi', 'Yomiuri', 0.4108], ['Mainichi', 'Zakzak', 0.0242], ['Mainichi', 'Nhk', 0.5148], ['Mainichi', 'Akahata', 0.0191], ['Mainichi', 'Nikkan', 0.0576], ['Mainichi', 'Agora', 0.0121], ['Mainichi', 'Anonymous', 0.0121], ['Mainichi', 'Hamusoku', 0.0198], ['Mainichi', 'Seijichishin', 0.0087], ['Mainichi', 'Litera', 0.0344], ['Mainichi', 'Share_News_Japan', 0.0213], ['Mainichi', 'Moeruasia', 0.0026], ['Mainichi', 'BuzzFeed_Japan', 0.0198], ['Mainichi', 'Yahoo_News', 0.1812], ['Mainichi', 'Jiyuminsyu', 0.0529], ['Mainichi', 'Rikkenminsyu', 0.047], ['Mainichi', 'Komei', 0.0245], ['Mainichi', 'Kyosan', 0.0341], ['Mainichi', 'Ishin', 0.0122], ['Mainichi', 'Kokuminminsyu', 0.0105], ['Mainichi', 'Syakaiminsyu', 0.0186], ['Mainichi', 'Reiwa', 0.0201], ['Asahi', 'Gendai_biz', 0.0385], ['Asahi', 'Okinawa', 0.0207], ['Asahi', 'Mainichi', 0.4373], ['Asahi', 'Asahi', 1], ['Asahi', 'Jiji', 0.1136], ['Asahi', 'Nikkei', 0.517], ['Asahi', 'Sankei', 0.1726], ['Asahi', 'Tokyo', 0.0397], ['Asahi', 'Yomiuri', 0.3883], ['Asahi', 'Zakzak', 0.0188], ['Asahi', 'Nhk', 0.5765], ['Asahi', 'Akahata', 0.0155], ['Asahi', 'Nikkan', 0.045], ['Asahi', 'Agora', 0.0103], ['Asahi', 'Anonymous', 0.0096], ['Asahi', 'Hamusoku', 0.0158], ['Asahi', 'Seijichishin', 0.007], ['Asahi', 'Litera', 0.0273], ['Asahi', 'Share_News_Japan', 0.0161], ['Asahi', 'Moeruasia', 0.0021], ['Asahi', 'BuzzFeed_Japan', 0.016], ['Asahi', 'Yahoo_News', 0.1466], ['Asahi', 'Jiyuminsyu', 0.0441], ['Asahi', 'Rikkenminsyu', 0.0399], ['Asahi', 'Komei', 0.02], ['Asahi', 'Kyosan', 0.0282], ['Asahi', 'Ishin', 0.01], ['Asahi', 'Kokuminminsyu', 0.0084], ['Asahi', 'Syakaiminsyu', 0.015], ['Asahi', 'Reiwa', 0.0158], ['Jiji', 'Gendai_biz', 0.0588 ...

# %%
#セクション3.1 
#フォロワー総数（重複ありあり/なし）

sum_totalcount_list = 現代ビジネス_list + 沖縄タイムス_list + 毎日新聞_list + 朝日新聞_list + 時事ドットコム_list + 日本経済新聞_list + 産経ニュース_list + 東京新聞_list + 読売新聞オンライン_list + zakzak_list + NHKニュース_list + しんぶん赤旗_list + 日刊ゲンダイ_list + アゴラ_list + アノニマス_ポスト_list + ハム速_list + 政治知新_list + litera_list + Share_News_Japan_list + もえるあじあ_list + BuzzFeed_Japan_list + Yahoo_ニュース_list + 自由民主党_list + 立憲民主党_list + 公明党_list + 日本共産党_list + 日本維新の会_list + 国民民主党_list + 社会民主党_list + れいわ新選組_list

print('収集したフォロワーIDの総数：', len(sum_totalcount_list)-30)
print('フォロワーの総数', len(set(sum_totalcount_list))-30)

# %%
#セクションセクション3.2 
#アカウント同士の共通項の数

for n in sum_list:
  for k in sum_list:
    if n == k:
      continue
    n_k_=set(n) & set(k)
    print(n[-1], 'と', k[-1], 'の共通項の数は', len(n_k_))
  print('\n')

# %%
#セクション3.3
#アカウント同士のJaccard係数

for n in sum_list:
  for k in sum_list:
    if n == k:
      continue
    n_k_=set(n) & set(k)
    print(n[-1], 'と', k[-1], 'のJaccard係数は', (len(n_k_))/((len(n)-1)+(len(k)-1)-(len(n_k_))))
  print('\n')

# %%
#セクション3.4
#アカウント同士のDice係数

for n in sum_list:
  for k in sum_list:
    if n == k:
      continue
    n_k_=set(n) & set(k)
    print(n[-1], 'と', k[-1], 'のDice係数は', (len(n_k_)*2)/((len(n)-1)+(len(k)-1)))
  print('\n')

# %%
#セクション3.5
#アカウント同士のSimpson係数

for n in sum_list:
  for k in sum_list:
    if n == k:
      continue
    n_k_=set(n) & set(k)
    print(n[-1], 'と', k[-1], 'のSimpson係数は', round((round((len(n_k_)-1), 5)/(min(len(n)-1, len(k)-1))), 4))
  print('\n')

# %%
#セクション4.1 ②
#グラフリスト Jaccard係数


import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['現代ビジネス', '沖縄タイムス', '毎日新聞', '朝日新聞', '時事ドットコム',  '日本経済新聞', '産経ニュース', '東京新聞', '読売新聞オンライン', 'zakzak', 'NHKニュース', 'しんぶん赤旗', '日刊ゲンダイ', 'アゴラ', 'アノニマス_ポスト', 'ハム速', '政治知新', 'litera', 'Share_News_Japan', 'もえるあじあ', 'BuzzFeed_Japan', 'Yahoo_ニュース', '自由民主党', '立憲民主党', '公明党', '日本共産党',  '日本維新の会', '国民民主党', '社会民主党', 'れいわ新選組']
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News', 'Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa']
matrix_j = [[0]*3 for i in range(len(sum_engname_list)**2)]

a_b = []

for a in sum_list:
  for b in sum_list:
    if a == b:
      a_b.append(1)
    else:
      a_b_list = set(a) & set(b)
      a_b.append((len(a_b_list))/((len(a)-1)+(len(b)-1)-(len(a_b_list))))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        matrix_j[i+k][n] = sum_engname_list[k//30]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        matrix_j[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        t += 1
        matrix_j[i+k][n] = round(a_b[t], 4)

print(matrix_j)
# Out:
# [['Gendai_biz', 'Gendai_biz', 1], ['Gendai_biz', 'Okinawa', 0.0248], ['Gendai_biz', 'Mainichi', 0.0391], ['Gendai_biz', 'Asahi', 0.0356], ['Gendai_biz', 'Jiji', 0.0414], ['Gendai_biz', 'Nikkei', 0.0232], ['Gendai_biz', 'Sankei', 0.0318], ['Gendai_biz', 'Tokyo', 0.0341], ['Gendai_biz', 'Yomiuri', 0.0467], ['Gendai_biz', 'Zakzak', 0.0467], ['Gendai_biz', 'Nhk', 0.0209], ['Gendai_biz', 'Akahata', 0.0236], ['Gendai_biz', 'Nikkan', 0.0661], ['Gendai_biz', 'Agora', 0.0411], ['Gendai_biz', 'Anonymous', 0.0164], ['Gendai_biz', 'Hamusoku', 0.0108], ['Gendai_biz', 'Seijichishin', 0.0139], ['Gendai_biz', 'Litera', 0.0411], ['Gendai_biz', 'Share_News_Japan', 0.0206], ['Gendai_biz', 'Moeruasia', 0.0056], ['Gendai_biz', 'BuzzFeed_Japan', 0.0231], ['Gendai_biz', 'Yahoo_News', 0.0246], ['Gendai_biz', 'Jiyuminsyu', 0.0328], ['Gendai_biz', 'Rikkenminsyu', 0.0275], ['Gendai_biz', 'Komei', 0.0198], ['Gendai_biz', 'Kyosan', 0.0236], ['Gendai_biz', 'Ishin', 0.0145], ['Gendai_biz', 'Kokuminminsyu', 0.0127], ['Gendai_biz', 'Syakaiminsyu', 0.0197], ['Gendai_biz', 'Reiwa', 0.0173], ['Okinawa', 'Gendai_biz', 0.0248], ['Okinawa', 'Okinawa', 1], ['Okinawa', 'Mainichi', 0.0235], ['Okinawa', 'Asahi', 0.0193], ['Okinawa', 'Jiji', 0.0314], ['Okinawa', 'Nikkei', 0.0075], ['Okinawa', 'Sankei', 0.0192], ['Okinawa', 'Tokyo', 0.0586], ['Okinawa', 'Yomiuri', 0.0199], ['Okinawa', 'Zakzak', 0.0256], ['Okinawa', 'Nhk', 0.01], ['Okinawa', 'Akahata', 0.0754], ['Okinawa', 'Nikkan', 0.0784], ['Okinawa', 'Agora', 0.0158], ['Okinawa', 'Anonymous', 0.0101], ['Okinawa', 'Hamusoku', 0.0051], ['Okinawa', 'Seijichishin', 0.0098], ['Okinawa', 'Litera', 0.0754], ['Okinawa', 'Share_News_Japan', 0.0133], ['Okinawa', 'Moeruasia', 0.0043], ['Okinawa', 'BuzzFeed_Japan', 0.014], ['Okinawa', 'Yahoo_News', 0.0163], ['Okinawa', 'Jiyuminsyu', 0.0234], ['Okinawa', 'Rikkenminsyu', 0.0583], ['Okinawa', 'Komei', 0.0197], ['Okinawa', 'Kyosan', 0.0653], ['Okinawa', 'Ishin', 0.0131], ['Okinawa', 'Kokuminminsyu', 0.0206], ['Okinawa', 'Syakaiminsyu', 0.0579], ['Okinawa', 'Reiwa', 0.0434], ['Mainichi', 'Gendai_biz', 0.0391], ['Mainichi', 'Okinawa', 0.0235], ['Mainichi', 'Mainichi', 1], ['Mainichi', 'Asahi', 0.3385], ['Mainichi', 'Jiji', 0.1272], ['Mainichi', 'Nikkei', 0.1112], ['Mainichi', 'Sankei', 0.1507], ['Mainichi', 'Tokyo', 0.0383], ['Mainichi', 'Yomiuri', 0.2855], ['Mainichi', 'Zakzak', 0.023], ['Mainichi', 'Nhk', 0.1283], ['Mainichi', 'Akahata', 0.0185], ['Mainichi', 'Nikkan', 0.0536], ['Mainichi', 'Agora', 0.0117], ['Mainichi', 'Anonymous', 0.0109], ['Mainichi', 'Hamusoku', 0.0143], ['Mainichi', 'Seijichishin', 0.0082], ['Mainichi', 'Litera', 0.032], ['Mainichi', 'Share_News_Japan', 0.019], ['Mainichi', 'Moeruasia', 0.0026], ['Mainichi', 'BuzzFeed_Japan', 0.0169], ['Mainichi', 'Yahoo_News', 0.0889], ['Mainichi', 'Jiyuminsyu', 0.0442], ['Mainichi', 'Rikkenminsyu', 0.0407], ['Mainichi', 'Komei', 0.0226], ['Mainichi', 'Kyosan', 0.031], ['Mainichi', 'Ishin', 0.0116], ['Mainichi', 'Kokuminminsyu', 0.0101], ['Mainichi', 'Syakaiminsyu', 0.0181], ['Mainichi', 'Reiwa', 0.0183], ['Asahi', 'Gendai_biz', 0.0356], ['Asahi', 'Okinawa', 0.0193], ['Asahi', 'Mainichi', 0.3385], ['Asahi', 'Asahi', 1], ['Asahi', 'Jiji', 0.0998], ['Asahi', 'Nikkei', 0.1647], ['Asahi', 'Sankei', 0.1302], ['Asahi', 'Tokyo', 0.0384], ['Asahi', 'Yomiuri', 0.3153], ['Asahi', 'Zakzak', 0.0181], ['Asahi', 'Nhk', 0.1924], ['Asahi', 'Akahata', 0.0151], ['Asahi', 'Nikkan', 0.0428], ['Asahi', 'Agora', 0.01], ['Asahi', 'Anonymous', 0.0089], ['Asahi', 'Hamusoku', 0.0124], ['Asahi', 'Seijichishin', 0.0067], ['Asahi', 'Litera', 0.0259], ['Asahi', 'Share_News_Japan', 0.0148], ['Asahi', 'Moeruasia', 0.0021], ['Asahi', 'BuzzFeed_Japan', 0.0142], ['Asahi', 'Yahoo_News', 0.0841], ['Asahi', 'Jiyuminsyu', 0.0387], ['Asahi', 'Rikkenminsyu', 0.0361], ['Asahi', 'Komei', 0.0189], ['Asahi', 'Kyosan', 0.0264], ['Asahi', 'Ishin', 0.0096], ['Asahi', 'Kokuminminsyu', 0.0082], ['Asahi', 'Syakaiminsyu', 0.0147], ['Asahi', 'Reiwa', 0.0148], ['Jiji', 'Gendai_biz ...

# %%
#セクション4.1.1 
#グラフリスト 
Jaccard係数 = 0.1

import networkx as nx
import matplotlib.pyplot as plt

matrix_con = []
for i in range(len(matrix_j)):
  if matrix_j[i][2] >= Jaccard係数 and matrix_j[i][2] != 1: #右の条件式でアカウントの自己ループをなくす
    matrix_con.append(matrix_j[i])

H = nx.Graph()
H.add_weighted_edges_from(matrix_con)

edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]
#pos = nx.spring_layout(H, k=0.5) 
pos=nx.nx_pydot.graphviz_layout(H)

nx.draw(H, pos, with_labels=True, width=edge_width)

# %%
#セクション4.2 ②
#グラフリスト Dice係数


import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['現代ビジネス', '沖縄タイムス', '毎日新聞', '朝日新聞', '時事ドットコム',  '日本経済新聞', '産経ニュース', '東京新聞', '読売新聞オンライン', 'zakzak', 'NHKニュース', 'しんぶん赤旗', '日刊ゲンダイ', 'アゴラ', 'アノニマス_ポスト', 'ハム速', '政治知新', 'litera', 'Share_News_Japan', 'もえるあじあ', 'BuzzFeed_Japan', 'Yahoo_ニュース', '自由民主党', '立憲民主党', '公明党', '日本共産党',  '日本維新の会', '国民民主党', '社会民主党', 'れいわ新選組']
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News', 'Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa']
matrix_d = [[0]*3 for i in range(len(sum_engname_list)**2)]

a_b = []

for a in sum_list:
  for b in sum_list:
    if a == b:
      a_b.append(1)
    else:
      a_b_list = set(a) & set(b)
      a_b.append((len(a_b_list)*2)/((len(a)-1)+(len(b)-1)))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        matrix_d[i+k][n] = sum_engname_list[k//30]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        matrix_d[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        t += 1
        matrix_d[i+k][n] = round(a_b[t], 4)

print(matrix_d)
# Out:
# [['Gendai_biz', 'Gendai_biz', 1], ['Gendai_biz', 'Okinawa', 0.0484], ['Gendai_biz', 'Mainichi', 0.0752], ['Gendai_biz', 'Asahi', 0.0687], ['Gendai_biz', 'Jiji', 0.0795], ['Gendai_biz', 'Nikkei', 0.0454], ['Gendai_biz', 'Sankei', 0.0616], ['Gendai_biz', 'Tokyo', 0.0659], ['Gendai_biz', 'Yomiuri', 0.0892], ['Gendai_biz', 'Zakzak', 0.0892], ['Gendai_biz', 'Nhk', 0.0409], ['Gendai_biz', 'Akahata', 0.046], ['Gendai_biz', 'Nikkan', 0.1241], ['Gendai_biz', 'Agora', 0.0789], ['Gendai_biz', 'Anonymous', 0.0323], ['Gendai_biz', 'Hamusoku', 0.0214], ['Gendai_biz', 'Seijichishin', 0.0274], ['Gendai_biz', 'Litera', 0.079], ['Gendai_biz', 'Share_News_Japan', 0.0403], ['Gendai_biz', 'Moeruasia', 0.0111], ['Gendai_biz', 'BuzzFeed_Japan', 0.0452], ['Gendai_biz', 'Yahoo_News', 0.048], ['Gendai_biz', 'Jiyuminsyu', 0.0635], ['Gendai_biz', 'Rikkenminsyu', 0.0536], ['Gendai_biz', 'Komei', 0.0389], ['Gendai_biz', 'Kyosan', 0.046], ['Gendai_biz', 'Ishin', 0.0285], ['Gendai_biz', 'Kokuminminsyu', 0.0251], ['Gendai_biz', 'Syakaiminsyu', 0.0386], ['Gendai_biz', 'Reiwa', 0.034], ['Okinawa', 'Gendai_biz', 0.0484], ['Okinawa', 'Okinawa', 1], ['Okinawa', 'Mainichi', 0.0459], ['Okinawa', 'Asahi', 0.0378], ['Okinawa', 'Jiji', 0.0608], ['Okinawa', 'Nikkei', 0.0149], ['Okinawa', 'Sankei', 0.0377], ['Okinawa', 'Tokyo', 0.1107], ['Okinawa', 'Yomiuri', 0.0389], ['Okinawa', 'Zakzak', 0.0499], ['Okinawa', 'Nhk', 0.0199], ['Okinawa', 'Akahata', 0.1403], ['Okinawa', 'Nikkan', 0.1454], ['Okinawa', 'Agora', 0.0311], ['Okinawa', 'Anonymous', 0.0201], ['Okinawa', 'Hamusoku', 0.0102], ['Okinawa', 'Seijichishin', 0.0194], ['Okinawa', 'Litera', 0.1402], ['Okinawa', 'Share_News_Japan', 0.0262], ['Okinawa', 'Moeruasia', 0.0086], ['Okinawa', 'BuzzFeed_Japan', 0.0277], ['Okinawa', 'Yahoo_News', 0.0321], ['Okinawa', 'Jiyuminsyu', 0.0457], ['Okinawa', 'Rikkenminsyu', 0.1102], ['Okinawa', 'Komei', 0.0387], ['Okinawa', 'Kyosan', 0.1226], ['Okinawa', 'Ishin', 0.0259], ['Okinawa', 'Kokuminminsyu', 0.0404], ['Okinawa', 'Syakaiminsyu', 0.1095], ['Okinawa', 'Reiwa', 0.0831], ['Mainichi', 'Gendai_biz', 0.0752], ['Mainichi', 'Okinawa', 0.0459], ['Mainichi', 'Mainichi', 1], ['Mainichi', 'Asahi', 0.5058], ['Mainichi', 'Jiji', 0.2257], ['Mainichi', 'Nikkei', 0.2002], ['Mainichi', 'Sankei', 0.262], ['Mainichi', 'Tokyo', 0.0739], ['Mainichi', 'Yomiuri', 0.4441], ['Mainichi', 'Zakzak', 0.045], ['Mainichi', 'Nhk', 0.2274], ['Mainichi', 'Akahata', 0.0363], ['Mainichi', 'Nikkan', 0.1018], ['Mainichi', 'Agora', 0.0231], ['Mainichi', 'Anonymous', 0.0215], ['Mainichi', 'Hamusoku', 0.0282], ['Mainichi', 'Seijichishin', 0.0162], ['Mainichi', 'Litera', 0.062], ['Mainichi', 'Share_News_Japan', 0.0372], ['Mainichi', 'Moeruasia', 0.0051], ['Mainichi', 'BuzzFeed_Japan', 0.0332], ['Mainichi', 'Yahoo_News', 0.1632], ['Mainichi', 'Jiyuminsyu', 0.0846], ['Mainichi', 'Rikkenminsyu', 0.0783], ['Mainichi', 'Komei', 0.0443], ['Mainichi', 'Kyosan', 0.0602], ['Mainichi', 'Ishin', 0.0229], ['Mainichi', 'Kokuminminsyu', 0.0201], ['Mainichi', 'Syakaiminsyu', 0.0355], ['Mainichi', 'Reiwa', 0.036], ['Asahi', 'Gendai_biz', 0.0687], ['Asahi', 'Okinawa', 0.0378], ['Asahi', 'Mainichi', 0.5058], ['Asahi', 'Asahi', 1], ['Asahi', 'Jiji', 0.1814], ['Asahi', 'Nikkei', 0.2829], ['Asahi', 'Sankei', 0.2304], ['Asahi', 'Tokyo', 0.074], ['Asahi', 'Yomiuri', 0.4794], ['Asahi', 'Zakzak', 0.0356], ['Asahi', 'Nhk', 0.3228], ['Asahi', 'Akahata', 0.0298], ['Asahi', 'Nikkan', 0.0821], ['Asahi', 'Agora', 0.0199], ['Asahi', 'Anonymous', 0.0176], ['Asahi', 'Hamusoku', 0.0245], ['Asahi', 'Seijichishin', 0.0133], ['Asahi', 'Litera', 0.0506], ['Asahi', 'Share_News_Japan', 0.0291], ['Asahi', 'Moeruasia', 0.0042], ['Asahi', 'BuzzFeed_Japan', 0.028], ['Asahi', 'Yahoo_News', 0.1552], ['Asahi', 'Jiyuminsyu', 0.0746], ['Asahi', 'Rikkenminsyu', 0.0697], ['Asahi', 'Komei', 0.037], ['Asahi', 'Kyosan', 0.0514], ['Asahi', 'Ishin', 0.0191], ['Asahi', 'Kokuminminsyu', 0.0162], ['Asahi', 'Syakaiminsyu', 0.0291], ['Asahi', 'Reiwa', 0.0291], ['Jiji', 'Gendai_biz',  ...

# %%
#セクション4.2.1 
#グラフリスト 
Dice係数 = 0.15

import networkx as nx
import matplotlib.pyplot as plt

matrix_con1 = []
for i in range(len(matrix_d)):
  if matrix_d[i][2] >= Dice係数 and matrix_d[i][2] != 1: #右の条件式でアカウントの自己ループをなくす
    matrix_con1.append(matrix_d[i])

H = nx.Graph()
H.add_weighted_edges_from(matrix_con1)

edge_width = [d["weight"] * 8  for (u, v, d) in H.edges(data=True)]
pos = nx.spring_layout(H, k=0.70) 

nx.draw_kamada_kawai(H, with_labels=True, width=edge_width)

# %%
#セクション4.3 ②
#グラフリスト Simpson係数

import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['現代ビジネス', '沖縄タイムス', '毎日新聞', '朝日新聞', '時事ドットコム',  '日本経済新聞', '産経ニュース', '東京新聞', '読売新聞オンライン', 'zakzak', 'NHKニュース', 'しんぶん赤旗', '日刊ゲンダイ', 'アゴラ', 'アノニマス_ポスト', 'ハム速', '政治知新', 'litera', 'Share_News_Japan', 'もえるあじあ', 'BuzzFeed_Japan', 'Yahoo_ニュース', '自由民主党', '立憲民主党', '公明党', '日本共産党',  '日本維新の会', '国民民主党', '社会民主党', 'れいわ新選組']
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News', 'Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa']
matrix_s = [[0]*3 for i in range(len(sum_engname_list)**2)]

a_b_ = []

for a in sum_list:
  for b in sum_list:
    if a == b:
      a_b_.append((len(set(a) & set(b))-1)/min((len(a)-1), (len(b)-1)))
    else:
      a_b_.append(len(set(a) & set(b))/min((len(a)-1), (len(b)-1)))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        matrix_s[i+k][n] = sum_engname_list[k//30]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        matrix_s[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        t += 1
        matrix_s[i+k][n] = round(a_b_[t], 4)

print(matrix_s)
# Out:
# [['Gendai_biz', 'Gendai_biz', 1.0], ['Gendai_biz', 'Okinawa', 0.0554], ['Gendai_biz', 'Mainichi', 0.2641], ['Gendai_biz', 'Asahi', 0.3181], ['Gendai_biz', 'Jiji', 0.1226], ['Gendai_biz', 'Nikkei', 0.5199], ['Gendai_biz', 'Sankei', 0.1576], ['Gendai_biz', 'Tokyo', 0.0881], ['Gendai_biz', 'Yomiuri', 0.2728], ['Gendai_biz', 'Zakzak', 0.1435], ['Gendai_biz', 'Nhk', 0.4545], ['Gendai_biz', 'Akahata', 0.0936], ['Gendai_biz', 'Nikkan', 0.1405], ['Gendai_biz', 'Agora', 0.1842], ['Gendai_biz', 'Anonymous', 0.0378], ['Gendai_biz', 'Hamusoku', 0.0365], ['Gendai_biz', 'Seijichishin', 0.0463], ['Gendai_biz', 'Litera', 0.099], ['Gendai_biz', 'Share_News_Japan', 0.0439], ['Gendai_biz', 'Moeruasia', 0.0419], ['Gendai_biz', 'BuzzFeed_Japan', 0.0492], ['Gendai_biz', 'Yahoo_News', 0.2005], ['Gendai_biz', 'Jiyuminsyu', 0.0794], ['Gendai_biz', 'Rikkenminsyu', 0.059], ['Gendai_biz', 'Komei', 0.0495], ['Gendai_biz', 'Kyosan', 0.0518], ['Gendai_biz', 'Ishin', 0.0495], ['Gendai_biz', 'Kokuminminsyu', 0.0583], ['Gendai_biz', 'Syakaiminsyu', 0.0875], ['Gendai_biz', 'Reiwa', 0.041], ['Okinawa', 'Gendai_biz', 0.0554], ['Okinawa', 'Okinawa', 1.0], ['Okinawa', 'Mainichi', 0.2013], ['Okinawa', 'Asahi', 0.2203], ['Okinawa', 'Jiji', 0.1122], ['Okinawa', 'Nikkei', 0.2186], ['Okinawa', 'Sankei', 0.119], ['Okinawa', 'Tokyo', 0.1272], ['Okinawa', 'Yomiuri', 0.1479], ['Okinawa', 'Zakzak', 0.0678], ['Okinawa', 'Nhk', 0.2818], ['Okinawa', 'Akahata', 0.2369], ['Okinawa', 'Nikkan', 0.1469], ['Okinawa', 'Agora', 0.0598], ['Okinawa', 'Anonymous', 0.0205], ['Okinawa', 'Hamusoku', 0.0209], ['Okinawa', 'Seijichishin', 0.0276], ['Okinawa', 'Litera', 0.152], ['Okinawa', 'Share_News_Japan', 0.0275], ['Okinawa', 'Moeruasia', 0.0263], ['Okinawa', 'BuzzFeed_Japan', 0.0348], ['Okinawa', 'Yahoo_News', 0.1681], ['Okinawa', 'Jiyuminsyu', 0.0671], ['Okinawa', 'Rikkenminsyu', 0.1404], ['Okinawa', 'Komei', 0.0425], ['Okinawa', 'Kyosan', 0.1245], ['Okinawa', 'Ishin', 0.0377], ['Okinawa', 'Kokuminminsyu', 0.0774], ['Okinawa', 'Syakaiminsyu', 0.2048], ['Okinawa', 'Reiwa', 0.087], ['Mainichi', 'Gendai_biz', 0.2641], ['Mainichi', 'Okinawa', 0.2013], ['Mainichi', 'Mainichi', 1.0], ['Mainichi', 'Asahi', 0.5997], ['Mainichi', 'Jiji', 0.4388], ['Mainichi', 'Nikkei', 0.4645], ['Mainichi', 'Sankei', 0.3227], ['Mainichi', 'Tokyo', 0.4091], ['Mainichi', 'Yomiuri', 0.4833], ['Mainichi', 'Zakzak', 0.3228], ['Mainichi', 'Nhk', 0.5148], ['Mainichi', 'Akahata', 0.3532], ['Mainichi', 'Nikkan', 0.4383], ['Mainichi', 'Agora', 0.2662], ['Mainichi', 'Anonymous', 0.0975], ['Mainichi', 'Hamusoku', 0.0494], ['Mainichi', 'Seijichishin', 0.1239], ['Mainichi', 'Litera', 0.3122], ['Mainichi', 'Share_News_Japan', 0.1504], ['Mainichi', 'Moeruasia', 0.1037], ['Mainichi', 'BuzzFeed_Japan', 0.1018], ['Mainichi', 'Yahoo_News', 0.1812], ['Mainichi', 'Jiyuminsyu', 0.2121], ['Mainichi', 'Rikkenminsyu', 0.2353], ['Mainichi', 'Komei', 0.2276], ['Mainichi', 'Kyosan', 0.2569], ['Mainichi', 'Ishin', 0.1817], ['Mainichi', 'Kokuminminsyu', 0.2309], ['Mainichi', 'Syakaiminsyu', 0.3954], ['Mainichi', 'Reiwa', 0.1706], ['Asahi', 'Gendai_biz', 0.3181], ['Asahi', 'Okinawa', 0.2203], ['Asahi', 'Mainichi', 0.5997], ['Asahi', 'Asahi', 1.0], ['Asahi', 'Jiji', 0.4499], ['Asahi', 'Nikkei', 0.517], ['Asahi', 'Sankei', 0.3464], ['Asahi', 'Tokyo', 0.5486], ['Asahi', 'Yomiuri', 0.6264], ['Asahi', 'Zakzak', 0.3435], ['Asahi', 'Nhk', 0.5765], ['Asahi', 'Akahata', 0.3925], ['Asahi', 'Nikkan', 0.4696], ['Asahi', 'Agora', 0.3106], ['Asahi', 'Anonymous', 0.1065], ['Asahi', 'Hamusoku', 0.0543], ['Asahi', 'Seijichishin', 0.1371], ['Asahi', 'Litera', 0.3395], ['Asahi', 'Share_News_Japan', 0.1559], ['Asahi', 'Moeruasia', 0.1157], ['Asahi', 'BuzzFeed_Japan', 0.1127], ['Asahi', 'Yahoo_News', 0.1647], ['Asahi', 'Jiyuminsyu', 0.2426], ['Asahi', 'Rikkenminsyu', 0.2743], ['Asahi', 'Komei', 0.2541], ['Asahi', 'Kyosan', 0.2914], ['Asahi', 'Ishin', 0.2035], ['Asahi', 'Kokuminminsyu', 0.2528], ['Asahi', 'Syakaiminsyu', 0.4383], ['Asahi', 'Reiwa', 0.1837], ['Jiji', ' ...

# %%
#セクション4.3.3
#グラフリスト 
Simpson係数 = 0.5

matrix_con = []
for i in range(len(matrix_s)):
  if matrix_s[i][2] >= Simpson係数 and matrix_s[i][2] != 1:
    matrix_con.append(matrix_s[i])

H = nx.Graph()
H.add_weighted_edges_from(matrix_con)

edge_width = [d["weight"] * 4  for (u, v, d) in H.edges(data=True)]
pos = nx.spring_layout(H, k=0.35) 


nx.draw_kamada_kawai(H, with_labels=True, width=edge_width)

# %%
#セクション4.4 ②
#グラフリスト Simpson係数の拡張

import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['現代ビジネス', '沖縄タイムス', '毎日新聞', '朝日新聞', '時事ドットコム',  '日本経済新聞', '産経ニュース', '東京新聞', '読売新聞オンライン', 'zakzak', 'NHKニュース', 'しんぶん赤旗', '日刊ゲンダイ', 'アゴラ', 'アノニマス_ポスト', 'ハム速', '政治知新', 'litera', 'Share_News_Japan', 'もえるあじあ', 'BuzzFeed_Japan', 'Yahoo_ニュース', '自由民主党', '立憲民主党', '公明党', '日本共産党',  '日本維新の会', '国民民主党', '社会民主党', 'れいわ新選組']
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News', 'Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa']
matrix_sk = [[0]*3 for i in range(len(sum_engname_list)**2)]

a_b_ = []

for a in sum_list:
  for b in sum_list:
    if a == b:
      a_b_.append(1)
    else:
      a_b_.append(len(set(a) & set(b))/(len(a)-1))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        matrix_sk[i+k][n] = sum_engname_list[k//30]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        matrix_sk[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 30):
      for i in range(30):
        t += 1
        matrix_sk[i+k][n] = round(a_b_[t], 4)

print(matrix_sk)

# %%
#セクション4.3.3
#グラフリスト 
#Simpson係数の拡張 = float(input("Simpson係数の拡張verの値："))
Simpson係数の拡張 = 0.5

matrix_con = []
for i in range(len(matrix_sk)):
  if matrix_sk[i][2] >= Simpson係数の拡張 and matrix_sk[i][2] != 1:
    matrix_con.append(matrix_sk[i])

H = nx.DiGraph()
for n in sum_engname_list:
    H.add_node(n)
size =[((len(i)-1)/1000) for i in sum_list]
H.add_weighted_edges_from(matrix_con)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]
# pos = nx.spring_layout(H, k=0.6) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(18,12))
nx.draw_networkx(H, pos, node_size = size, arrows=True, width=[v['weight'] * 5 for v in H.edges.values()], connectionstyle="arc3, rad=0.2")

# %% [markdown]
# \- draw_circular 頂点を円周上に配置
# - draw_kamada_kawai 頂点を力学モデルにより配置
# - draw_random 頂点をランダムに配置
# - draw_spectral ネットワークを表す行列の固有ベクトルにより、頂点を配置
# - draw_spring 頂点を力学モデルにより配置
# - draw_shell 頂点を同心円上に配置
