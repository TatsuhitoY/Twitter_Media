# %%
#セクション2
import csv

filename = '31.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_党首_lists=[]
    for row in csvreader:
      自由民主党_党首_lists += row

    print('データ取得終了時刻：', 自由民主党_党首_lists[-2])
    del 自由民主党_党首_lists[-1]
    del 自由民主党_党首_lists[-1]

    unique_set = set(自由民主党_党首_lists)
    自由民主党_党首_list = list(unique_set)
    自由民主党_党首_list.append('自由民主党_党首')

    print('自由民主党_党首のフォロワー数：', len(自由民主党_党首_list)-1)
    print('\n')

filename = '32.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_党首_lists=[]
    for row in csvreader:
      立憲民主党_党首_lists += row

    print('データ取得終了時刻：', 立憲民主党_党首_lists[-2])
    del 立憲民主党_党首_lists[-1]
    del 立憲民主党_党首_lists[-1]

    unique_set = set(立憲民主党_党首_lists)
    立憲民主党_党首_list = list(unique_set)
    立憲民主党_党首_list.append('立憲民主党_党首')

    print('立憲民主党_党首のフォロワー数：', len(立憲民主党_党首_list)-1)
    print('\n')

filename = '33.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    公明党_党首_lists=[]
    for row in csvreader:
      公明党_党首_lists += row

    print('データ取得終了時刻：', 公明党_党首_lists[-2])
    del 公明党_党首_lists[-1]
    del 公明党_党首_lists[-1]

    unique_set = set(公明党_党首_lists)
    公明党_党首_list = list(unique_set)
    公明党_党首_list.append('公明党_党首')

    print('公明党_党首のフォロワー数：', len(公明党_党首_list)-1)
    print('\n')

filename = '34.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本共産党_党首_lists=[]
    for row in csvreader:
      日本共産党_党首_lists += row

    print('データ取得終了時刻：', 日本共産党_党首_lists[-2])
    del 日本共産党_党首_lists[-1]
    del 日本共産党_党首_lists[-1]

    unique_set = set(日本共産党_党首_lists)
    日本共産党_党首_list = list(unique_set)
    日本共産党_党首_list.append('日本共産党_党首')

    print('日本共産党_党首のフォロワー数：', len(日本共産党_党首_list)-1)
    print('\n')

filename = '35.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_党首_lists=[]
    for row in csvreader:
      日本維新の会_党首_lists += row

    print('データ取得終了時刻：', 日本維新の会_党首_lists[-2])
    del 日本維新の会_党首_lists[-1]
    del 日本維新の会_党首_lists[-1]

    unique_set = set(日本維新の会_党首_lists)
    日本維新の会_党首_list = list(unique_set)
    日本維新の会_党首_list.append('日本維新の会_党首')

    print('日本維新の会_党首のフォロワー数：', len(日本維新の会_党首_list)-1)
    print('\n')

filename = '36.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    国民民主党_党首_lists=[]
    for row in csvreader:
      国民民主党_党首_lists += row

    print('データ取得終了時刻：', 国民民主党_党首_lists[-2])
    del 国民民主党_党首_lists[-1]
    del 国民民主党_党首_lists[-1]

    unique_set = set(国民民主党_党首_lists)
    国民民主党_党首_list = list(unique_set)
    国民民主党_党首_list.append('国民民主党_党首')

    print('国民民主党_党首のフォロワー数：', len(国民民主党_党首_list)-1)
    print('\n')

filename = '37.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    社会民主党_党首_lists=[]
    for row in csvreader:
      社会民主党_党首_lists += row

    print('データ取得終了時刻：', 社会民主党_党首_lists[-2])
    del 社会民主党_党首_lists[-1]
    del 社会民主党_党首_lists[-1]

    unique_set = set(社会民主党_党首_lists)
    社会民主党_党首_list = list(unique_set)
    社会民主党_党首_list.append('社会民主党_党首')

    print('社会民主党_党首のフォロワー数：', len(社会民主党_党首_list)-1)
    print('\n')

filename = '38.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    れいわ新選組_党首_lists=[]
    for row in csvreader:
      れいわ新選組_党首_lists += row

    print('データ取得終了時刻：', れいわ新選組_党首_lists[-2])
    del れいわ新選組_党首_lists[-1]
    del れいわ新選組_党首_lists[-1]

    unique_set = set(れいわ新選組_党首_lists)
    れいわ新選組_党首_list = list(unique_set)
    れいわ新選組_党首_list.append('れいわ新選組_党首')

    print('れいわ新選組_党首のフォロワー数：', len(れいわ新選組_党首_list)-1)
    print('\n')

filename = '39.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_菅_lists=[]
    for row in csvreader:
      自由民主党_菅_lists += row

    print('データ取得終了時刻：', 自由民主党_菅_lists[-2])
    del 自由民主党_菅_lists[-1]
    del 自由民主党_菅_lists[-1]

    unique_set = set(自由民主党_菅_lists)
    自由民主党_菅_list = list(unique_set)
    自由民主党_菅_list.append('自由民主党_菅')

    print('自由民主党_菅のフォロワー数：', len(自由民主党_菅_list)-1)
    print('\n')

filename = '40.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_河野_lists=[]
    for row in csvreader:
      自由民主党_河野_lists += row

    print('データ取得終了時刻：', 自由民主党_河野_lists[-2])
    del 自由民主党_河野_lists[-1]
    del 自由民主党_河野_lists[-1]

    unique_set = set(自由民主党_河野_lists)
    自由民主党_河野_list = list(unique_set)
    自由民主党_河野_list.append('自由民主党_河野')

    print('自由民主党_河野のフォロワー数：', len(自由民主党_河野_list)-1)
    print('\n')

filename = '41.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_枝野_lists=[]
    for row in csvreader:
      立憲民主党_枝野_lists += row

    print('データ取得終了時刻：', 立憲民主党_枝野_lists[-2])
    del 立憲民主党_枝野_lists[-1]
    del 立憲民主党_枝野_lists[-1]

    unique_set = set(立憲民主党_枝野_lists)
    立憲民主党_枝野_list = list(unique_set)
    立憲民主党_枝野_list.append('立憲民主党_枝野')

    print('立憲民主党_枝野のフォロワー数：', len(立憲民主党_枝野_list)-1)
    print('\n')

filename = '42.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_蓮舫_lists=[]
    for row in csvreader:
      立憲民主党_蓮舫_lists += row

    print('データ取得終了時刻：', 立憲民主党_蓮舫_lists[-2])
    del 立憲民主党_蓮舫_lists[-1]
    del 立憲民主党_蓮舫_lists[-1]

    unique_set = set(立憲民主党_蓮舫_lists)
    立憲民主党_蓮舫_list = list(unique_set)
    立憲民主党_蓮舫_list.append('立憲民主党_蓮舫')

    print('立憲民主党_蓮舫のフォロワー数：', len(立憲民主党_蓮舫_list)-1)
    print('\n')

filename = '43.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_吉村_lists=[]
    for row in csvreader:
      日本維新の会_吉村_lists += row

    print('データ取得終了時刻：', 日本維新の会_吉村_lists[-2])
    del 日本維新の会_吉村_lists[-1]
    del 日本維新の会_吉村_lists[-1]

    unique_set = set(日本維新の会_吉村_lists)
    日本維新の会_吉村_list = list(unique_set)
    日本維新の会_吉村_list.append('日本維新の会_吉村')

    print('日本維新の会_吉村のフォロワー数：', len(日本維新の会_吉村_list)-1)
    print('\n')

filename = '44.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_橋下_lists=[]
    for row in csvreader:
      日本維新の会_橋下_lists += row

    print('データ取得終了時刻：', 日本維新の会_橋下_lists[-2])
    del 日本維新の会_橋下_lists[-1]
    del 日本維新の会_橋下_lists[-1]

    unique_set = set(日本維新の会_橋下_lists)
    日本維新の会_橋下_list = list(unique_set)
    日本維新の会_橋下_list.append('日本維新の会_橋下')

    print('日本維新の会_橋下のフォロワー数：', len(日本維新の会_橋下_list)-1)
    print('\n')

sum_list = [自由民主党_党首_list, 立憲民主党_党首_list, 公明党_党首_list, 日本共産党_党首_list, 日本維新の会_党首_list, 国民民主党_党首_list, 社会民主党_党首_list, れいわ新選組_党首_list, 自由民主党_菅_list, 自由民主党_河野_list, 立憲民主党_枝野_list, 立憲民主党_蓮舫_list, 日本維新の会_吉村_list, 日本維新の会_橋下_list]
# Out:
# データ取得終了時刻： 2022-05-05T23:41:24
# 自由民主党_党首のフォロワー数： 516553
#
#
# データ取得終了時刻： 2022-05-06T01:11:52
# 立憲民主党_党首のフォロワー数： 27834
#
#
# データ取得終了時刻： 2022-05-06T19:36:57
# 公明党_党首のフォロワー数： 48960
#
#
# データ取得終了時刻： 2022-05-06T20:22:11
# 日本共産党_党首のフォロワー数： 205336
#
#
# データ取得終了時刻： 2022-05-06T23:25:57
# 日本維新の会_党首のフォロワー数： 425594
#
#
# データ取得終了時刻： 2022-05-07T14:13:43
# 国民民主党_党首のフォロワー数： 219035
#
#
# データ取得終了時刻： 2022-05-07T14:59:00
# 社会民主党_党首のフォロワー数： 233406
#
#
# データ取得終了時刻： 2022-05-07T16:44:33
# れいわ新選組_党首のフォロワー数： 462013
#
#
# データ取得終了時刻： 2022-05-06T15:24:20
# 自由民主党_菅のフォロワー数： 545750
#
#
# データ取得終了時刻： 2022-05-06T09:59:52
# 自由民主党_河野のフォロワー数： 2457515
#
#
# データ取得終了時刻： 2022-05-06T01:42:05
# 立憲民主党_枝野のフォロワー数： 184142
#
#
# データ取得終了時刻： 2022-05-06T17:24:58
# 立憲民主党_蓮舫のフォロワー数： 528100
#
#
# データ取得終了時刻： 2022-05-07T04:25:25
# 日本維新の会_吉村のフォロワー数： 1263583
#
#
# データ取得終了時刻： 2022-05-07T13:28:28
# 日本維新の会_橋下のフォロワー数： 2697434

# %%
import networkx as nx
import math
import csv
import random as rand
import sys

_DEBUG_ = False

                                              
def buildG(G, list):                                       
    for line in list:
       G.add_edge(line[0], line[1],weight=float(line[2]))            

def CmtyGirvanNewmanStep(G): #③
    if _DEBUG_:
        print("Running CmtyGirvanNewmanStep method ...")
    init_ncomp = nx.number_connected_components(G)     
    ncomp = init_ncomp                                      
    while ncomp <= init_ncomp:
        bw = nx.edge_betweenness_centrality(G, weight='weight')                              
        max_ = max(bw.values())                                    
        for k, v in bw.items():                    
            if float(v) == max_:
                G.remove_edge(k[0],k[1])                    
        ncomp = nx.number_connected_components(G)             

                                                   
def _GirvanNewmanGetModularity(G, deg_, m_): #②
    New_A = nx.adjacency_matrix(G)                      
    New_deg = {}
    New_deg = UpdateDeg(New_A, G.nodes())                       
                                                                           
    comps = nx.connected_components(G)                                                         
    print('Number of communities in decomposed G: {}'.format(nx.number_connected_components(G)))
    Mod = 0                                                                                  
    for c in comps:
        EWC = 0                                                                       
        RE = 0                                                                            
        for u in c:
            EWC += New_deg[u]   
            RE += deg_[u]                   
        Mod += ( float(EWC) - float(RE*RE)/float(4*m_) )                      
    Mod = Mod/float(m_)
    if _DEBUG_:
        print("Modularity: {}".format(Mod))
    return Mod

                                                                      
def UpdateDeg(A, nodes): #                                 
    deg_dict = {}
    n = len(nodes)             
    B = A.sum(axis = 1)                               
    i = 0
    for node_id in list(nodes): 
        deg_dict[node_id] = B[i]        
        i += 1
    return deg_dict
   


                                                                                                        
def runGirvanNewman(G, Orig_deg, m_): #④
                                                                                                      
    BestQ = 0.0
    Q = 0.0
    while True:    
        CmtyGirvanNewmanStep(G)                                                 
        Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);      
        print("Modularity of decomposed G: {}".format(Q))
        if Q > BestQ:
            BestQ = Q                                            
            Bestcomps = list(nx.connected_components(G))    #Best Split
            print("Identified components: {}".format(Bestcomps))
        if G.number_of_edges() == 0:                               
            break
    if BestQ > 0.0:                                                                       
        print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
        print("Graph communities: {}".format(Bestcomps))
    else:
        print("Max modularity (Q):", BestQ)

# %%
#セクション4.1 ②
#グラフリスト Jaccard係数 重複なしversion


import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_j = [[0]*3 for i in range(total)]


a_b = []

c = 0
for a in sum_list:
  c += 1
  d = 0
  for b in sum_list:
    d += 1
    if d > c:
      a_b_list = set(a) & set(b)
      a_b.append((len(a_b_list))/((len(a)-1)+(len(b)-1)-(len(a_b_list))))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_j[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_j[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_j[e][2] = a_b[e]
      
print(matrix_j)
# Out:
# [['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 0.021247099300080105], ['Jiyuminsyu_Leader', 'Komei_Leader', 0.011712698088971423], ['Jiyuminsyu_Leader', 'Kyosan_Leader', 0.033902019140153936], ['Jiyuminsyu_Leader', 'Ishin_Leader', 0.06744714864998068], ['Jiyuminsyu_Leader', 'Kokuminminsyu_Leader', 0.10088793837561005], ['Jiyuminsyu_Leader', 'Syakaiminsyu_Leader', 0.031074149282951838], ['Jiyuminsyu_Leader', 'Reiwa_Leader', 0.03781705108027506], ['Jiyuminsyu_Leader', 'Jiyuminsyu_Suga', 0.16519687526735943], ['Jiyuminsyu_Leader', 'Jiyuminsyu_Kono', 0.09021286890984871], ['Jiyuminsyu_Leader', 'Rikkenminsyu_Edano', 0.04771339070104742], ['Jiyuminsyu_Leader', 'Rikkenminsyu_Renho', 0.03690627323267866], ['Jiyuminsyu_Leader', 'Ishin_Yoshimura', 0.0660403459455834], ['Jiyuminsyu_Leader', 'Ishin_Hashimoto', 0.041601687829350344], ['Rikkenminsyu_Leader', 'Komei_Leader', 0.031068743286788398], ['Rikkenminsyu_Leader', 'Kyosan_Leader', 0.057191824298590835], ['Rikkenminsyu_Leader', 'Ishin_Leader', 0.018186554210482587], ['Rikkenminsyu_Leader', 'Kokuminminsyu_Leader', 0.06454478419670463], ['Rikkenminsyu_Leader', 'Syakaiminsyu_Leader', 0.046957595091434455], ['Rikkenminsyu_Leader', 'Reiwa_Leader', 0.028224122115612687], ['Rikkenminsyu_Leader', 'Jiyuminsyu_Suga', 0.01689193980739501], ['Rikkenminsyu_Leader', 'Jiyuminsyu_Kono', 0.005350464095218601], ['Rikkenminsyu_Leader', 'Rikkenminsyu_Edano', 0.08099728190195468], ['Rikkenminsyu_Leader', 'Rikkenminsyu_Renho', 0.024460988464231746], ['Rikkenminsyu_Leader', 'Ishin_Yoshimura', 0.007268555133850923], ['Rikkenminsyu_Leader', 'Ishin_Hashimoto', 0.004252082650846861], ['Komei_Leader', 'Kyosan_Leader', 0.02520107238605898], ['Komei_Leader', 'Ishin_Leader', 0.018325629702111955], ['Komei_Leader', 'Kokuminminsyu_Leader', 0.027288826875603734], ['Komei_Leader', 'Syakaiminsyu_Leader', 0.031982895674579244], ['Komei_Leader', 'Reiwa_Leader', 0.014312285737539279], ['Komei_Leader', 'Jiyuminsyu_Suga', 0.01623175230814185], ['Komei_Leader', 'Jiyuminsyu_Kono', 0.006016895954378996], ['Komei_Leader', 'Rikkenminsyu_Edano', 0.03182198456928109], ['Komei_Leader', 'Rikkenminsyu_Renho', 0.016228019970238358], ['Komei_Leader', 'Ishin_Yoshimura', 0.006680303382411704], ['Komei_Leader', 'Ishin_Hashimoto', 0.005471454894453456], ['Kyosan_Leader', 'Ishin_Leader', 0.03734528522761651], ['Kyosan_Leader', 'Kokuminminsyu_Leader', 0.09232642302999727], ['Kyosan_Leader', 'Syakaiminsyu_Leader', 0.1826025547376394], ['Kyosan_Leader', 'Reiwa_Leader', 0.15082196765243003], ['Kyosan_Leader', 'Jiyuminsyu_Suga', 0.03807258489176119], ['Kyosan_Leader', 'Jiyuminsyu_Kono', 0.02008957217049129], ['Kyosan_Leader', 'Rikkenminsyu_Edano', 0.1986852188685865], ['Kyosan_Leader', 'Rikkenminsyu_Renho', 0.08315549917371727], ['Kyosan_Leader', 'Ishin_Yoshimura', 0.02143959301488714], ['Kyosan_Leader', 'Ishin_Hashimoto', 0.016942205219292253], ['Ishin_Leader', 'Kokuminminsyu_Leader', 0.0862818847137053], ['Ishin_Leader', 'Syakaiminsyu_Leader', 0.05298478844433082], ['Ishin_Leader', 'Reiwa_Leader', 0.04333153490537095], ['Ishin_Leader', 'Jiyuminsyu_Suga', 0.1064945657436234], ['Ishin_Leader', 'Jiyuminsyu_Kono', 0.06383507084032414], ['Ishin_Leader', 'Rikkenminsyu_Edano', 0.0505372120109441], ['Ishin_Leader', 'Rikkenminsyu_Renho', 0.05672231197271585], ['Ishin_Leader', 'Ishin_Yoshimura', 0.23051757182912677], ['Ishin_Leader', 'Ishin_Hashimoto', 0.10899084158618003], ['Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 0.09467976743792175], ['Kokuminminsyu_Leader', 'Reiwa_Leader', 0.07445732685654245], ['Kokuminminsyu_Leader', 'Jiyuminsyu_Suga', 0.10061435863635121], ['Kokuminminsyu_Leader', 'Jiyuminsyu_Kono', 0.04240176720115778], ['Kokuminminsyu_Leader', 'Rikkenminsyu_Edano', 0.12906902500224035], ['Kokuminminsyu_Leader', 'Rikkenminsyu_Renho', 0.06562310572294526], ['Kokuminminsyu_Leader', 'Ishin_Yoshimura', 0.04594010009185198], ['Kokuminminsyu_Leader', 'Ishin_Hashimoto', 0.028860614274944536], ['Syakaiminsyu_Leader', 'Reiwa_Leader', 0.166462029796470 ...

# %%
#セクション4.2 ②
#グラフリスト Dice係数
import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_d = [[0]*3 for i in range(total)]


a_b = []

c = 0
for a in sum_list:
  c += 1
  d = 0
  for b in sum_list:
    d += 1
    if d > c:
      a_b_list = set(a) & set(b)
      a_b.append((len(a_b_list)*2)/((len(a)-1)+(len(b)-1)))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_d[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_d[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_d[e][2] = a_b[e]
      
print(matrix_d)

# %%
#セクション4.3 ②
#グラフリスト Simpson係数
import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_s = [[0]*3 for i in range(total)]


a_b = []

c = 0
for a in sum_list:
  c += 1
  d = 0
  for b in sum_list:
    d += 1
    if d > c:
      a_b_list = set(a) & set(b)
      a_b.append(len(set(a) & set(b))/min((len(a)-1), (len(b)-1)))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_s[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_s[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_s[e][2] = a_b[e]
      
print(matrix_s)

# %%
#セクション4 ②
#グラフリスト Simpson係数の拡張

import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
matrix_sk = [[0]*3 for i in range(len(sum_engname_list)**2)]

a_b_ = []

for a in sum_list:
  for b in sum_list:
    if a == b:
      a_b_.append(1)
    else:
      a_b_.append(len(set(a) & set(b))/(len(a)-1))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 14):
      for i in range(14):
        matrix_sk[i+k][n] = sum_engname_list[k//14]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 14):
      for i in range(14):
        matrix_sk[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 14):
      for i in range(14):
        t += 1
        matrix_sk[i+k][n] = round(a_b_[t], 4)
        

print(matrix_sk)
# Out:
# [['Jiyuminsyu_Leader', 'Jiyuminsyu_Leader', 1], ['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 0.0219], ['Jiyuminsyu_Leader', 'Komei_Leader', 0.0127], ['Jiyuminsyu_Leader', 'Kyosan_Leader', 0.0458], ['Jiyuminsyu_Leader', 'Ishin_Leader', 0.1152], ['Jiyuminsyu_Leader', 'Kokuminminsyu_Leader', 0.1305], ['Jiyuminsyu_Leader', 'Syakaiminsyu_Leader', 0.0438], ['Jiyuminsyu_Leader', 'Reiwa_Leader', 0.069], ['Jiyuminsyu_Leader', 'Jiyuminsyu_Suga', 0.2916], ['Jiyuminsyu_Leader', 'Jiyuminsyu_Kono', 0.4764], ['Jiyuminsyu_Leader', 'Rikkenminsyu_Edano', 0.0618], ['Jiyuminsyu_Leader', 'Rikkenminsyu_Renho', 0.072], ['Jiyuminsyu_Leader', 'Ishin_Yoshimura', 0.2135], ['Jiyuminsyu_Leader', 'Ishin_Hashimoto', 0.2485], ['Rikkenminsyu_Leader', 'Jiyuminsyu_Leader', 0.4069], ['Rikkenminsyu_Leader', 'Rikkenminsyu_Leader', 1], ['Rikkenminsyu_Leader', 'Komei_Leader', 0.0831], ['Rikkenminsyu_Leader', 'Kyosan_Leader', 0.4532], ['Rikkenminsyu_Leader', 'Ishin_Leader', 0.291], ['Rikkenminsyu_Leader', 'Kokuminminsyu_Leader', 0.5378], ['Rikkenminsyu_Leader', 'Syakaiminsyu_Leader', 0.421], ['Rikkenminsyu_Leader', 'Reiwa_Leader', 0.4831], ['Rikkenminsyu_Leader', 'Jiyuminsyu_Suga', 0.3423], ['Rikkenminsyu_Leader', 'Jiyuminsyu_Kono', 0.4752], ['Rikkenminsyu_Leader', 'Rikkenminsyu_Edano', 0.5706], ['Rikkenminsyu_Leader', 'Rikkenminsyu_Renho', 0.4769], ['Rikkenminsyu_Leader', 'Ishin_Yoshimura', 0.3348], ['Rikkenminsyu_Leader', 'Ishin_Hashimoto', 0.4146], ['Komei_Leader', 'Jiyuminsyu_Leader', 0.1337], ['Komei_Leader', 'Rikkenminsyu_Leader', 0.0473], ['Komei_Leader', 'Komei_Leader', 1], ['Komei_Leader', 'Kyosan_Leader', 0.1277], ['Komei_Leader', 'Ishin_Leader', 0.1744], ['Komei_Leader', 'Kokuminminsyu_Leader', 0.1454], ['Komei_Leader', 'Syakaiminsyu_Leader', 0.1787], ['Komei_Leader', 'Reiwa_Leader', 0.1473], ['Komei_Leader', 'Jiyuminsyu_Suga', 0.194], ['Komei_Leader', 'Jiyuminsyu_Kono', 0.3062], ['Komei_Leader', 'Rikkenminsyu_Edano', 0.1468], ['Komei_Leader', 'Rikkenminsyu_Renho', 0.1882], ['Komei_Leader', 'Ishin_Yoshimura', 0.1779], ['Komei_Leader', 'Ishin_Hashimoto', 0.3052], ['Kyosan_Leader', 'Jiyuminsyu_Leader', 0.1153], ['Kyosan_Leader', 'Rikkenminsyu_Leader', 0.0614], ['Kyosan_Leader', 'Komei_Leader', 0.0304], ['Kyosan_Leader', 'Kyosan_Leader', 1], ['Kyosan_Leader', 'Ishin_Leader', 0.1106], ['Kyosan_Leader', 'Kokuminminsyu_Leader', 0.1747], ['Kyosan_Leader', 'Syakaiminsyu_Leader', 0.3299], ['Kyosan_Leader', 'Reiwa_Leader', 0.4259], ['Kyosan_Leader', 'Jiyuminsyu_Suga', 0.1342], ['Kyosan_Leader', 'Jiyuminsyu_Kono', 0.2554], ['Kyosan_Leader', 'Rikkenminsyu_Edano', 0.3144], ['Kyosan_Leader', 'Rikkenminsyu_Renho', 0.2742], ['Kyosan_Leader', 'Ishin_Yoshimura', 0.1502], ['Kyosan_Leader', 'Ishin_Hashimoto', 0.2355], ['Ishin_Leader', 'Jiyuminsyu_Leader', 0.1399], ['Ishin_Leader', 'Rikkenminsyu_Leader', 0.019], ['Ishin_Leader', 'Komei_Leader', 0.0201], ['Ishin_Leader', 'Kyosan_Leader', 0.0534], ['Ishin_Leader', 'Ishin_Leader', 1], ['Ishin_Leader', 'Kokuminminsyu_Leader', 0.1203], ['Ishin_Leader', 'Syakaiminsyu_Leader', 0.0779], ['Ishin_Leader', 'Reiwa_Leader', 0.0866], ['Ishin_Leader', 'Jiyuminsyu_Suga', 0.2197], ['Ishin_Leader', 'Jiyuminsyu_Kono', 0.4065], ['Ishin_Leader', 'Rikkenminsyu_Edano', 0.0689], ['Ishin_Leader', 'Rikkenminsyu_Renho', 0.1203], ['Ishin_Leader', 'Ishin_Yoshimura', 0.7435], ['Ishin_Leader', 'Ishin_Hashimoto', 0.7212], ['Kokuminminsyu_Leader', 'Jiyuminsyu_Leader', 0.3078], ['Kokuminminsyu_Leader', 'Rikkenminsyu_Leader', 0.0683], ['Kokuminminsyu_Leader', 'Komei_Leader', 0.0325], ['Kokuminminsyu_Leader', 'Kyosan_Leader', 0.1638], ['Kokuminminsyu_Leader', 'Ishin_Leader', 0.2338], ['Kokuminminsyu_Leader', 'Kokuminminsyu_Leader', 1], ['Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 0.1787], ['Kokuminminsyu_Leader', 'Reiwa_Leader', 0.2155], ['Kokuminminsyu_Leader', 'Jiyuminsyu_Suga', 0.3192], ['Kokuminminsyu_Leader', 'Jiyuminsyu_Kono', 0.4971], ['Kokuminminsyu_Leader', 'Rikkenminsyu_Edano', 0.2104], ['Kokuminminsyu_Leader', 'Rikkenminsyu_Renho', 0.2101], ['Kokum ...

# %%
#セクション4.1
#グラフリスト 
Simpson係数の拡張 = 0.5

matrix_con = []
for i in range(len(matrix_sk)):
  if matrix_sk[i][2] >= Simpson係数の拡張 and matrix_sk[i][2] != 1:
    matrix_con.append(matrix_sk[i])

H = nx.DiGraph()
for n in sum_engname_list:
    H.add_node(n)
size =[((len(i)-1)/800) for i in sum_list]
H.add_weighted_edges_from(matrix_con)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]
# pos = nx.spring_layout(H, k=2) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(12,8))
nx.draw_networkx(H, pos,node_size = size, arrows=True, width=[v['weight'] * 7 for v in H.edges.values()], connectionstyle="arc3, rad=0.1")

# %% [markdown]
# - draw_circular 頂点を円周上に配置
# - draw_kamada_kawai 頂点を力学モデルにより配置
# - draw_random 頂点をランダムに配置
# - draw_spectral ネットワークを表す行列の固有ベクトルにより、頂点を配置
# - draw_spring 頂点を力学モデルにより配置
# - draw_shell 頂点を同心円上に配置

# %%
G = nx.Graph()  #let's create the graph first
buildG(G, matrix_con) #ここに三次元リストを入れて実行！
    
if _DEBUG_:
  print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
n = G.number_of_nodes()    #|V|
A = nx.adjacency_matrix(G)    #adjacenct matrix

m_ = 0.0    #the weighted version for number of edges
for i in range(0,n):
  for j in range(0,n):
    m_ += A[i,j]
m_ = m_/2.0
if _DEBUG_:
        print("m: {}".format(m_))

    #calculate the weighted degree for each node
Orig_deg = {}
Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
runGirvanNewman(G, Orig_deg, m_)
# Out:
# Number of communities in decomposed G: 8
# Modularity of decomposed G: 0.4472007440579323
# Identified components: [{'Rikkenminsyu_Leader'}, {'Kokuminminsyu_Leader'}, {'Rikkenminsyu_Edano'}, {'Ishin_Leader'}, {'Ishin_Yoshimura'}, {'Ishin_Hashimoto'}, {'Syakaiminsyu_Leader', 'Rikkenminsyu_Renho'}, {'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono'}]
# Number of communities in decomposed G: 10
# Modularity of decomposed G: -0.11702147260949385
# Max modularity found (Q): 0.4472007440579323 and number of communities: 8
# Graph communities: [{'Rikkenminsyu_Leader'}, {'Kokuminminsyu_Leader'}, {'Rikkenminsyu_Edano'}, {'Ishin_Leader'}, {'Ishin_Yoshimura'}, {'Ishin_Hashimoto'}, {'Syakaiminsyu_Leader', 'Rikkenminsyu_Renho'}, {'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono'}]
