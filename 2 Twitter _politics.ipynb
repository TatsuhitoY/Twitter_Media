# %%
#セクション2
import csv

filename = '23.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_lists=[]
    for row in csvreader:
      自由民主党_lists += row

    print('データ取得終了時刻：', 自由民主党_lists[-2])
    del 自由民主党_lists[-1]
    del 自由民主党_lists[-1]

    unique_set = set(自由民主党_lists)
    自由民主党_list = list(unique_set)
    自由民主党_list.append('自由民主党')

    print('自由民主党のフォロワー数：', len(自由民主党_list)-1)
    print('\n')

filename = '24.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_lists=[]
    for row in csvreader:
      立憲民主党_lists += row

    print('データ取得終了時刻：', 立憲民主党_lists[-2])
    del 立憲民主党_lists[-1]
    del 立憲民主党_lists[-1]

    unique_set = set(立憲民主党_lists)
    立憲民主党_list = list(unique_set)
    立憲民主党_list.append('立憲民主党')

    print('立憲民主党のフォロワー数：', len(立憲民主党_list)-1)
    print('\n')

filename = '25.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    公明党_lists=[]
    for row in csvreader:
      公明党_lists += row

    print('データ取得終了時刻：', 公明党_lists[-2])
    del 公明党_lists[-1]
    del 公明党_lists[-1]

    unique_set = set(公明党_lists)
    公明党_list = list(unique_set)
    公明党_list.append('公明党')

    print('公明党のフォロワー数：', len(公明党_list)-1)
    print('\n')

filename = '26.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本共産党_lists=[]
    for row in csvreader:
      日本共産党_lists += row

    print('データ取得終了時刻：', 日本共産党_lists[-2])
    del 日本共産党_lists[-1]
    del 日本共産党_lists[-1]

    unique_set = set(日本共産党_lists)
    日本共産党_list = list(unique_set)
    日本共産党_list.append('日本共産党')

    print('日本共産党のフォロワー数：', len(日本共産党_list)-1)
    print('\n')

filename = '27.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_lists=[]
    for row in csvreader:
      日本維新の会_lists += row

    print('データ取得終了時刻：', 日本維新の会_lists[-2])
    del 日本維新の会_lists[-1]
    del 日本維新の会_lists[-1]

    unique_set = set(日本維新の会_lists)
    日本維新の会_list = list(unique_set)
    日本維新の会_list.append('日本維新の会')

    print('日本維新の会のフォロワー数：', len(日本維新の会_list)-1)
    print('\n')

filename = '28.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    国民民主党_lists=[]
    for row in csvreader:
      国民民主党_lists += row

    print('データ取得終了時刻：', 国民民主党_lists[-2])
    del 国民民主党_lists[-1]
    del 国民民主党_lists[-1]

    unique_set = set(国民民主党_lists)
    国民民主党_list = list(unique_set)
    国民民主党_list.append('国民民主党')

    print('国民民主党のフォロワー数：', len(国民民主党_list)-1)
    print('\n')

filename = '29.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    社会民主党_lists=[]
    for row in csvreader:
      社会民主党_lists += row

    print('データ取得終了時刻：', 社会民主党_lists[-2])
    del 社会民主党_lists[-1]
    del 社会民主党_lists[-1]

    unique_set = set(社会民主党_lists)
    社会民主党_list = list(unique_set)
    社会民主党_list.append('社会民主党')

    print('社会民主党のフォロワー数：', len(社会民主党_list)-1)
    print('\n')

filename = '30.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    れいわ新選組_lists=[]
    for row in csvreader:
      れいわ新選組_lists += row

    print('データ取得終了時刻：', れいわ新選組_lists[-2])
    del れいわ新選組_lists[-1]
    del れいわ新選組_lists[-1]

    unique_set = set(れいわ新選組_lists)
    れいわ新選組_list = list(unique_set)
    れいわ新選組_list.append('れいわ新選組')

    print('れいわ新選組のフォロワー数：', len(れいわ新選組_list)-1)
    print('\n')

sum_list = [自由民主党_list, 立憲民主党_list, 公明党_list, 日本共産党_list, 日本維新の会_list, 国民民主党_list, 社会民主党_list, れいわ新選組_list]
# Out:
# データ取得終了時刻： 2022-04-27T20:04:33
# 自由民主党のフォロワー数： 239712
#
#
# データ取得終了時刻： 2022-04-27T21:50:12
# 立憲民主党のフォロワー数： 191978
#
#
# データ取得終了時刻： 2022-04-27T22:20:20
# 公明党のフォロワー数： 103607
#
#
# データ取得終了時刻： 2022-04-27T22:50:29
# 日本共産党のフォロワー数： 127694
#
#
# データ取得終了時刻： 2022-04-27T22:50:32
# 日本維新の会のフォロワー数： 64812
#
#
# データ取得終了時刻： 2022-04-27T23:05:35
# 国民民主党のフォロワー数： 43724
#
#
# データ取得終了時刻： 2022-04-28T00:14:47
# 社会民主党のフォロワー数： 45234
#
#
# データ取得終了時刻： 2022-04-28T00:44:56
# れいわ新選組のフォロワー数： 113374

# %%
import networkx as nx
import math
import csv
import random as rand
import sys

_DEBUG_ = False
                 
def buildG(G, list):                                       
    for line in list:
       G.add_edge(line[0], line[1],weight=float(line[2]))            

def CmtyGirvanNewmanStep(G): #③
    if _DEBUG_:
        print("Running CmtyGirvanNewmanStep method ...")
    init_ncomp = nx.number_connected_components(G)     
    ncomp = init_ncomp                                      
    while ncomp <= init_ncomp:
        bw = nx.edge_betweenness_centrality(G, weight='weight')                              
        max_ = max(bw.values())                                    
        for k, v in bw.items():                    
            if float(v) == max_:
                G.remove_edge(k[0],k[1])                    
        ncomp = nx.number_connected_components(G)             
                                                   
def _GirvanNewmanGetModularity(G, deg_, m_): #②
    New_A = nx.adjacency_matrix(G)                      
    New_deg = {}
    New_deg = UpdateDeg(New_A, G.nodes())                       
                                                                           
    comps = nx.connected_components(G)                                                         
    print('Number of communities in decomposed G: {}'.format(nx.number_connected_components(G)))
    Mod = 0                                                                                  
    for c in comps:
        EWC = 0                                                                       
        RE = 0                                                                            
        for u in c:
            EWC += New_deg[u]   
            RE += deg_[u]                   
        Mod += ( float(EWC) - float(RE*RE)/float(4*m_) )                      
    Mod = Mod/float(m_)
    if _DEBUG_:
        print("Modularity: {}".format(Mod))
    return Mod
                                                                      
def UpdateDeg(A, nodes): #                                 
    deg_dict = {}
    n = len(nodes)             
    B = A.sum(axis = 1)                               
    i = 0
    for node_id in list(nodes): 
        deg_dict[node_id] = B[i]        
        i += 1
    return deg_dict
   
def runGirvanNewman(G, Orig_deg, m_): #④
                                                                                                      
    BestQ = 0.0
    Q = 0.0
    while True:    
        CmtyGirvanNewmanStep(G)                                                 
        Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);      
        print("Modularity of decomposed G: {}".format(Q))
        if Q > BestQ:
            BestQ = Q                                            
            Bestcomps = list(nx.connected_components(G))    #Best Split
            print("Identified components: {}".format(Bestcomps))
        if G.number_of_edges() == 0:                               
            break
    if BestQ > 0.0:                                                                       
        print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
        print("Graph communities: {}".format(Bestcomps))
    else:
        print("Max modularity (Q):", BestQ)

# %%
#セクション3.1 
#フォロワー総数（重複ありあり/なし）

sum_total_list = 自由民主党_list + 立憲民主党_list + 公明党_list + 日本共産党_list + 日本維新の会_list + 国民民主党_list + 社会民主党_list + れいわ新選組_list

print('収集したフォロワーIDの総数：', len(sum_total_list)-8)
print('フォロワーの総数', len(set(sum_total_list))-8)

# %%
#セクションセクション3.2 
#アカウント同士の共通項の数

for n in sum_list:
  for k in sum_list:
    if n == k:
      continue
    n_k_= set(n) & set(k)
    print(n[-1], 'と', k[-1], 'の共通項の数は', len(n_k_))
  print('\n')

# %%
#セクション4.1 ②
#グラフリスト Jaccard係数 重複なしversion


import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['自由民主党', '立憲民主党', '公明党', '日本共産党',  '日本維新の会', '国民民主党', '社会民主党', 'れいわ新選組']
sum_engname_list = ['jiyuminsyu', 'rikkenminsyu', 'komei', 'kyosan', 'ishin', 'kokuminminsyu', 'syakaiminsyu', 'reiwa']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_j = [[0]*3 for i in range(total)]


a_b = []

c = 0
for a in sum_list:
  c += 1
  d = 0
  for b in sum_list:
    d += 1
    if d > c:
      a_b_list = set(a) & set(b)
      a_b.append((len(a_b_list))/((len(a)-1)+(len(b)-1)-(len(a_b_list))))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_j[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_j[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_j[e][2] = a_b[e]
      
print(matrix_j)
# Out:
# [['jiyuminsyu', 'rikkenminsyu', 0.08354019884188782], ['jiyuminsyu', 'komei', 0.14108372026549584], ['jiyuminsyu', 'kyosan', 0.08212403872491701], ['jiyuminsyu', 'ishin', 0.09269405901159349], ['jiyuminsyu', 'kokuminminsyu', 0.05745496873554299], ['jiyuminsyu', 'syakaiminsyu', 0.06642265286416814], ['jiyuminsyu', 'reiwa', 0.030754544578763456], ['rikkenminsyu', 'komei', 0.05422997360724731], ['rikkenminsyu', 'kyosan', 0.21426862111272757], ['rikkenminsyu', 'ishin', 0.05304813535968243], ['rikkenminsyu', 'kokuminminsyu', 0.08171291940687572], ['rikkenminsyu', 'syakaiminsyu', 0.14051358979166967], ['rikkenminsyu', 'reiwa', 0.13142780919068334], ['komei', 'kyosan', 0.07875884970197841], ['komei', 'ishin', 0.06001900769748809], ['komei', 'kokuminminsyu', 0.05389242973740495], ['komei', 'syakaiminsyu', 0.09322942680024679], ['komei', 'reiwa', 0.0268665051300496], ['kyosan', 'ishin', 0.05773689820767261], ['kyosan', 'kokuminminsyu', 0.08253972263621896], ['kyosan', 'syakaiminsyu', 0.244641
# ...

# %%
G = nx.Graph()  #let's create the graph first
buildG(G, matrix_con)
    
if _DEBUG_:
  print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
n = G.number_of_nodes()    #|V|
A = nx.adjacency_matrix(G)    #adjacenct matrix

m_ = 0.0    #the weighted version for number of edges
for i in range(0,n):
  for j in range(0,n):
    m_ += A[i,j]
m_ = m_/2.0
if _DEBUG_:
        print("m: {}".format(m_))

    #calculate the weighted degree for each node
Orig_deg = {}
Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
runGirvanNewman(G, Orig_deg, m_)

# %%
#セクション4.1.1 
#グラフリスト 条件:Jaccard係数 >= 0.08

import networkx as nx
import matplotlib.pyplot as plt

matrix_con = []
for i in range(len(matrix_j)):
  if matrix_j[i][2] >= 0.1 and matrix_j[i][2] != 1: #右の条件式でアカウントの自己ループをなくす
    matrix_con.append(matrix_j[i])

H = nx.Graph()
H.add_weighted_edges_from(matrix_con)

edge_width = [d["weight"] * 20  for (u, v, d) in H.edges(data=True)]
pos = nx.spring_layout(H, k=0.8) 

nx.draw_kamada_kawai(H, with_labels=True, width=edge_width)

# %%
from networkx.algorithms.community import greedy_modularity_communities

c = greedy_modularity_communities(H)
sorted(c[0])
# Out:
# ['kyosan', 'reiwa', 'rikkenminsyu']

# %%
#セクション4.2 ②
#グラフリスト Dice係数
import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['自由民主党', '立憲民主党', '公明党', '日本共産党',  '日本維新の会', '国民民主党', '社会民主党', 'れいわ新選組']
sum_engname_list = ['jiyuminsyu', 'rikkenminsyu', 'komei', 'kyosan', 'ishin', 'kokuminminsyu', 'syakaiminsyu', 'reiwa']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_d = [[0]*3 for i in range(total)]


a_b = []

c = 0
for a in sum_list:
  c += 1
  d = 0
  for b in sum_list:
    d += 1
    if d > c:
      a_b_list = set(a) & set(b)
      a_b.append((len(a_b_list)*2)/((len(a)-1)+(len(b)-1)))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_d[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_d[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_d[e][2] = a_b[e]
      
print(matrix_d)
# Out:
# [['jiyuminsyu', 'rikkenminsyu', 0.15419861474669322], ['jiyuminsyu', 'komei', 0.24728022626187307], ['jiyuminsyu', 'kyosan', 0.15178304110439134], ['jiyuminsyu', 'ishin', 0.16966150451195966], ['jiyuminsyu', 'kokuminminsyu', 0.10866650672462214], ['jiyuminsyu', 'syakaiminsyu', 0.12457097134193847], ['jiyuminsyu', 'reiwa', 0.05967384716471341], ['rikkenminsyu', 'komei', 0.10288072804776968], ['rikkenminsyu', 'kyosan', 0.35291799094071424], ['rikkenminsyu', 'ishin', 0.10075158689980139], ['rikkenminsyu', 'kokuminminsyu', 0.1510806017768199], ['rikkenminsyu', 'syakaiminsyu', 0.24640406050284133], ['rikkenminsyu', 'reiwa', 0.23232204144724777], ['komei', 'kyosan', 0.1460175269454088], ['komei', 'ishin', 0.11324138012932032], ['komei', 'kokuminminsyu', 0.10227311292260284], ['komei', 'syakaiminsyu', 0.17055784360492068], ['komei', 'reiwa', 0.05232716228609878], ['kyosan', 'ishin', 0.1091706232533012], ['kyosan', 'kokuminminsyu', 0.15249273705211822], ['kyosan', 'syakaiminsyu', 0.393111584
# ...

# %%
#セクション4.2.1 
#グラフリスト 条件:
Dice係数 = 0.2

import networkx as nx
import matplotlib.pyplot as plt

matrix_con1 = []
for i in range(len(matrix_d)):
  if matrix_d[i][2] >= Dice係数 and matrix_d[i][2] != 1: #右の条件式でアカウントの自己ループをなくす
    matrix_con1.append(matrix_d[i])

H = nx.Graph()
H.add_weighted_edges_from(matrix_con1)

edge_width = [d["weight"] * 8  for (u, v, d) in H.edges(data=True)]
pos = nx.spring_layout(H, k=0.70) 

nx.draw_kamada_kawai(H, with_labels=True, width=edge_width)

# %%
#セクション4.3 ②
#グラフリスト Simpson係数
import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['自由民主党', '立憲民主党', '公明党', '日本共産党',  '日本維新の会', '国民民主党', '社会民主党', 'れいわ新選組']
sum_engname_list = ['jiyuminsyu', 'rikkenminsyu', 'komei', 'kyosan', 'ishin', 'kokuminminsyu', 'syakaiminsyu', 'reiwa']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_s = [[0]*3 for i in range(total)]


a_b = []

c = 0
for a in sum_list:
  c += 1
  d = 0
  for b in sum_list:
    d += 1
    if d > c:
      a_b_list = set(a) & set(b)
      a_b.append(len(set(a) & set(b))/min((len(a)-1), (len(b)-1)))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_s[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_s[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_s[e][2] = a_b[e]
      
print(matrix_s)

# %%
#セクション4.3.3
#グラフリスト 条件:
Simpson係数 = 0.20

matrix_con = []
for i in range(len(matrix_s)):
  if matrix_s[i][2] >= Simpson係数 and matrix_s[i][2] != 1:
    matrix_con.append(matrix_s[i])

H = nx.Graph()
H.add_weighted_edges_from(matrix_con)

edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]
pos = nx.spring_layout(H, k=0.3) 

nx.draw_kamada_kawai(H, with_labels=True, width=edge_width)

# %%
#セクション4.4 ②
#グラフリスト Simpson係数の拡張

import networkx as nx
import matplotlib.pyplot as plt

sum_name_list = ['自由民主党', '立憲民主党', '公明党', '日本共産党',  '日本維新の会', '国民民主党', '社会民主党', 'れいわ新選組']
sum_engname_list = ['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa']
matrix_sk = [[0]*3 for i in range(len(sum_engname_list)**2)]

a_b_ = []

for a in sum_list:
  for b in sum_list:
    if a == b:
      a_b_.append(1)
    else:
      a_b_.append(len(set(a) & set(b))/(len(a)-1))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 8):
      for i in range(8):
        matrix_sk[i+k][n] = sum_engname_list[k//8]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 8):
      for i in range(8):
        matrix_sk[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 8):
      for i in range(8):
        t += 1
        matrix_sk[i+k][n] = round(a_b_[t], 4)
        

print(matrix_sk)
# Out:
# [['Jiyuminsyu', 'Jiyuminsyu', 1], ['Jiyuminsyu', 'Rikkenminsyu', 0.1388], ['Jiyuminsyu', 'Komei', 0.1771], ['Jiyuminsyu', 'Kyosan', 0.1163], ['Jiyuminsyu', 'Ishin', 0.1078], ['Jiyuminsyu', 'Kokuminminsyu', 0.0642], ['Jiyuminsyu', 'Syakaiminsyu', 0.074], ['Jiyuminsyu', 'Reiwa', 0.0439], ['Rikkenminsyu', 'Jiyuminsyu', 0.1734], ['Rikkenminsyu', 'Rikkenminsyu', 1], ['Rikkenminsyu', 'Komei', 0.0792], ['Rikkenminsyu', 'Kyosan', 0.2938], ['Rikkenminsyu', 'Ishin', 0.0674], ['Rikkenminsyu', 'Kokuminminsyu', 0.0927], ['Rikkenminsyu', 'Syakaiminsyu', 0.1522], ['Rikkenminsyu', 'Reiwa', 0.1848], ['Komei', 'Jiyuminsyu', 0.4097], ['Komei', 'Rikkenminsyu', 0.1468], ['Komei', 'Komei', 1], ['Komei', 'Kyosan', 0.163], ['Komei', 'Ishin', 0.092], ['Komei', 'Kokuminminsyu', 0.0727], ['Komei', 'Syakaiminsyu', 0.1225], ['Komei', 'Reiwa', 0.0548], ['Kyosan', 'Jiyuminsyu', 0.2184], ['Kyosan', 'Rikkenminsyu', 0.4418], ['Kyosan', 'Komei', 0.1322], ['Kyosan', 'Kyosan', 1], ['Kyosan', 'Ishin', 0.0823], ['Kyosan',
# ...

# %%
#セクション4.3.3
#グラフリスト 
Simpson係数の拡張 = 0.3

matrix_con = []
for i in range(len(matrix_sk)):
  if matrix_sk[i][2] >= Simpson係数の拡張 and matrix_sk[i][2] != 1:
    matrix_con.append(matrix_sk[i])
print(matrix_con)

H = nx.DiGraph()
for n in sum_engname_list:
    H.add_node(n)
size =[((len(i)-1)/50) for i in sum_list]
H.add_weighted_edges_from(matrix_con)
edge_width = [d["weight"] * 7  for (u, v, d) in H.edges(data=True)]
# pos = nx.spring_layout(H, k=1) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(12,8))
nx.draw_networkx(H, pos,node_size = size, arrows=True, width=edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# [['Komei', 'Jiyuminsyu', 0.4097], ['Kyosan', 'Rikkenminsyu', 0.4418], ['Ishin', 'Jiyuminsyu', 0.3986], ['Kokuminminsyu', 'Jiyuminsyu', 0.3522], ['Kokuminminsyu', 'Rikkenminsyu', 0.4072], ['Syakaiminsyu', 'Jiyuminsyu', 0.3924], ['Syakaiminsyu', 'Rikkenminsyu', 0.6461], ['Syakaiminsyu', 'Kyosan', 0.7514], ['Reiwa', 'Rikkenminsyu', 0.3129]]

# %% [markdown]
# - draw_circular 頂点を円周上に配置
# - draw_kamada_kawai 頂点を力学モデルにより配置
# - draw_random 頂点をランダムに配置
# - draw_spectral ネットワークを表す行列の固有ベクトルにより、頂点を配置
# - draw_spring 頂点を力学モデルにより配置
# - draw_shell 頂点を同心円上に配置

# %%
G = nx.Graph()  #let's create the graph first
buildG(G, matrix_con) #ここに三次元リストを入れて実行！
    
if _DEBUG_:
  print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
n = G.number_of_nodes()    #|V|
A = nx.adjacency_matrix(G)    #adjacenct matrix

m_ = 0.0    #the weighted version for number of edges
for i in range(0,n):
  for j in range(0,n):
    m_ += A[i,j]
m_ = m_/2.0
if _DEBUG_:
        print("m: {}".format(m_))

    #calculate the weighted degree for each node
Orig_deg = {}
Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
runGirvanNewman(G, Orig_deg, m_)
# Out:
# Number of communities in decomposed G: 2
# Modularity of decomposed G: 1.047205508074615
# Identified components: [{'Komei', 'Jiyuminsyu', 'Ishin'}, {'Kyosan', 'Kokuminminsyu', 'Syakaiminsyu', 'Rikkenminsyu', 'Reiwa'}]
# Number of communities in decomposed G: 4
# Modularity of decomposed G: 0.8559113264597673
# Number of communities in decomposed G: 6
# Modularity of decomposed G: 0.5047385708415549
# Number of communities in decomposed G: 8
# Modularity of decomposed G: -0.16718635695500147
# Max modularity found (Q): 1.047205508074615 and number of communities: 2
# Graph communities: [{'Komei', 'Jiyuminsyu', 'Ishin'}, {'Kyosan', 'Kokuminminsyu', 'Syakaiminsyu', 'Rikkenminsyu', 'Reiwa'}]
