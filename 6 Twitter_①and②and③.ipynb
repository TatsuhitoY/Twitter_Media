# %%
#セクション1 ①
import csv

filename = '1.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    現代ビジネス_lists=[]
    for row in csvreader:
      現代ビジネス_lists += row

    print('データ取得終了時刻：', 現代ビジネス_lists[-2])
    del 現代ビジネス_lists[-1]
    del 現代ビジネス_lists[-1]

    unique_set = set(現代ビジネス_lists)
    現代ビジネス_list = list(unique_set)
    現代ビジネス_list.append('現代ビジネス')

    print('現代ビジネスのフォロワー数：', len(現代ビジネス_list)-1)
    print('\n')

filename = '2.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    沖縄タイムス_lists=[]
    for row in csvreader:
      沖縄タイムス_lists += row

    print('データ取得終了時刻：', 沖縄タイムス_lists[-2])
    del 沖縄タイムス_lists[-1]
    del 沖縄タイムス_lists[-1]

    unique_set = set(沖縄タイムス_lists)
    沖縄タイムス_list = list(unique_set)
    沖縄タイムス_list.append('沖縄タイムス')
        
    print('沖縄タイムスのフォロワー数：', len(沖縄タイムス_list)-1)
    print('\n')
    
filename = '3.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    毎日新聞_lists=[]
    for row in csvreader:
      毎日新聞_lists += row

    print('データ取得終了時刻：', 毎日新聞_lists[-2])
    del 毎日新聞_lists[-1]
    del 毎日新聞_lists[-1]

    unique_set = set(毎日新聞_lists)
    毎日新聞_list = list(unique_set)
    毎日新聞_list.append('毎日新聞')
        
    print('毎日新聞のフォロワー数：', len(毎日新聞_list)-1)
    print('\n')
    
filename = '4.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    朝日新聞_lists=[]
    for row in csvreader:
      朝日新聞_lists += row

    print('データ取得終了時刻：', 朝日新聞_lists[-2])
    del 朝日新聞_lists[-1]
    del 朝日新聞_lists[-1]

    unique_set = set(朝日新聞_lists)
    朝日新聞_list = list(unique_set)
    朝日新聞_list.append('朝日新聞')
        
    print('朝日新聞のフォロワー数：', len(朝日新聞_list)-1)
    print('\n')
    
filename = '5.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    時事ドットコム_lists=[]
    for row in csvreader:
      時事ドットコム_lists += row

    print('データ取得終了時刻：', 時事ドットコム_lists[-2])
    del 時事ドットコム_lists[-1]
    del 時事ドットコム_lists[-1]

    unique_set = set(時事ドットコム_lists)
    時事ドットコム_list = list(unique_set)
    時事ドットコム_list.append('時事ドットコム')
        
    print('時事ドットコムのフォロワー数：', len(時事ドットコム_list)-1)
    print('\n')
    
filename = '6.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本経済新聞_lists=[]
    for row in csvreader:
      日本経済新聞_lists += row

    print('データ取得終了時刻：', 日本経済新聞_lists[-2])
    del 日本経済新聞_lists[-1]
    del 日本経済新聞_lists[-1]

    unique_set = set(日本経済新聞_lists)
    日本経済新聞_list = list(unique_set)
    日本経済新聞_list.append('日本経済新聞')
        
    print('日本経済新聞のフォロワー数：', len(日本経済新聞_list)-1)
    print('\n')
    
filename = '7.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    産経ニュース_lists=[]
    for row in csvreader:
      産経ニュース_lists += row

    print('データ取得終了時刻：', 産経ニュース_lists[-2])
    del 産経ニュース_lists[-1]
    del 産経ニュース_lists[-1]

    unique_set = set(産経ニュース_lists)
    産経ニュース_list = list(unique_set)
    産経ニュース_list.append('産経ニュース')
        
    print('産経ニュースのフォロワー数：', len(産経ニュース_list)-1)
    print('\n')
    
filename = '8.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    東京新聞_lists=[]
    for row in csvreader:
      東京新聞_lists += row

    print('データ取得終了時刻：', 東京新聞_lists[-2])
    del 東京新聞_lists[-1]
    del 東京新聞_lists[-1]

    unique_set = set(東京新聞_lists)
    東京新聞_list = list(unique_set)
    東京新聞_list.append('東京新聞')
        
    print('東京新聞のフォロワー数：', len(東京新聞_list)-1)
    print('\n')
    
filename = '9.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    読売新聞オンライン_lists=[]
    for row in csvreader:
      読売新聞オンライン_lists += row

    print('データ取得終了時刻：', 読売新聞オンライン_lists[-2])
    del 読売新聞オンライン_lists[-1]
    del 読売新聞オンライン_lists[-1]

    unique_set = set(読売新聞オンライン_lists)
    読売新聞オンライン_list = list(unique_set)
    読売新聞オンライン_list.append('読売新聞オンライン')
        
    print('読売新聞オンラインのフォロワー数：', len(読売新聞オンライン_list)-1)
    print('\n')
    
filename = '10.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    zakzak_lists=[]
    for row in csvreader:
      zakzak_lists += row

    print('データ取得終了時刻：', zakzak_lists[-2])
    del zakzak_lists[-1]
    del zakzak_lists[-1]

    unique_set = set(zakzak_lists)
    zakzak_list = list(unique_set)
    zakzak_list.append('zakzak')
        
    print('zakzakのフォロワー数：', len(zakzak_list)-1)
    print('\n')
    
filename = '11.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    NHKニュース_lists=[]
    for row in csvreader:
      NHKニュース_lists += row

    print('データ取得終了時刻：', NHKニュース_lists[-2])
    del NHKニュース_lists[-1]
    del NHKニュース_lists[-1]

    unique_set = set(NHKニュース_lists)
    NHKニュース_list = list(unique_set)
    NHKニュース_list.append('NHKニュース')
        
    print('NHKニュースのフォロワー数：', len(NHKニュース_list)-1)
    print('\n')
    
filename = '12.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    しんぶん赤旗_lists=[]
    for row in csvreader:
      しんぶん赤旗_lists += row

    print('データ取得終了時刻：', しんぶん赤旗_lists[-2])
    del しんぶん赤旗_lists[-1]
    del しんぶん赤旗_lists[-1]

    unique_set = set(しんぶん赤旗_lists)
    しんぶん赤旗_list = list(unique_set)
    しんぶん赤旗_list.append('しんぶん赤旗')
        
    print('しんぶん赤旗のフォロワー数：', len(しんぶん赤旗_list)-1)
    print('\n')
    
filename = '13.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日刊ゲンダイ_lists=[]
    for row in csvreader:
      日刊ゲンダイ_lists += row

    print('データ取得終了時刻：', 日刊ゲンダイ_lists[-2])
    del 日刊ゲンダイ_lists[-1]
    del 日刊ゲンダイ_lists[-1]

    unique_set = set(日刊ゲンダイ_lists)
    日刊ゲンダイ_list = list(unique_set)
    日刊ゲンダイ_list.append('日刊ゲンダイ')
        
    print('日刊ゲンダイのフォロワー数：', len(日刊ゲンダイ_list)-1)
    print('\n')
    
filename = '14.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    アゴラ_lists=[]
    for row in csvreader:
      アゴラ_lists += row

    print('データ取得終了時刻：', アゴラ_lists[-2])
    del アゴラ_lists[-1]
    del アゴラ_lists[-1]

    unique_set = set(アゴラ_lists)
    アゴラ_list = list(unique_set)
    アゴラ_list.append('アゴラ')
        
    print('アゴラのフォロワー数：', len(アゴラ_list)-1)
    print('\n')
    
filename = '15.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    アノニマス_ポスト_lists=[]
    for row in csvreader:
      アノニマス_ポスト_lists += row

    print('データ取得終了時刻：', アノニマス_ポスト_lists[-2])
    del アノニマス_ポスト_lists[-1]
    del アノニマス_ポスト_lists[-1]

    unique_set = set(アノニマス_ポスト_lists)
    アノニマス_ポスト_list = list(unique_set)
    アノニマス_ポスト_list.append('アノニマス_ポスト')
        
    print('アノニマス_ポストのフォロワー数：', len(アノニマス_ポスト_list)-1)
    print('\n')
    
filename = '16.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    ハム速_lists=[]
    for row in csvreader:
      ハム速_lists += row

    print('データ取得終了時刻：', ハム速_lists[-2])
    del ハム速_lists[-1]
    del ハム速_lists[-1]

    unique_set = set(ハム速_lists)
    ハム速_list = list(unique_set)
    ハム速_list.append('ハム速')
        
    print('ハム速のフォロワー数：', len(ハム速_list)-1)
    print('\n')
    
filename = '17.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    政治知新_lists=[]
    for row in csvreader:
      政治知新_lists += row

    print('データ取得終了時刻：', 政治知新_lists[-2])
    del 政治知新_lists[-1]
    del 政治知新_lists[-1]

    unique_set = set(政治知新_lists)
    政治知新_list = list(unique_set)
    政治知新_list.append('政治知新')
        
    print('政治知新のフォロワー数：', len(政治知新_list)-1)
    print('\n')
    
filename = '18.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    litera_lists=[]
    for row in csvreader:
      litera_lists += row

    print('データ取得終了時刻：', litera_lists[-2])
    del litera_lists[-1]
    del litera_lists[-1]

    unique_set = set(litera_lists)
    litera_list = list(unique_set)
    litera_list.append('litera')
        
    print('literaのフォロワー数：', len(litera_list)-1)
    print('\n')
    
filename = '19.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    Share_News_Japan_lists=[]
    for row in csvreader:
      Share_News_Japan_lists += row

    print('データ取得終了時刻：', Share_News_Japan_lists[-2])
    del Share_News_Japan_lists[-1]
    del Share_News_Japan_lists[-1]

    unique_set = set(Share_News_Japan_lists)
    Share_News_Japan_list = list(unique_set)
    Share_News_Japan_list.append('Share_News_Japan')
        
    print('Share_News_Japanのフォロワー数：', len(Share_News_Japan_list)-1)
    print('\n')
    
filename = '20.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    もえるあじあ_lists=[]
    for row in csvreader:
      もえるあじあ_lists += row

    print('データ取得終了時刻：', もえるあじあ_lists[-2])
    del もえるあじあ_lists[-1]
    del もえるあじあ_lists[-1]

    unique_set = set(もえるあじあ_lists)
    もえるあじあ_list = list(unique_set)
    もえるあじあ_list.append('もえるあじあ')
        
    print('もえるあじあのフォロワー数：', len(もえるあじあ_list)-1)
    print('\n')
    
filename = '21.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    BuzzFeed_Japan_lists=[]
    for row in csvreader:
      BuzzFeed_Japan_lists += row

    print('データ取得終了時刻：', BuzzFeed_Japan_lists[-2])
    del BuzzFeed_Japan_lists[-1]
    del BuzzFeed_Japan_lists[-1]

    unique_set = set(BuzzFeed_Japan_lists)
    BuzzFeed_Japan_list = list(unique_set)
    BuzzFeed_Japan_list.append('BuzzFeed_Japan')
        
    print('BuzzFeed_Japanのフォロワー数：', len(BuzzFeed_Japan_list)-1)
    print('\n')
    
filename = '22.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    Yahoo_ニュース_lists=[]
    for row in csvreader:
      Yahoo_ニュース_lists += row

    print('データ取得終了時刻：', Yahoo_ニュース_lists[-2])
    del Yahoo_ニュース_lists[-1]
    del Yahoo_ニュース_lists[-1]

    unique_set = set(Yahoo_ニュース_lists)
    Yahoo_ニュース_list = list(unique_set)
    Yahoo_ニュース_list.append('Yahoo_ニュース')
        
    print('Yahoo_ニュースのフォロワー数：', len(Yahoo_ニュース_list)-1)
    print('\n')

filename = '23.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_lists=[]
    for row in csvreader:
      自由民主党_lists += row

    print('データ取得終了時刻：', 自由民主党_lists[-2])
    del 自由民主党_lists[-1]
    del 自由民主党_lists[-1]

    unique_set = set(自由民主党_lists)
    自由民主党_list = list(unique_set)
    自由民主党_list.append('自由民主党')

    print('自由民主党のフォロワー数：', len(自由民主党_list)-1)
    print('\n')

filename = '24.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_lists=[]
    for row in csvreader:
      立憲民主党_lists += row

    print('データ取得終了時刻：', 立憲民主党_lists[-2])
    del 立憲民主党_lists[-1]
    del 立憲民主党_lists[-1]

    unique_set = set(立憲民主党_lists)
    立憲民主党_list = list(unique_set)
    立憲民主党_list.append('立憲民主党')

    print('立憲民主党のフォロワー数：', len(立憲民主党_list)-1)
    print('\n')

filename = '25.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    公明党_lists=[]
    for row in csvreader:
      公明党_lists += row

    print('データ取得終了時刻：', 公明党_lists[-2])
    del 公明党_lists[-1]
    del 公明党_lists[-1]

    unique_set = set(公明党_lists)
    公明党_list = list(unique_set)
    公明党_list.append('公明党')

    print('公明党のフォロワー数：', len(公明党_list)-1)
    print('\n')

filename = '26.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本共産党_lists=[]
    for row in csvreader:
      日本共産党_lists += row

    print('データ取得終了時刻：', 日本共産党_lists[-2])
    del 日本共産党_lists[-1]
    del 日本共産党_lists[-1]

    unique_set = set(日本共産党_lists)
    日本共産党_list = list(unique_set)
    日本共産党_list.append('日本共産党')

    print('日本共産党のフォロワー数：', len(日本共産党_list)-1)
    print('\n')

filename = '27.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_lists=[]
    for row in csvreader:
      日本維新の会_lists += row

    print('データ取得終了時刻：', 日本維新の会_lists[-2])
    del 日本維新の会_lists[-1]
    del 日本維新の会_lists[-1]

    unique_set = set(日本維新の会_lists)
    日本維新の会_list = list(unique_set)
    日本維新の会_list.append('日本維新の会')

    print('日本維新の会のフォロワー数：', len(日本維新の会_list)-1)
    print('\n')

filename = '28.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    国民民主党_lists=[]
    for row in csvreader:
      国民民主党_lists += row

    print('データ取得終了時刻：', 国民民主党_lists[-2])
    del 国民民主党_lists[-1]
    del 国民民主党_lists[-1]

    unique_set = set(国民民主党_lists)
    国民民主党_list = list(unique_set)
    国民民主党_list.append('国民民主党')

    print('国民民主党のフォロワー数：', len(国民民主党_list)-1)
    print('\n')

filename = '29.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    社会民主党_lists=[]
    for row in csvreader:
      社会民主党_lists += row

    print('データ取得終了時刻：', 社会民主党_lists[-2])
    del 社会民主党_lists[-1]
    del 社会民主党_lists[-1]

    unique_set = set(社会民主党_lists)
    社会民主党_list = list(unique_set)
    社会民主党_list.append('社会民主党')

    print('社会民主党のフォロワー数：', len(社会民主党_list)-1)
    print('\n')

filename = '30.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    れいわ新選組_lists=[]
    for row in csvreader:
      れいわ新選組_lists += row

    print('データ取得終了時刻：', れいわ新選組_lists[-2])
    del れいわ新選組_lists[-1]
    del れいわ新選組_lists[-1]

    unique_set = set(れいわ新選組_lists)
    れいわ新選組_list = list(unique_set)
    れいわ新選組_list.append('れいわ新選組')

    print('れいわ新選組のフォロワー数：', len(れいわ新選組_list)-1)
    print('\n')

filename = '31.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_党首_lists=[]
    for row in csvreader:
      自由民主党_党首_lists += row

    print('データ取得終了時刻：', 自由民主党_党首_lists[-2])
    del 自由民主党_党首_lists[-1]
    del 自由民主党_党首_lists[-1]

    unique_set = set(自由民主党_党首_lists)
    自由民主党_党首_list = list(unique_set)
    自由民主党_党首_list.append('自由民主党_党首')

    print('自由民主党_党首のフォロワー数：', len(自由民主党_党首_list)-1)
    print('\n')

filename = '32.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_党首_lists=[]
    for row in csvreader:
      立憲民主党_党首_lists += row

    print('データ取得終了時刻：', 立憲民主党_党首_lists[-2])
    del 立憲民主党_党首_lists[-1]
    del 立憲民主党_党首_lists[-1]

    unique_set = set(立憲民主党_党首_lists)
    立憲民主党_党首_list = list(unique_set)
    立憲民主党_党首_list.append('立憲民主党_党首')

    print('立憲民主党_党首のフォロワー数：', len(立憲民主党_党首_list)-1)
    print('\n')

filename = '33.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    公明党_党首_lists=[]
    for row in csvreader:
      公明党_党首_lists += row

    print('データ取得終了時刻：', 公明党_党首_lists[-2])
    del 公明党_党首_lists[-1]
    del 公明党_党首_lists[-1]

    unique_set = set(公明党_党首_lists)
    公明党_党首_list = list(unique_set)
    公明党_党首_list.append('公明党_党首')

    print('公明党_党首のフォロワー数：', len(公明党_党首_list)-1)
    print('\n')

filename = '34.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本共産党_党首_lists=[]
    for row in csvreader:
      日本共産党_党首_lists += row

    print('データ取得終了時刻：', 日本共産党_党首_lists[-2])
    del 日本共産党_党首_lists[-1]
    del 日本共産党_党首_lists[-1]

    unique_set = set(日本共産党_党首_lists)
    日本共産党_党首_list = list(unique_set)
    日本共産党_党首_list.append('日本共産党_党首')

    print('日本共産党_党首のフォロワー数：', len(日本共産党_党首_list)-1)
    print('\n')

filename = '35.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_党首_lists=[]
    for row in csvreader:
      日本維新の会_党首_lists += row

    print('データ取得終了時刻：', 日本維新の会_党首_lists[-2])
    del 日本維新の会_党首_lists[-1]
    del 日本維新の会_党首_lists[-1]

    unique_set = set(日本維新の会_党首_lists)
    日本維新の会_党首_list = list(unique_set)
    日本維新の会_党首_list.append('日本維新の会_党首')

    print('日本維新の会_党首のフォロワー数：', len(日本維新の会_党首_list)-1)
    print('\n')

filename = '36.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    国民民主党_党首_lists=[]
    for row in csvreader:
      国民民主党_党首_lists += row

    print('データ取得終了時刻：', 国民民主党_党首_lists[-2])
    del 国民民主党_党首_lists[-1]
    del 国民民主党_党首_lists[-1]

    unique_set = set(国民民主党_党首_lists)
    国民民主党_党首_list = list(unique_set)
    国民民主党_党首_list.append('国民民主党_党首')

    print('国民民主党_党首のフォロワー数：', len(国民民主党_党首_list)-1)
    print('\n')

filename = '37.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    社会民主党_党首_lists=[]
    for row in csvreader:
      社会民主党_党首_lists += row

    print('データ取得終了時刻：', 社会民主党_党首_lists[-2])
    del 社会民主党_党首_lists[-1]
    del 社会民主党_党首_lists[-1]

    unique_set = set(社会民主党_党首_lists)
    社会民主党_党首_list = list(unique_set)
    社会民主党_党首_list.append('社会民主党_党首')

    print('社会民主党_党首のフォロワー数：', len(社会民主党_党首_list)-1)
    print('\n')

filename = '38.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    れいわ新選組_党首_lists=[]
    for row in csvreader:
      れいわ新選組_党首_lists += row

    print('データ取得終了時刻：', れいわ新選組_党首_lists[-2])
    del れいわ新選組_党首_lists[-1]
    del れいわ新選組_党首_lists[-1]

    unique_set = set(れいわ新選組_党首_lists)
    れいわ新選組_党首_list = list(unique_set)
    れいわ新選組_党首_list.append('れいわ新選組_党首')

    print('れいわ新選組_党首のフォロワー数：', len(れいわ新選組_党首_list)-1)
    print('\n')

filename = '39.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_菅_lists=[]
    for row in csvreader:
      自由民主党_菅_lists += row

    print('データ取得終了時刻：', 自由民主党_菅_lists[-2])
    del 自由民主党_菅_lists[-1]
    del 自由民主党_菅_lists[-1]

    unique_set = set(自由民主党_菅_lists)
    自由民主党_菅_list = list(unique_set)
    自由民主党_菅_list.append('自由民主党_菅')

    print('自由民主党_菅のフォロワー数：', len(自由民主党_菅_list)-1)
    print('\n')

filename = '40.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    自由民主党_河野_lists=[]
    for row in csvreader:
      自由民主党_河野_lists += row

    print('データ取得終了時刻：', 自由民主党_河野_lists[-2])
    del 自由民主党_河野_lists[-1]
    del 自由民主党_河野_lists[-1]

    unique_set = set(自由民主党_河野_lists)
    自由民主党_河野_list = list(unique_set)
    自由民主党_河野_list.append('自由民主党_河野')

    print('自由民主党_河野のフォロワー数：', len(自由民主党_河野_list)-1)
    print('\n')

filename = '41.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_枝野_lists=[]
    for row in csvreader:
      立憲民主党_枝野_lists += row

    print('データ取得終了時刻：', 立憲民主党_枝野_lists[-2])
    del 立憲民主党_枝野_lists[-1]
    del 立憲民主党_枝野_lists[-1]

    unique_set = set(立憲民主党_枝野_lists)
    立憲民主党_枝野_list = list(unique_set)
    立憲民主党_枝野_list.append('立憲民主党_枝野')

    print('立憲民主党_枝野のフォロワー数：', len(立憲民主党_枝野_list)-1)
    print('\n')

filename = '42.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    立憲民主党_蓮舫_lists=[]
    for row in csvreader:
      立憲民主党_蓮舫_lists += row

    print('データ取得終了時刻：', 立憲民主党_蓮舫_lists[-2])
    del 立憲民主党_蓮舫_lists[-1]
    del 立憲民主党_蓮舫_lists[-1]

    unique_set = set(立憲民主党_蓮舫_lists)
    立憲民主党_蓮舫_list = list(unique_set)
    立憲民主党_蓮舫_list.append('立憲民主党_蓮舫')

    print('立憲民主党_蓮舫のフォロワー数：', len(立憲民主党_蓮舫_list)-1)
    print('\n')

filename = '43.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_吉村_lists=[]
    for row in csvreader:
      日本維新の会_吉村_lists += row

    print('データ取得終了時刻：', 日本維新の会_吉村_lists[-2])
    del 日本維新の会_吉村_lists[-1]
    del 日本維新の会_吉村_lists[-1]

    unique_set = set(日本維新の会_吉村_lists)
    日本維新の会_吉村_list = list(unique_set)
    日本維新の会_吉村_list.append('日本維新の会_吉村')

    print('日本維新の会_吉村のフォロワー数：', len(日本維新の会_吉村_list)-1)
    print('\n')

filename = '44.csv'
with open(filename, encoding='utf8', newline='') as f:
    csvreader = csv.reader(f)

    日本維新の会_橋下_lists=[]
    for row in csvreader:
      日本維新の会_橋下_lists += row

    print('データ取得終了時刻：', 日本維新の会_橋下_lists[-2])
    del 日本維新の会_橋下_lists[-1]
    del 日本維新の会_橋下_lists[-1]

    unique_set = set(日本維新の会_橋下_lists)
    日本維新の会_橋下_list = list(unique_set)
    日本維新の会_橋下_list.append('日本維新の会_橋下')

    print('日本維新の会_橋下のフォロワー数：', len(日本維新の会_橋下_list)-1)
    print('\n')

sum_list = [現代ビジネス_list, 沖縄タイムス_list, 毎日新聞_list, 朝日新聞_list, 時事ドットコム_list, 日本経済新聞_list, 産経ニュース_list, 東京新聞_list, 読売新聞オンライン_list, zakzak_list, NHKニュース_list, しんぶん赤旗_list, 日刊ゲンダイ_list, アゴラ_list, アノニマス_ポスト_list, ハム速_list, 政治知新_list, litera_list, Share_News_Japan_list, もえるあじあ_list, BuzzFeed_Japan_list, Yahoo_ニュース_list, 自由民主党_list, 立憲民主党_list, 公明党_list, 日本共産党_list, 日本維新の会_list, 国民民主党_list, 社会民主党_list, れいわ新選組_list, 自由民主党_党首_list, 立憲民主党_党首_list, 公明党_党首_list, 日本共産党_党首_list, 日本維新の会_党首_list, 国民民主党_党首_list, 社会民主党_党首_list, れいわ新選組_党首_list, 自由民主党_菅_list, 自由民主党_河野_list, 立憲民主党_枝野_list, 立憲民主党_蓮舫_list, 日本維新の会_吉村_list, 日本維新の会_橋下_list]
# Out:
# データ取得終了時刻： 2022-04-21T18:41:46
# 現代ビジネスのフォロワー数： 159783
#
#
# データ取得終了時刻： 2022-04-21T18:56:54
# 沖縄タイムスのフォロワー数： 123898
#
#
# データ取得終了時刻： 2022-04-22T23:10:38
# 毎日新聞のフォロワー数： 961908
#
#
# データ取得終了時刻： 2022-04-24T15:42:25
# 朝日新聞のフォロワー数： 1319121
#
#
# データ取得終了時刻： 2022-04-22T08:29:02
# 時事ドットコムのフォロワー数： 333171
#
#
# データ取得終了時刻： 2022-04-26T04:51:54
# 日本経済新聞のフォロワー数： 3502954
#
#
# データ取得終了時刻： 2022-04-24T01:32:45
# 産経ニュースのフォロワー数： 657252
#
#
# データ取得終了時刻： 2022-04-22T16:12:21
# 東京新聞のフォロワー数： 95458
#
#
# データ取得終了時刻： 2022-04-23T21:16:17
# 読売新聞オンラインのフォロワー数： 817603
#
#
# データ取得終了時刻： 2022-04-21T23:06:11
# zakzakのフォロワー数： 72106
#
#
# データ取得終了時刻： 2022-04-27T10:29:08
# NHKニュースのフォロワー数： 3392866
#
#
# データ取得終了時刻： 2022-04-21T23:21:15
# しんぶん赤旗のフォロワー数： 52107
#
#
# データ取得終了時刻： 2022-04-21T23:51:22
# 日刊ゲンダイのフォロワー数： 126359
#
#
# データ取得終了時刻： 2022-04-22T00:06:26
# アゴラのフォロワー数： 43559
#
#
# データ取得終了時刻： 2022-04-22T00:21:32
# アノニマス_ポストのフォロワー数： 119150
#
#
# データ取得終了時刻： 2022-04-22T18:17:41
# ハム速のフォロワー数： 385114
#
#
# ...

# %%
G = nx.path_graph(4)
h, a = nx.hits(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3959956d9bae> in <module>
#       1 G = nx.path_graph(4)
# ----> 2 h, a = nx.hits(G)
#
# /usr/local/lib/python3.8/dist-packages/networkx/classes/backends.py in wrapper(*args, **kwds)
#     143                         f"'{name}' not implemented by {plugin_name}"
#     144                     )
# --> 145         return func(*args, **kwds)
#     146
#     147     _register_algo(name, wrapper)
#
# /usr/local/lib/python3.8/dist-packages/networkx/algorithms/link_analysis/hits_alg.py in hits(G, max_iter, tol, nstart, normalized)
#      77     if len(G) == 0:
#      78         return {}, {}
# ---> 79     A = nx.adjacency_matrix(G, nodelist=list(G), dtype=float)
#      80
#      81     if nstart is None:
#
# ...

# %%
import networkx as nx
import math
import csv
import random as rand
import sys

_DEBUG_ = False

                                                                                                               
def buildG(G, list):                                                                                            
    for line in list:
       G.add_edge(line[0], line[1],weight=float(line[2]))                                                       #これでファイルから重み付き無向グラフの情報を打ち込む 元々int関数がついてたが削除
                                                                                                                #もしファイルの情報に重みが付与されていなかったら重みを自動で1とする。
                                                                                                                #この作業はGの中にある塊の数が一つ増えるまでエッジを減らし続ける。得られる成果はエッジが減ったG
                                                                                                                # This method keeps removing edges from Graph until one of the connected components of Graph splits into two
                                                                                                                # compute the edge betweenness
def CmtyGirvanNewmanStep(G): #③
    if _DEBUG_:
        print("Running CmtyGirvanNewmanStep method ...")
    init_ncomp = nx.number_connected_components(G)                                                              #number of components　連結グループの数を取得
    ncomp = init_ncomp                                                                                          #ncompを更新し続けてある塊を分割できるまで繰り返す。
    while ncomp <= init_ncomp:
        bw = nx.edge_betweenness_centrality(G, weight='weight')                                                 #edge betweenness for G
                                                                                                                #find the edge with max centrality その段階のグラフで最大の中心性を持つエッジを取得。
                                                                                                                #bwの形式は形式は{('エッジ', 'エッジ'): edge_betweenness_centralityの値の値, ...}
        max_ = max(bw.values())
                                                                                                                #find the edge with the highest centrality and remove all of them if there is more than one!
        for k, v in bw.items():                                                                                 #この場合kはインデックスでvが中身
            if float(v) == max_:
                G.remove_edge(k[0],k[1])                                                                        #remove the central edge
        ncomp = nx.number_connected_components(G)                                                               #recalculate the no of components

                                                                                                                #渡されたグラフGのモジュラリティーを計算して引数Modとして渡す
                                                                                                                # This method compute the modularity of current split
def _GirvanNewmanGetModularity(G, deg_, m_): #②
    New_A = nx.adjacency_matrix(G)                                                                              #データは['エッジ', 'エッジ', 重み]というリストが並んでいる。
    New_deg = {}
    New_deg = UpdateDeg(New_A, G.nodes())                                                                       #（重複）UpdateDegでは辞書型で{'ノード名': 重みの総和, ...}が取得できる。
                                                                                                                #Let's compute the Q
    comps = nx.connected_components(G)                                                                                                             #list of components データの形式の確認は困難 
    print('Number of communities in decomposed G: {}'.format(nx.number_connected_components(G)))                #元々Noと記載されてたが、Numberに修正
    Mod = 0                                                                                                     #Modularity of a given partitionning
    for c in comps:
        EWC = 0                                                                                                 #number of edges within a community
        RE = 0                                                                                                  #number of random edges
        for u in c:
            EWC += New_deg[u]     #EWCはその連結部のノードの最新の重みの総和
            RE += deg_[u]         #REはその連結部のノードの初期の重みの総和                                           #count the probability of a random edge
        Mod += ( float(EWC) - float(RE*RE)/float(2*m_) )                                                        #モジュラリティーの計算
    Mod = Mod/float(2*m_) 
    if _DEBUG_:
        print("Modularity: {}".format(Mod))
    return Mod

                                                                                                                #（重複）UpdateDegでは辞書型で{'ノード名': 重みの総和, ...}がdeg_dictに格納されている。
def UpdateDeg(A, nodes): #                                                                                      #nodes = G.nodes()でノードが並ぶリストが格納される。
    deg_dict = {}
    n = len(nodes)                                                                                              #len(A) ---> some ppl get issues when trying len() on sparse matrixes!
    B = A.sum(axis = 1)                                                                                         #グラフのノードが持つそれぞれのエッジの重みを足し合わせたものが格納され、それはノードごとにあり、ノードの番号順に並べられる。
    i = 0
    for node_id in list(nodes): 
        deg_dict[node_id] = B[i]                                                                             #Bは縦に一列なのでB[i, 0]はi番目の要素のこと。つまりdeg_dictは
        i += 1
    return deg_dict

# %%
#セクション3.1 
#フォロワー総数（重複ありあり/なし）

sum_totalcount_list = 現代ビジネス_list + 沖縄タイムス_list + 毎日新聞_list + 朝日新聞_list + 時事ドットコム_list + 日本経済新聞_list + 産経ニュース_list + 東京新聞_list + 読売新聞オンライン_list + zakzak_list + NHKニュース_list + しんぶん赤旗_list + 日刊ゲンダイ_list + アゴラ_list + アノニマス_ポスト_list + ハム速_list + 政治知新_list + litera_list + Share_News_Japan_list + もえるあじあ_list + BuzzFeed_Japan_list + Yahoo_ニュース_list + 自由民主党_list + 立憲民主党_list + 公明党_list + 日本共産党_list + 日本維新の会_list + 国民民主党_list + 社会民主党_list + れいわ新選組_list + 自由民主党_党首_list + 立憲民主党_党首_list + 公明党_党首_list + 日本共産党_党首_list + 日本維新の会_党首_list + 国民民主党_党首_list + 社会民主党_党首_list + れいわ新選組_党首_list + 自由民主党_菅_list + 自由民主党_河野_list + 立憲民主党_枝野_list + 立憲民主党_蓮舫_list + 日本維新の会_吉村_list + 日本維新の会_橋下_list

print('収集したフォロワーIDの総数：', len(sum_totalcount_list)-44)
print('フォロワーの総数', len(set(sum_totalcount_list))-44)
# Out:
# 収集したフォロワーIDの総数： 24602850
# フォロワーの総数 12272624

# %% [markdown]
# 収集したフォロワーIDの総数： 24602850
# フォロワーの総数 12272624

# %%
#セクション4.1 ②
#グラフリスト Jaccard係数

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News', 'Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa', 'Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_j = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Jaccard_Total.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_jt=[]
      for row in csvreader:
        a_b_jt += row
  a_b_j = []
  for i in a_b_jt:
    a_b_j.append(float(i))

if data_import == 0:

  a_b_j = []
  c = 0
  #sum_listはリストインリストで全てのフォロワーが格納されている
  for a in sum_list:
    #行列を作成
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_list = set(a) & set(b)
        a_b_j.append((len(a_b_list))/((len(a)-1)+(len(b)-1)-(len(a_b_list))))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_j[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_j[e][1] = sum_engname_list[d-1]

  else:
    for k in range(total):
      e += 1
      matrix_j[e][2] = a_b_j[e]
      
print(matrix_j)
# Out:
# [['Gendai_biz', 'Okinawa', 0.024803569170745804], ['Gendai_biz', 'Mainichi', 0.039088647932598114], ['Gendai_biz', 'Asahi', 0.03558759230912511], ['Gendai_biz', 'Jiji', 0.04137364297197324], ['Gendai_biz', 'Nikkei', 0.023208070040171412], ['Gendai_biz', 'Sankei', 0.03179093300465612], ['Gendai_biz', 'Tokyo', 0.03406770597005251], ['Gendai_biz', 'Yomiuri', 0.046686035740331616], ['Gendai_biz', 'Zakzak', 0.04669973774842807], ['Gendai_biz', 'Nhk', 0.020868228895925232], ['Gendai_biz', 'Akahata', 0.02355890692855038], ['Gendai_biz', 'Nikkan', 0.06613063679008022], ['Gendai_biz', 'Agora', 0.04108172313867642], ['Gendai_biz', 'Anonymous', 0.016427074792748474], ['Gendai_biz', 'Hamusoku', 0.01082998335989196], ['Gendai_biz', 'Seijichishin', 0.01390408725674547], ['Gendai_biz', 'Litera', 0.04112930379697276], ['Gendai_biz', 'Share_News_Japan', 0.020572197680839316], ['Gendai_biz', 'Moeruasia', 0.005556739390561739], ['Gendai_biz', 'BuzzFeed_Japan', 0.023148093582414993], ['Gendai_biz', 'Yah
# ...

# %%
sum_engname_list1 = [['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News'],['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa'],['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']]
color_list10 = ['burlywood', 'turquoise', 'lime', 'yellow', 'lavender', 'coral', 'red', 'fuchsia', 'blue', 'lightcoral', 'lightyellow', 'bisque', 'aqua', 'olive', 'salmon', 'lightskyblue', 'chocolate', 'sateblue', 'palegreen', 'grey']
#セクション4.2.1 
#グラフリスト 
#Jaccard係数

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 1

Jaccard係数 = 0.1

matrix_condj = []
for i in range(len(matrix_j)):
  if matrix_j[i][2] >= Jaccard係数 and matrix_j[i][2] != 1:
    matrix_condj.append(matrix_j[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_condj) #ここに三次元リストを入れて実行！
    
  if _DEBUG_:
    print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)                                                                         #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_condj)):
    node_list_del.append(matrix_condj[i][0])
    node_list_del.append(matrix_condj[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/800)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/800) for i in sum_list]

H.add_weighted_edges_from(matrix_condj)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = media, BLUE = political party, LIME = politician')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(21,14))
plt.title('Jaccard index Threshold:{}'.format(Jaccard係数))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-e08a99400d5e> in <module>
#      26
#      27   n = G.number_of_nodes()    #|V|
# ---> 28   A = nx.adjacency_matrix(G)    #adjacenct matrix
#      29
#      30   m_ = 0.0    #the weighted version for number of edges
#
# /usr/local/lib/python3.8/dist-packages/networkx/linalg/graphmatrix.py in adjacency_matrix(G, nodelist, dtype, weight)
#     155     adjacency_spectrum
#     156     """
# --> 157     return nx.to_scipy_sparse_array(G, nodelist=nodelist, dtype=dtype, weight=weight)
#
# /usr/local/lib/python3.8/dist-packages/networkx/convert_matrix.py in to_scipy_sparse_array(G, nodelist, dtype, weight, format)
#     591             r += diag_index
#     592             c += diag_index
# --> 593         A = sp.sparse.coo_array((d, (r, c)), shape=(nlen, nlen), dtype=dtype)
#     594     try:
# ...

# %%
Jaccard係数 = 0.05, Modularity = 0.35
Jaccard係数 = 0.075, Modularity = 0.48
Jaccard係数 = 0.1, Modularity = 0.59
Jaccard係数 = 0.2, Modularity = 0.79
Jaccard係数 = 0.3, Modularity = 0.08

# %%
#セクション4.2 ②
#グラフリスト Dice係数

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News', 'Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa', 'Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_d = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Dice_Total.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_dt=[]
      for row in csvreader:
        a_b_dt += row
  a_b_d = []
  for i in a_b_dt:
    a_b_d.append(float(i))

if data_import == 0:
  a_b_d = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_list = set(a) & set(b)
        a_b_d.append((len(a_b_list)*2)/((len(a)-1)+(len(b)-1)))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_d[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_d[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_d[e][2] = a_b_d[e]
      
print(matrix_d)
# Out:
# [['Gendai_biz', 'Okinawa', 0.04840648474871422], ['Gendai_biz', 'Mainichi', 0.07523640646131599], ['Gendai_biz', 'Asahi', 0.06872927519298075], ['Gendai_biz', 'Jiji', 0.07945974675121817], ['Gendai_biz', 'Nikkei', 0.045363344406109424], ['Gendai_biz', 'Sankei', 0.06162281909587716], ['Gendai_biz', 'Tokyo', 0.06589066803530781], ['Gendai_biz', 'Yomiuri', 0.08920733466614009], ['Gendai_biz', 'Zakzak', 0.08923234823557823], ['Gendai_biz', 'Nhk', 0.04088329581672718], ['Gendai_biz', 'Akahata', 0.046033319175043656], ['Gendai_biz', 'Nikkan', 0.12405728624249499], ['Gendai_biz', 'Agora', 0.07892122630838685], ['Gendai_biz', 'Anonymous', 0.03232317438237856], ['Gendai_biz', 'Hamusoku', 0.021427902888068753], ['Gendai_biz', 'Seijichishin', 0.027426829483180912], ['Gendai_biz', 'Litera', 0.07900902154415443], ['Gendai_biz', 'Share_News_Japan', 0.0403150266636458], ['Gendai_biz', 'Moeruasia', 0.011052065334333127], ['Gendai_biz', 'BuzzFeed_Japan', 0.04524876452902349], ['Gendai_biz', 'Yahoo_Ne
# ...

# %%
sum_engname_list1 = [['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News'],['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa'],['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']]
color_list10 = ['red', 'blue', 'lime', 'yellow', 'aqua', 'coral', 'burlywood', 'fuchsia', 'bisque', 'lightcoral', 'lightyellow', 'turquoise', 'lavender', 'olive', 'salmon', 'lightskyblue', 'chocolate', 'sateblue', 'palegreen', 'grey']
#セクション4.2.1 
#グラフリスト 
#Dice係数

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 0

Dice係数 = 0.2

matrix_condt = []
for i in range(len(matrix_d)):
  if matrix_d[i][2] >= Dice係数 and matrix_d[i][2] != 1:
    matrix_condt.append(matrix_d[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_condt) #ここに三次元リストを入れて実行！

  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))    #
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))  #
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)                                                                         #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_condt)):
    node_list_del.append(matrix_condt[i][0])
    node_list_del.append(matrix_condt[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/800)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/800) for i in sum_list]

H.add_weighted_edges_from(matrix_condt)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = media, BLUE = political party, LIME = politician')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(21,14))
plt.title('Dice index Threshold:{}'.format(Dice係数))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# Number of communities in decomposed G: 6
# Modularity of decomposed G: 0.5890537664891305
# Identified components: [{'Yahoo_News', 'Yomiuri', 'Jiji', 'Mainichi', 'Nikkei', 'Asahi', 'Nhk', 'Sankei'}, {'Litera', 'Kyosan', 'Tokyo', 'Reiwa_Leader', 'Rikkenminsyu_Renho', 'Rikkenminsyu', 'Akahata', 'Rikkenminsyu_Edano', 'Kyosan_Leader', 'Syakaiminsyu_Leader', 'Nikkan', 'Reiwa', 'Syakaiminsyu'}, {'Moeruasia', 'Seijichishin', 'Share_News_Japan', 'Anonymous'}, {'Jiyuminsyu_Leader', 'Komei_Leader', 'Komei', 'Jiyuminsyu', 'Jiyuminsyu_Suga'}, {'Kokuminminsyu', 'Kokuminminsyu_Leader'}, {'Ishin_Hashimoto', 'Ishin_Leader', 'Ishin_Yoshimura', 'Jiyuminsyu_Kono'}]
# Number of communities in decomposed G: 7
# Modularity of decomposed G: 0.577872043923903
# Number of communities in decomposed G: 8
# Modularity of decomposed G: 0.5600931266155428
# Number of communities in decomposed G: 9
# Modularity of decomposed G: 0.560153390167663
# Number of communities in decomposed G: 11
# ...

# %%
Dice係数 = 0.05, Modularity = 0.019
Dice係数 = 0.1, Modularity = 0.36
Dice係数 = 0.2, Modularity = 0.58
Dice係数 = 0.3, Modularity = 0.68
Dice係数 = 0.1, Modularity = 0

# %%
#セクション4.3 ② 重複なし
#グラフリスト Simpson係数

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News', 'Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa', 'Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_s = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Simpson_Total.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_st=[]
      for row in csvreader:
        a_b_st += row
  a_b_s = []
  for i in a_b_st:
    a_b_s.append(float(i))

if data_import == 0:
  a_b_s = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_s.append(len(set(a) & set(b))/min((len(a)-1), (len(b)-1)))


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_s[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_s[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_s[e][2] = a_b_s[e]
      
print(matrix_s)
# Out:
# [['Gendai_biz', 'Okinawa', 0.055416552325299843], ['Gendai_biz', 'Mainichi', 0.2640831627895333], ['Gendai_biz', 'Asahi', 0.3180688809197474], ['Gendai_biz', 'Jiji', 0.12257248893812232], ['Gendai_biz', 'Nikkei', 0.5199364137611636], ['Gendai_biz', 'Sankei', 0.15755117878622882], ['Gendai_biz', 'Tokyo', 0.08809109765551341], ['Gendai_biz', 'Yomiuri', 0.2728387876056902], ['Gendai_biz', 'Zakzak', 0.1434832052811139], ['Gendai_biz', 'Nhk', 0.45450392094277864], ['Gendai_biz', 'Akahata', 0.09359587003665534], ['Gendai_biz', 'Nikkan', 0.140464865977097], ['Gendai_biz', 'Agora', 0.18420992217452192], ['Gendai_biz', 'Anonymous', 0.037834662190516156], ['Gendai_biz', 'Hamusoku', 0.03653705337864479], ['Gendai_biz', 'Seijichishin', 0.046309932907871054], ['Gendai_biz', 'Litera', 0.09897678450290194], ['Gendai_biz', 'Share_News_Japan', 0.04385087319219056], ['Gendai_biz', 'Moeruasia', 0.04192949907235621], ['Gendai_biz', 'BuzzFeed_Japan', 0.04916668231288685], ['Gendai_biz', 'Yahoo_News', 0.2
# ...

# %%
sum_engname_list1 = [['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News'],['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa'],['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']]
color_list10 = ['turquoise', 'lavender', 'lime', 'yellow', 'aqua', 'coral', 'burlywood', 'fuchsia', 'bisque', 'lightcoral', 'lightyellow', 'red', 'blue', 'olive', 'salmon', 'lightskyblue', 'chocolate', 'sateblue', 'palegreen', 'grey']
#セクション4.2.1 
#グラフリスト 
#Simpson係数

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 0

Simpson係数 = 0.4

matrix_cons = []
for i in range(len(matrix_s)):
  if matrix_s[i][2] >= Simpson係数 and matrix_s[i][2] != 1:
    matrix_cons.append(matrix_s[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_cons) #ここに三次元リストを入れて実行！

  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))    #
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))  #
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)                                                                         #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_cons)):
    node_list_del.append(matrix_cons[i][0])
    node_list_del.append(matrix_cons[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/800)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/800) for i in sum_list]

H.add_weighted_edges_from(matrix_cons)
edge_width = [d["weight"] * 5  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = media, BLUE = political party, LIME = politician')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(21,14))
plt.title('Simpson index Threshold:{}'.format(Simpson係数))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# Number of communities in decomposed G: 2
# Modularity of decomposed G: 0.02700468969867679
# Identified components: [{'Moeruasia', 'Rikkenminsyu_Renho', 'Asahi', 'Nikkei', 'Rikkenminsyu_Edano', 'Anonymous', 'Jiyuminsyu_Leader', 'Ishin_Leader', 'Kokuminminsyu', 'Nhk', 'Kyosan', 'Syakaiminsyu_Leader', 'Reiwa', 'Akahata', 'Reiwa_Leader', 'Zakzak', 'Jiji', 'Kokuminminsyu_Leader', 'Share_News_Japan', 'Rikkenminsyu', 'Tokyo', 'Litera', 'Rikkenminsyu_Leader', 'Ishin', 'Jiyuminsyu_Suga', 'Seijichishin', 'Kyosan_Leader', 'Jiyuminsyu_Kono', 'Gendai_biz', 'Agora', 'Sankei', 'Ishin_Hashimoto', 'Syakaiminsyu', 'Yomiuri', 'Mainichi', 'Nikkan', 'Ishin_Yoshimura'}, {'Komei', 'Jiyuminsyu', 'Komei_Leader'}]
# Number of communities in decomposed G: 3
# Modularity of decomposed G: 0.33577419614052817
# ...

# %%
Simpson係数 = 0.2, Modularity = 0.11
Simpson係数 = 0.3, Modularity = 0.33
Simpson係数 = 0.4, Modularity = 0.48
Simpson係数 = 0.5, Modularity = 0.71

# %%
#セクション4.3 ②
#グラフリスト Simpson係数の拡張

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import matplotlib.pyplot as plt

sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News', 'Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa', 'Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
matrix_sk = [[0]*3 for i in range(len(sum_engname_list)**2)]

if data_import == 1:
  filename = 'Simpsonk_Total.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_skt=[]
      for row in csvreader:
        a_b_skt += row
  a_b_sk = []
  for i in a_b_skt:
    a_b_sk.append(float(i))

if data_import == 0:
  a_b_sk = []
  for a in sum_list:
    for b in sum_list:
      if a == b:
        a_b_sk.append(1)
      else:
        a_b_sk.append(len(set(a) & set(b))/(len(a)-1))

for n in range(3):
  if n == 0:
    for k in range(0, len(sum_engname_list)**2, 44):
      for i in range(44):
        matrix_sk[i+k][n] = sum_engname_list[k//44]
  elif n == 1:
    for k in range(0, len(sum_engname_list)**2, 44):
      for i in range(44):
        matrix_sk[i+k][n] = sum_engname_list[i]
  else:
    t = -1
    for k in range(0, len(sum_engname_list)**2, 44):
      for i in range(44):
        t += 1
        matrix_sk[i+k][n] = a_b_sk[t]

print(matrix_sk)
# Out:
# [['Gendai_biz', 'Gendai_biz', 1.0], ['Gendai_biz', 'Okinawa', 0.04297077911918039], ['Gendai_biz', 'Mainichi', 0.2640831627895333], ['Gendai_biz', 'Asahi', 0.3180688809197474], ['Gendai_biz', 'Jiji', 0.12257248893812232], ['Gendai_biz', 'Nikkei', 0.5199364137611636], ['Gendai_biz', 'Sankei', 0.15755117878622882], ['Gendai_biz', 'Tokyo', 0.05262762621805824], ['Gendai_biz', 'Yomiuri', 0.2728387876056902], ['Gendai_biz', 'Zakzak', 0.06475031761826978], ['Gendai_biz', 'Nhk', 0.45450392094277864], ['Gendai_biz', 'Akahata', 0.0305226463390974], ['Gendai_biz', 'Nikkan', 0.11108190483343033], ['Gendai_biz', 'Agora', 0.05021810830939462], ['Gendai_biz', 'Anonymous', 0.028213264239624992], ['Gendai_biz', 'Hamusoku', 0.03653705337864479], ['Gendai_biz', 'Seijichishin', 0.019482673375765883], ['Gendai_biz', 'Litera', 0.06574541722210749], ['Gendai_biz', 'Share_News_Japan', 0.037306847411802256], ['Gendai_biz', 'Moeruasia', 0.006364882371716641], ['Gendai_biz', 'BuzzFeed_Japan', 0.04916668231288
# ...

# %%
sum_engname_list1 = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News']
sum_engname_list2 = ['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa']
sum_engname_list3 = ['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']


#セクション4.3.1
#グラフリスト 
Simpson係数の拡張 = 0.45

matrix_consk = []
for i in range(len(matrix_sk)):
  if matrix_sk[i][2] >= Simpson係数の拡張 and matrix_sk[i][2] != 1:
    matrix_consk.append(matrix_sk[i])

H = nx.DiGraph()
for n in sum_engname_list:
    H.add_node(n)
size =[((len(i)-1)/800) for i in sum_list]
H.add_weighted_edges_from(matrix_consk)
edge_width = [d["weight"] * 5  for (u, v, d) in H.edges(data=True)]

c = []
for i in H.nodes():
  if i in sum_engname_list1:
    c.append('red')
  elif i in sum_engname_list2:
    c.append('blue')
  else:
    c.append('green')

# pos = nx.spring_layout(H, k=0.5) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(24,16))
plt.title('Enhanced Simpson index Threshold:{}'.format(Simpson係数の拡張))
nx.draw_networkx(H, pos,node_size = size, node_color=c, arrows=True, width = edge_width, connectionstyle="arc3, rad=0.1")

# %%
#セクション4.4 ②
#グラフリスト Simpson係数の拡張2nd 重み付き有向グラフを重み付き無向グラフに変換

# if csv is ready, data_import = 1, otherwise 0
data_import = 1

import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
sum_engname_list = ['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News', 'Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa', 'Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']
total = 0
for i in range(len(sum_engname_list)):
  total += i
matrix_sk2 = [[0]*3 for i in range(total)]

if data_import == 1:
  filename = 'Simpsonk2_Total.csv'
  with open(filename, encoding='utf8', newline='') as f:
      csvreader = csv.reader(f)

      a_b_sk2t=[]
      for row in csvreader:
        a_b_sk2t += row
  a_b_sk2 = []
  for i in a_b_sk2t:
    a_b_sk2.append(float(i))

if data_import == 0:
  a_b_sk2 = []
  c = 0
  for a in sum_list:
    c += 1
    d = 0
    for b in sum_list:
      d += 1
      if d > c:
        a_b_sk2.append(((len(set(a) & set(b))/(len(a)-1))+((len(set(a) & set(b)))/(len(b)-1)))/2)


for n in range(3):
  e = -1
  if n == 0:
    c = 0
    for i in range(len(sum_engname_list)):
      d = 0
      c += 1
      for k in range(len(sum_engname_list)):
        d += 1
        if c < d:
          e += 1
          matrix_sk2[e][0] = sum_engname_list[c-1]

  elif n == 1:
    c = 0
    for i in range(len(sum_engname_list)):
       d = 0
       c += 1
       for k in range(len(sum_engname_list)):
         d += 1
         if d > c:
           e += 1
           matrix_sk2[e][1] = sum_engname_list[d-1]
  
  else:
    for k in range(total):
      e += 1
      matrix_sk2[e][2] = a_b_sk2[e]
      
print(matrix_sk2)
# Out:
# [['Gendai_biz', 'Okinawa', 0.04919366572224011], ['Gendai_biz', 'Mainichi', 0.15397507191568965], ['Gendai_biz', 'Asahi', 0.17829802583225424], ['Gendai_biz', 'Jiji', 0.09067805828238826], ['Gendai_biz', 'Nikkei', 0.2718263414721294], ['Gendai_biz', 'Sankei', 0.09792653910494488], ['Gendai_biz', 'Tokyo', 0.07035936193678582], ['Gendai_biz', 'Yomiuri', 0.16307964333715452], ['Gendai_biz', 'Zakzak', 0.10411676144969184], ['Gendai_biz', 'Nhk', 0.23795412200679922], ['Gendai_biz', 'Akahata', 0.06205925818787637], ['Gendai_biz', 'Nikkan', 0.12577338540526367], ['Gendai_biz', 'Agora', 0.11721401524195826], ['Gendai_biz', 'Anonymous', 0.033023963215070576], ['Gendai_biz', 'Hamusoku', 0.025848100529795606], ['Gendai_biz', 'Seijichishin', 0.03289630314181847], ['Gendai_biz', 'Litera', 0.08236110086250471], ['Gendai_biz', 'Share_News_Japan', 0.04057886030199641], ['Gendai_biz', 'Moeruasia', 0.024147190722036426], ['Gendai_biz', 'BuzzFeed_Japan', 0.04553792710598811], ['Gendai_biz', 'Yahoo_News
# ...

# %%
sum_engname_list1 = [['Gendai_biz', 'Okinawa', 'Mainichi', 'Asahi', 'Jiji', 'Nikkei', 'Sankei', 'Tokyo', 'Yomiuri', 'Zakzak', 'Nhk', 'Akahata', 'Nikkan', 'Agora', 'Anonymous', 'Hamusoku', 'Seijichishin', 'Litera', 'Share_News_Japan', 'Moeruasia', 'BuzzFeed_Japan', 'Yahoo_News'],['Jiyuminsyu', 'Rikkenminsyu', 'Komei', 'Kyosan', 'Ishin', 'Kokuminminsyu', 'Syakaiminsyu', 'Reiwa'],['Jiyuminsyu_Leader', 'Rikkenminsyu_Leader', 'Komei_Leader', 'Kyosan_Leader', 'Ishin_Leader', 'Kokuminminsyu_Leader', 'Syakaiminsyu_Leader', 'Reiwa_Leader', 'Jiyuminsyu_Suga', 'Jiyuminsyu_Kono', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Renho', 'Ishin_Yoshimura', 'Ishin_Hashimoto']]
color_list10 = ['burlywood', 'turquoise', 'lime', 'yellow', 'lavender', 'coral', 'red', 'fuchsia', 'blue', 'lightcoral', 'lightyellow', 'bisque', 'aqua', 'olive', 'salmon', 'lightskyblue', 'chocolate', 'sateblue', 'palegreen', 'grey']
#セクション4.2.1 
#グラフリスト 
#Simpson係数の拡張2

#community detection   on → 1, off → 0
sign1 = 1
#Delete node with 0 edge delete → 1, retain → 0
sign2 = 0

Simpson係数の拡張2 = 0.25
# Simpson係数の拡張2 = 0

matrix_consk2 = []
for i in range(len(matrix_sk2)):
  if matrix_sk2[i][2] >= Simpson係数の拡張2 and matrix_sk2[i][2] != 1:
    matrix_consk2.append(matrix_sk2[i])

#########################################################################################################
if sign1 == 1:
  G = nx.Graph()  #let's create the graph first
  buildG(G, matrix_consk2) #ここに三次元リストを入れて実行！
    
  if _DEBUG_:
    print('G nodes: {} & G no of nodes: {}'.format(G.nodes(), G.number_of_nodes()))
    
  n = G.number_of_nodes()    #|V|
  A = nx.adjacency_matrix(G)    #adjacenct matrix

  m_ = 0.0    #the weighted version for number of edges
  for i in range(0,n):
    for j in range(0,n):
      m_ += A[i,j]
  m_ = m_/2.0
  if _DEBUG_:
          print("m: {}".format(m_))

    #calculate the weighted degree for each node
  Orig_deg = {}
  Orig_deg = UpdateDeg(A, G.nodes())

    #run Newman alg
  BestQ = 0.0
  Q = 0.0
  while True:    
      CmtyGirvanNewmanStep(G)                                                                                 #エッジが減らされて分割されたGが得られる。
      Q = _GirvanNewmanGetModularity(G, Orig_deg, m_);                                                        #Gのモジュラリティーを取得
      print("Modularity of decomposed G: {}".format(Q))
      if Q > BestQ:
          BestQ = Q                                                                                           #最高値のモジュラリティー値を取得
          Bestcomps = list(nx.connected_components(G))    #Best Split
          print("Identified components: {}".format(Bestcomps))
      if G.number_of_edges() == 0:                                                                            #分割し終えたら処理を抜ける
          break
  if BestQ > 0.0:                                                                                             #分割作業が終わって最大のモジュラリティーを得たので表示
    print("Max modularity found (Q): {} and number of communities: {}".format(BestQ, len(Bestcomps)))
    print("Graph communities: {}".format(Bestcomps))
  else:
    print("Max modularity (Q):", BestQ)                                                                         #G.nodes()でノードが並ぶリストが作られる。
#########################################################################################################

H = nx.Graph() #リンクを持つノードのみの集合を作成
if sign2 == 1: #次数0のノードを非表示
  node_list_del = []
  for i in range(len(matrix_consk2)):
    node_list_del.append(matrix_consk2[i][0])
    node_list_del.append(matrix_consk2[i][1])
  node_list_first = list(set(node_list_del)) #ノードの集合をリストにしてリストにしてsum_engname_listの順番に並び替えて順番に並び替えてsizeを作成
  node_list_final = []
  num = -1
  size = []
  for i in sum_engname_list:
    num += 1
    if i in node_list_first:
      node_list_final.append(i)
      size.append((len(sum_list[num])-1)/800)
  H.add_nodes_from(node_list_final)

if sign2 == 0: #全てのノードを表示
  for n in sum_engname_list:
    H.add_node(n)
  size =[((len(i)-1)/800) for i in sum_list]

H.add_weighted_edges_from(matrix_consk2)
edge_width = [d["weight"] * 10  for (u, v, d) in H.edges(data=True)]

if sign1 == 1:
  a = Bestcomps
  e = len(Bestcomps)
if sign1 == 0:
  a = sum_engname_list1
  e = len(sum_engname_list1)

c = []
for i in H.nodes():
  n = 0
  for j in range(e):
    if i in a[j]:
      n += 1
      c.append(color_list10[j])
  if sign2 == 0:
    if n == 0:
      c.append(color_list10[19])

if sign1 == 0:
  print('note : RED = media, BLUE = political party, LIME = politician')
if sign1 == 1:
  if sign2 == 0 and BestQ != 0.0:
    print('note : nodes in color gray are not in any community as it have no edges')
  if BestQ == 0:
    print('community detection fail')
# pos = nx.spring_layout(H, k=0.4) 
pos=nx.nx_pydot.graphviz_layout(H)
plt.figure(figsize=(21,14))
plt.title('Enhanced Simpson index 2nd Threshold:{}'.format(Simpson係数の拡張2))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")
# Out:
# Number of communities in decomposed G: 2
# Modularity of decomposed G: 0.46539892460492255
# Identified components: [{'Jiyuminsyu', 'Ishin_Yoshimura', 'Tokyo', 'Share_News_Japan', 'Jiji', 'Nhk', 'Anonymous', 'Agora', 'Yomiuri', 'Jiyuminsyu_Kono', 'Asahi', 'Ishin_Hashimoto', 'Nikkei', 'Jiyuminsyu_Leader', 'Mainichi', 'Seijichishin', 'Ishin', 'Gendai_biz', 'Sankei', 'Moeruasia', 'Jiyuminsyu_Suga', 'Komei_Leader', 'Yahoo_News', 'Ishin_Leader', 'Zakzak', 'Komei'}, {'Syakaiminsyu', 'Reiwa', 'Nikkan', 'Akahata', 'Litera', 'Kokuminminsyu_Leader', 'Kyosan_Leader', 'Kyosan', 'Rikkenminsyu', 'Reiwa_Leader', 'Rikkenminsyu_Renho', 'Rikkenminsyu_Edano', 'Rikkenminsyu_Leader', 'Syakaiminsyu_Leader', 'Kokuminminsyu'}]
# Number of communities in decomposed G: 3
# Modularity of decomposed G: 0.5701806204065016
# ...

# %%
# !pip install pyvis
from pyvis.network import Network

from IPython.core.display import display, HTML
nt = Network('800px', '800px', bgcolor='#222222', font_color='white', notebook=True)
nt.from_nx(H)
nt.show('nx.html')
display(HTML('nx.html')) # Colab上で表示するのに必要
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.6 MB 49.0 MB/s
# ...
#   Created wheel for pyvis: filename=pyvis-0.2.1-py3-none-any.whl size=23688 sha256=388c75f981f47517d42db5f72573f764133c0163e761b5a5496ec52bb5fb86b2
#   Stored in directory: /root/.cache/pip/wheels/2a/8f/04/6340d46afc74f59cc857a594ca1a2a14a1f4cbd4fd6c2e9306
# Successfully built pyvis
# ...
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
# ...

# %%
#国民民主党をフォローしている人のうち河野太郎をフォローしている人と立憲民主党の党首をフォローしている人の重複度合い？しかしこの図は立憲民主党の党首と国民民主党の党首をフォローしている人が極端に少なく、河野太郎と国民民主党の党首をフォローしている人が極端に多い場合でも成り立ってしまう。

# %%
Simpson係数拡張2 = 0.2, Modularity = 0.47
Simpson係数拡張2 = 0.3, Modularity = 0.70
Simpson係数拡張2 = 0.4, Modularity = 0.51
Simpson係数拡張2 = 0.5, Modularity = 0.28

# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

def draw_h(G, pos, measures, measure_name):                            #measure_nameはグラフのタイトル
  nodes = nx.draw_networkx_nodes(G, pos, node_size = 250,
                                 cmap = plt.cm.plasma,                 #matplotlibのcolormapを入力
                                 node_color = list(measures.values()),
                                 nodelist = list(measures.keys()))     #posは辞書型、list(measures.values())で辞書のインデックスの方をリストに格納リストに格納
  nodes.set_norm(mcolors.SymLogNorm(linthresh = 0.01, linscale = 1))   #?
  # labels = nx.draw_networkx_labels(G, pos)
  edges = nx.draw_networkx_edges(G, pos)                               #エッジを出力
  plt.title(measure_name)                                              #タイトルを表示
  plt.colorbar(nodes)                                                #カラーバーを出力
  plt.axis('off')
  plt.show()

# pos = nx.spring_layout(H)
pos=nx.nx_pydot.graphviz_layout(H)

# plt.subplot(211)
plt.figure(figsize=(12,8))
nx.draw_networkx(H, pos, node_size = size, node_color=c, arrows=False, width= edge_width, connectionstyle="arc3, rad=0.1")

# plt.subplot(212)
plt.figure(figsize=(12,8))
draw_h(H, pos, nx.degree_centrality(H), 'Degree Centrality')
print("次数中心性→次数が大きいノードほど中心")

# draw_h(H, pos, nx.eigenvector_centrality(H), 'Eigenvector Centrality')       #エラーが発生、固有ベクトル中心性→次数の大きいノードに隣接しているノードほど中心

plt.figure(figsize=(12,8))
draw_h(H, pos, nx.closeness_centrality(H), 'Closeness Centrality')
print("近接中心性→他のノードへの良いアクセスを持っているノードほど中心")

plt.figure(figsize=(12,8))
draw_h(H, pos, nx.betweenness_centrality(H), 'Betweenness Centrality')         
print("媒介中心性→多くの経路上に位置するノードほど中心")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: default base may change from np.e to 10.  To suppress this warning specify the base keyword argument.
#   # Remove the CWD from sys.path while we load stuff.
# 次数中心性→次数が大きいノードほど中心
# 近接中心性→他のノードへの良いアクセスを持っているノードほど中心
# 媒介中心性→多くの経路上に位置するノードほど中心

# %%
Z = nx.adjacency_matrix(H).todense()
print(Z)
print(f"隣接行列の次元：len(Z)")
# Out:
# [[0.         0.04919367 0.15397507 ... 0.07864708 0.05258512 0.1558428 ]
#  [0.04919367 0.         0.11363846 ... 0.08621988 0.03782982 0.08288658]
#  [0.15397507 0.11363846 0.         ... 0.15060126 0.05544637 0.12913553]
#  ...
#  [0.07864708 0.08621988 0.15060126 ... 0.         0.08390566 0.24459572]
#  [0.05258512 0.03782982 0.05544637 ... 0.08390566 0.         0.31175984]
#  [0.1558428  0.08288658 0.12913553 ... 0.24459572 0.31175984 0.        ]]
# 隣接行列の次元：len(Z)
